# %% [markdown]
# ## Scale-Shift and Fractional Fourier Transform as Rotations over Finite Holographic Substrate, [Akhtman, 2026, preprint](https://doi.org/10.20944/preprints202606.0127.v1)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Appendix A; [finitering.space/6-fourier/](https://finitering.space/6-fourier/)): it runs the
# blocks of [`fourier.py`](https://finitering.space/src/6-fourier/) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 10 s).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B1 (p06008) [D] — the deciding check A1
# Shell data, capacity-first: $\kap$ primary, $\p=4\kap+1$, the meridian cycle $\Phit=\Z_{4\kap}$, the
# oriented quarter-turn $\im=-\gen^{\kap}$ (clockwise phase convention), $\pi=2\kap$, $e=\gen^{\im}$; the
# meridians $M_s=\{a\gen^{s}:a\in I_\p\}$; the six shells of Table~\ref{tab:checks} with their generators and
# quarter-turns.
from frc_6_fourier import predicate; predicate("6:B1")
# Out:
# block A — the frame datum and the shell Fourier operator
#   [PASS] A1   EXACT   [6:B1] p = 4κ+1, g the smallest primitive root, i = −g^κ = g^{−κ}, i² ≡ −1, π = 2κ, 2π ≡ −1, g^π ≡ −1, −π ≡ 2⁻¹, e = g^i; Table tab:checks (κ, g, i)  --  F_5(κ=1, g=2, i=3, e=3); F_13(κ=3, g=2, i=5, e=6); F_17(κ=4, g=3, i=4, e=13); F_29(κ=7, g=2, i=17, e=21); F_37(κ=9, g=2, i=6, e=27); F_41(κ=10, g=6, i=9, e=19)
#   [PASS] A2   EXACT   [6:B2] e^{iπ} = g^{2κ(i mod 2)} ≡ −1 exactly on the odd quarter-turn; the conjugate reframing toggles it, one member of each pair carries it  --  54 primitive frames of p ∈ [5, 13, 17, 29, 37, 41], 27 carry e^{iπ} ≡ −1 (one per conjugate pair); F_13(t;0,1,2): i = 5, e = 6, 6^{30} = 6^{6} ≡ −1
#   [PASS] A3   EXACT   [6:B3] g' = g^u: the quarter-turn flips only on u ≡ 3 (mod 4); e' = g^{ui} ≠ e iff i(u−1) ≢ 0 (mod 4κ); at p = 13, u = 5: e' = 2 ≠ 6  --  every unit u of Z_{4κ} on the six shells; F_13, g' = 2^5 = 6: i' = 5, e' = 6^5 = 2
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B2 (p06009) [T] — the deciding check A2
# The Euler identity is a property of the chart class: $e^{\im\pi}=\gen^{2\kap(\im\bmod2)}\equiv-1$ exactly
# when the quarter-turn residue is odd; the conjugate reframing $(\gen,\im)\mapsto(\gen^{-1},-\im)$ toggles
# the parity, so one member of each conjugate pair carries it; on $\F_{13}(\chron;0,1,2)$, $\im=5$ and
# $6^{6}=-1$. Every primitive frame of the six shells.
from frc_6_fourier import predicate; predicate("6:B2")
# Out:
# — fourier.py:376 (the check that decides 6:B2: A2)
#   376      # 6:B2 (p06009)
#   377      check("A2", "e^{iπ} = g^{2κ(i mod 2)} ≡ −1 exactly on the odd quarter-turn; the conjugate reframing toggles it, one member of each pair carries it",
#   378            ok, f"{n_frames} primitive frames of p ∈ {SHELLS}, {n_carry} carry e^{{iπ}} ≡ −1 (one per conjugate pair); F_13(t;0,1,2): i = 5, e = 6, 6^{{30}} = 6^{{6}} ≡ −1")
#   379
#   380      # A3 — the u-relabelling
#   381      ok = True
#   382      for p in SHELLS:
#   383          f = frames[p]
#   384          for u in range(1, f.n):
#   385              if np.gcd(u, f.n) != 1:
#   386                  continue
#   387              fu = Frame(p, pow(f.g, u, p))
#   388              ok &= (fu.i == f.i) if u % 4 == 1 else (fu.i == (-f.i) % p)
#   389              if u % 4 == 1:
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B3 (p06010) [T] — the deciding check A3
# Chart covariance: under $\gen'=\gen^{u}$, $u\in\Zp^{\times}$, the quarter-turn name flips exactly on
# $u\equiv3\pmod4$ and the exponential-unit name moves already at $u\equiv1\pmod4$ whenever
# $\im(u-1)\not\equiv0\pmod{4\kap}$ ($\p=13$, $u=5$: $e'=2\neq6$); the registered objects (C3, C4, C9, F3) are
# invariant.
from frc_6_fourier import predicate; predicate("6:B3")
# Out:
# — fourier.py:394 (the check that decides 6:B3: A3)
#   394      # 6:B3 (p06010)
#   395      check("A3", "g' = g^u: the quarter-turn flips only on u ≡ 3 (mod 4); e' = g^{ui} ≠ e iff i(u−1) ≢ 0 (mod 4κ); at p = 13, u = 5: e' = 2 ≠ 6",
#   396            ok, "every unit u of Z_{4κ} on the six shells; F_13, g' = 2^5 = 6: i' = 5, e' = 6^5 = 2")
#   397
#   398      # A4 — the operator identities of Table tab:checks (00:C2)
#   399      ok, det = True, []
#   400      for p in SHELLS:
#   401          f = frames[p]
#   402          W2 = mm(f.W, f.W, p); F2 = mm(f.F, f.F, p); F4 = mm(F2, F2, p)
#   403          a, b, c = eq(W2, (-f.J) % p, p), eq(F2, f.J, p), eq(F4, f.I(), p)
#   404          ok &= a and b and c
#   405          det.append(f"p={p}: {a},{b},{c}")
#   406      # 6:B5 (p06012)
#   407      check("A4", "W² = −J, (iW)² = J, (iW)⁴ = I on the six shells of Table tab:checks", ok, "; ".join(det))
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B5 (p06012) [T] — the deciding check A4
# $\Wt^{2}=-J$, $\Ft^{2}=J$, $\Ft^{4}=I$: the normalized operator generates the four-cycle, on the six shells
# of Table~\ref{tab:checks}.
from frc_6_fourier import predicate; predicate("6:B5")
# Out:
# — fourier.py:406 (the check that decides 6:B5: A4)
#   406      # 6:B5 (p06012)
#   407      check("A4", "W² = −J, (iW)² = J, (iW)⁴ = I on the six shells of Table tab:checks", ok, "; ".join(det))
#   408
#   409      # A5 — the unitary normalisation read in the field
#   410      ok = True
#   411      for p in SHELLS:
#   412          f = frames[p]
#   413          roots = sorted(c for c in range(p) if c * c % p == p - 1)
#   414          ok &= (roots == sorted([f.i, (-f.i) % p]))
#   415          ok &= ((1 * pow(f.n, p - 2, p)) % p == p - 1)                        # 1/n = −1
#   416          for c in range(1, p):
#   417              ok &= (eq(mm(c * f.W % p, c * f.W % p, p), f.J, p) == (c in roots))
#   418      # 6:B6 (p06013)
#   419      check("A5", "the square roots of 1/n ≡ −1 in F_p are exactly ±i, the two unitary normalisations of W: (cW)² = J iff c = ±i", ok, f"every c ∈ F_p^× tested on p ∈ {SHELLS}")
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B6 (p06013) [T] — the deciding check A5
# The normalization is the unitary constant read in the field: $1/n\equiv-1$, its square roots in $\Fp$ are
# exactly $\pm\im$, and $(c\Wt)^{2}=J$ if and only if $c=\pm\im$.
from frc_6_fourier import predicate; predicate("6:B6")
# Out:
# — fourier.py:418 (the check that decides 6:B6: A5)
#   418      # 6:B6 (p06013)
#   419      check("A5", "the square roots of 1/n ≡ −1 in F_p are exactly ±i, the two unitary normalisations of W: (cW)² = J iff c = ±i", ok, f"every c ∈ F_p^× tested on p ∈ {SHELLS}")
#   420
#   421      # A6 — the symmetric/antisymmetric decomposition
#   422      ok, det = True, []
#   423      for p in SHELLS:
#   424          f = frames[p]
#   425          ok &= eq(mm(f.W, f.J, p), mm(f.J, f.W, p), p) and eq(mm(f.F, f.J, p), mm(f.J, f.F, p), p)
#   426          dplus = f.n - rank_mod_p((f.J - f.I()) % p, p); dminus = f.n - rank_mod_p((f.J + f.I()) % p, p)
#   427          ok &= (dplus == 2 * f.kap + 1 and dminus == 2 * f.kap - 1)
#   428          det.append(f"p={p}: dim V⁺={dplus}, V⁻={dminus}")
#   429      # 6:B7 (p06014)
#   430      check("A6", "WJ = JW, FJ = JF; dim V⁺ = 2κ+1, dim V⁻ = 2κ−1", ok, "; ".join(det))
#   431
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:B7 (p06014) [T] — the deciding check A6
# $\Wt J=J\Wt$, hence $\Ft J=J\Ft$; $\Vt=V^{+}\oplus V^{-}$ with $\dim V^{+}=2\kap+1$, $\dim V^{-}=2\kap-1$.
from frc_6_fourier import predicate; predicate("6:B7")
# Out:
# — fourier.py:429 (the check that decides 6:B7: A6)
#   429      # 6:B7 (p06014)
#   430      check("A6", "WJ = JW, FJ = JF; dim V⁺ = 2κ+1, dim V⁻ = 2κ−1", ok, "; ".join(det))
#   431
#   432  # ------------------------------------------------------------------------------------------------------------
#   433  # Block B — the fractional family F^[s] = Σ_ℓ g^{−ℓs} Π_ℓ (EXACT, integer-pinned)
#   434  # ===============================================================================
#   435  # Paper statements decided (Section 5; master ledger rows 00:C2, 00:C7):
#   436  #
#   437  #   B1  lem:projectors        Π_ℓ² = Π_ℓ, Π_ℓ Π_m = 0 (ℓ ≠ m), Σ_ℓ Π_ℓ = I, F Π_ℓ = i^ℓ Π_ℓ
#   438  #   B2  thm:FRC-FrFT          additivity F^[s+r] = F^[s] F^[r] on every pair (s, r) ∈ Z_{4κ}²      (00:C2)
#   439  #   B3  thm:FRC-FrFT          cardinal values F^[0] = I, F^[κ] = F, F^[2κ] = J, F^[3κ] = F⁻¹, F^[4κ] = I;
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C2 (p06016) [T] — the deciding check B1
# $\Pi_\ell^{2}=\Pi_\ell$, $\Pi_\ell\Pi_m=0$ for $\ell\neq m$, $\sum_\ell\Pi_\ell=I$,
# $\Ft\Pi_\ell=\im^{\ell}\Pi_\ell$.
from frc_6_fourier import predicate; predicate("6:C2")
# Out:
# block B — the fractional family
#   [PASS] B1   EXACT   [6:C2] Π_ℓ² = Π_ℓ, Π_ℓ Π_m = 0, Σ Π_ℓ = I, F Π_ℓ = i^ℓ Π_ℓ  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] B2   EXACT   [6:C3] F^[s+r] = F^[s] F^[r] on every pair (s, r) of Z_{4κ}  --  4096 pairs over p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] B3   EXACT   [6:C3] F^[0] = I, F^[κ] = F, F^[2κ] = J, F^[3κ] = F⁻¹, F^[4κ] = I; (F^[1])^κ = F  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] B4   EXACT   [6:C4] s ↦ F^[s] is injective on Z_{4κ}: the 4κ members are pairwise distinct (p = 5 included)  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] B5   EXACT   [6:C5] m_ℓ = rank Π_ℓ = dim ker(F − i^ℓ I); m_0+m_2 = 2κ+1, m_1+m_3 = 2κ−1; m_0, m_2 ≥ 1; m_1, m_3 ≥ 1 for κ ≥ 2; p = 5: one odd projector vanishes  --  p=5: (2, 0, 1, 1); p=13: (3, 3, 4, 2); p=17: (4, 4, 5, 3); p=29: (7, 7, 8, 6); p=37: (9, 9, 10, 8); p=41: (10, 10, 11, 9)
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C3 (p06017) [T] — the deciding check B2
# The exact finite-field FrFT: $s\mapsto\Ft^{[s]}$ is a representation of $\Phit$,
# $\Ft^{[s+r]}=\Ft^{[s]}\Ft^{[r]}$ on every pair of the six shells, with the cardinal values $\Ft^{[0]}=I$,
# $\Ft^{[\kap]}=\Ft$, $\Ft^{[2\kap]}=J$, $\Ft^{[3\kap]}=\Ft^{-1}$, and $(\Ft^{[1]})^{\kap}=\Ft$.
from frc_6_fourier import predicate; predicate("6:C3")
# Out:
# — fourier.py:493 (the check that decides 6:C3: B2)
#   493      # 6:C3 (p06017)
#   494      check("B2", "F^[s+r] = F^[s] F^[r] on every pair (s, r) of Z_{4κ}", ok, f"{npairs} pairs over p ∈ {SHELLS}")
#   495
#   496      # B3 — cardinal values
#   497      ok = True
#   498      for p in SHELLS:
#   499          f = frames[p]; fam = f._fam; k = f.kap
#   500          F3 = matpow(f.F, 3, p)
#   501          ok &= eq(fam[0], f.I(), p) and eq(fam[k], f.F, p) and eq(fam[2 * k], f.J, p) and eq(fam[3 * k], F3, p)
#   502          ok &= eq(mm(F3, f.F, p), f.I(), p)                       # F³ = F⁻¹
#   503          ok &= eq(matpow(fam[1], k, p), f.F, p)
#   504      check("B3", "F^[0] = I, F^[κ] = F, F^[2κ] = J, F^[3κ] = F⁻¹, F^[4κ] = I; (F^[1])^κ = F", ok, f"p ∈ {SHELLS}")
#   505
#   506      # B4 — faithfulness
#   [PASS] B2   (deciding)       4096 pairs over p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] B3   (corroborating)  p ∈ [5, 13, 17, 29, 37, 41]
# 6:C3: VERIFIED — 2 record(s)

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C4 (p06018) [T] — the deciding check B4
# Faithfulness: $s\mapsto\Ft^{[s]}$ is injective on $\Z_{4\kap}$ for every $\kap\ge1$; at $\p=5$ the surviving
# odd projector carries the faithful character.
from frc_6_fourier import predicate; predicate("6:C4")
# Out:
# — fourier.py:512 (the check that decides 6:C4: B4)
#   512      # 6:C4 (p06018)
#   513      check("B4", "s ↦ F^[s] is injective on Z_{4κ}: the 4κ members are pairwise distinct (p = 5 included)", ok, f"p ∈ {SHELLS}")
#   514
#   515      # B5 — the multiplicity lemma
#   516      ok, det = True, []
#   517      for p in SHELLS:
#   518          f = frames[p]; m = f.mults()
#   519          for l in range(4):
#   520              ok &= (m[l] == f.n - rank_mod_p((f.F - pow(f.i, l, p) * f.I()) % p, p))
#   521          ok &= (m[0] + m[2] == 2 * f.kap + 1 and m[1] + m[3] == 2 * f.kap - 1 and m[0] >= 1 and m[2] >= 1)
#   522          ok &= (m[1] >= 1 and m[3] >= 1) if f.kap >= 2 else ((m[1] == 0) != (m[3] == 0))
#   523          det.append(f"p={p}: {m}")
#   524      # 6:C5 (p06019)
#   525      check("B5", "m_ℓ = rank Π_ℓ = dim ker(F − i^ℓ I); m_0+m_2 = 2κ+1, m_1+m_3 = 2κ−1; m_0, m_2 ≥ 1; m_1, m_3 ≥ 1 for κ ≥ 2; p = 5: one odd projector vanishes", ok, "; ".join(det))
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C5 (p06019) [T] — the deciding check B5
# The multiplicities $m_\ell=\operatorname{rank}\Pi_\ell=\dim\ker(\Ft-\im^{\ell}I)$: $m_0+m_2=2\kap+1$,
# $m_1+m_3=2\kap-1$; $m_0,m_2\ge1$; $m_1,m_3\ge1$ for $\kap\ge2$; at $\p=5$ exactly one of $\Pi_1,\Pi_3$
# vanishes.
from frc_6_fourier import predicate; predicate("6:C5")
# Out:
# — fourier.py:524 (the check that decides 6:C5: B5)
#   524      # 6:C5 (p06019)
#   525      check("B5", "m_ℓ = rank Π_ℓ = dim ker(F − i^ℓ I); m_0+m_2 = 2κ+1, m_1+m_3 = 2κ−1; m_0, m_2 ≥ 1; m_1, m_3 ≥ 1 for κ ≥ 2; p = 5: one odd projector vanishes", ok, "; ".join(det))
#   526
#   527      # B6 — multiplicities are chart data
#   528      f2, f6 = Frame(13, 2), Frame(13, 6)
#   529      ok = (f2.mults() == (3, 3, 4, 2) and f6.mults() == (4, 2, 3, 3))
#   530      ok &= (int(np.trace(f2.F)) % 13 == 4 and int(np.trace(f6.F)) % 13 == 9)
#   531      ok &= (pow(2, 5, 13) == 6)                                    # same orientation class: 6 = 2^5, 5 ≡ 1 (mod 4)
#   532      nconj = 0
#   533      for p in SHELLS:
#   534          f = frames[p]
#   535          for u in range(1, f.n):
#   536              if np.gcd(u, f.n) != 1:
#   537                  continue
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C6 (p06020) [T] — the deciding check B6
# Multiplicities are chart data: the vertex relabelling $m\mapsto um$ carries $\Ft(\gen)$ to
# $\Ft(\gen^{u^{2}})$ by a coordinate permutation; at $\p=13$ the frames $\gen=2$ and $\gen=6$ give
# $(3,3,4,2)$ and $(4,2,3,3)$, traces $4$ and $9$.
from frc_6_fourier import predicate; predicate("6:C6")
# Out:
# — fourier.py:541 (the check that decides 6:C6: B6)
#   541      # 6:C6 (p06020)
#   542      check("B6", "p = 13: g = 2 gives (3,3,4,2), Tr F = 4; g = 6 gives (4,2,3,3), Tr F = 9; m ↦ um carries F(g) to F(g^{u²}) by a permutation", ok, f"{nconj} relabellings over p ∈ {SHELLS}")
#   543
#   544      # B7 — the multiplicity dichotomy on every primitive frame
#   545      ok, det, n38 = True, [], 0
#   546      for p in SHELLS:
#   547          f0 = frames[p]; k = f0.kap
#   548          prims = primitive_roots(p)
#   549          eps = {}
#   550          for g in prims:
#   551              f = Frame(p, g); e = f.epsilon()
#   552              ok &= (e is not None)
#   553              eps[g] = e
#   554              want = (k, k, k + 1, k - 1) if e == 1 else (k + 1, k - 1, k, k)
#   [PASS] B6   (deciding)       54 relabellings over p ∈ [5, 13, 17, 29, 37, 41]
# 6:C6: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C7 (p06021) [T] — the deciding check B7
# The multiplicity dichotomy: $G=\sum_{k}\gen^{k^{2}}=\varepsilon(1+\im)$; the tuple is
# $(\kap,\kap,\kap+1,\kap-1)$ for $\varepsilon=+1$ and $(\kap+1,\kap-1,\kap,\kap)$ for $\varepsilon=-1$;
# $\varepsilon(\gen^{-1})=-\varepsilon(\gen)$,
# $\varepsilon(\gen^{u})=\bigl(\tfrac{\kap}{u}\bigr)\varepsilon(\gen)$ for $u\equiv1\pmod4$, the two classes
# equally populated; the proof's identities $GG^{*}=-2$, $G^{2}=2\im$, $\operatorname{Tr}\Ft=\im G$,
# $\operatorname{Tr}\Ft^{2}=2$, $\operatorname{Tr}\Ft^{3}=\im G^{*}$. Exact on the $38$ primitive frames of
# $\p\in\{5,13,17,29,37\}$ and the $16$ of $\p=41$.
from frc_6_fourier import predicate; predicate("6:C7")
# Out:
# — fourier.py:570 (the check that decides 6:C7: B7)
#   570      # 6:C7 (p06021)
#   571      check("B7", "G = ε(1+i), the two patterns, ε(g⁻¹) = −ε(g), ε(g^u) = (κ/u) ε(g), classes equally populated; 38 frames of p ∈ {5,…,37} and 16 of p = 41; p = 5: (2,0,1,1) at g = 2, (1,1,2,0) at g = 3",
#   572            ok, "; ".join(det))
#   573
#   574      # B8 — the proof's identities
#   575      ok = True
#   576      for p in SHELLS:
#   577          for g in primitive_roots(p):
#   578              f = Frame(p, g)
#   579              G = f.gauss(); Gs = sum(f.gpow(-k * k) for k in range(f.n)) % p
#   580              ok &= (G * Gs % p == p - 2 and G * G % p == 2 * f.i % p)
#   581              tr = [int(np.trace(f.Fpow(r))) % p for r in range(4)]
#   582              ok &= (tr[1] == f.i * G % p and tr[2] == 2 and tr[3] == f.i * Gs % p)
#   583              m = f.mults()
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C8 (p06022) [T] — the deciding check B9
# Classification: every exponent lift $a_\ell\equiv\ell\pmod4$ is additive with the same cardinal skeleton; a
# family canonical in the chart $\gen^{u}$ with $u^{2}\not\equiv1\pmod{4\kap}$ does not commute with $\Ft$
# ($\p=29$, $u=5$, and every such chart of the six shells); the principal lift is the unique power-tower
# member.
from frc_6_fourier import predicate; predicate("6:C8")
# Out:
# — fourier.py:606 (the check that decides 6:C8: B9)
#   606      # 6:C8 (p06022)
#   607      check("B9", "exponent lifts a_ℓ ≡ ℓ (mod 4) are additive with the cardinal skeleton (p = 13); the chart g^5 at p = 29 (u² ≢ 1 mod 28) does not commute with F",
#   608            ok, f"non-commuting at p = 29, u = 5: {noncomm}; all charts with u² ≢ 1 (mod 4κ) on the six shells non-commuting: {all(x[2] for x in scan)} ({len(scan)} charts)")
#   609
#   610      # B10 — the conjugate reframing (00:C7, transform layer)
#   611      ok, det = True, []
#   612      for p in SHELLS:
#   613          f = frames[p]; fc = f.conjugate(); k = f.kap
#   614          ok &= (fc.i == (-f.i) % p)
#   615          Finv = matpow(f.F, 3, p)
#   616          ok &= eq(fc.F, (-Finv) % p, p)                                             # F' = −F⁻¹
#   617          ok &= eq(mm(fc.F, fc.F, p), f.J, p) and eq(matpow(fc.F, 4, p), f.I(), p)
#   618          famc = [fc.frft(s) for s in range(f.n)]
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:C9 (p06023) [T] — the deciding check B10
# The conjugate reframing $(\gen,\im)\mapsto(\gen^{-1},-\im)$: exactly $\Ft'=-\Ft^{-1}$ and
# $\Pi'_\ell=\Pi_{\ell+2}$; the operator relations, cardinal values, additivity and faithfulness hold on the
# conjugate frame, and its multiplicity tuple is the other pattern of C7.
from frc_6_fourier import predicate; predicate("6:C9")
# Out:
# — fourier.py:626 (the check that decides 6:C9: B10)
#   626      # 6:C9 (p06023)
#   627      check("B10", "the conjugate frame (g⁻¹, −i) keeps the operator relations, cardinal values, additivity and faithfulness; its multiplicity tuple is the other pattern; F' = −F⁻¹, Π'_ℓ = Π_{ℓ+2}",
#   628            ok, "; ".join(det))
#   629
#   630  # ------------------------------------------------------------------------------------------------------------
#   631  # Block C — representation domains and the coordinate-side zoom (EXACT, integer-pinned)
#   632  # =====================================================================================
#   633  # Paper statements decided (Sections 6–7; master ledger row 00:C2):
#   634  #
#   635  #   C1  def:domain            every F^[s] is invertible (rank 4κ over F_p); its eigenvalues g^{−ℓs} are
#   636  #                             nonzero, so the meridional bases B_s = F^[s] B_0 are bases
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:D1 (p06024) [D] — the deciding check C1
# The meridional representation domain $D_s=(\Vt,\mathcal B_s)$, $\mathcal B_s=\Ft^{[s]}\mathcal B_0$, every
# $\Ft^{[s]}$ invertible; the cardinal domains spatial, spectral, parity, inverse-spectral.
from frc_6_fourier import predicate; predicate("6:D1")
# Out:
# block C — representation domains and the coordinate-side zoom
#   [PASS] C1   EXACT   [6:D1] every F^[s] has full rank 4κ over F_p; the eigenvalues g^{−ℓs} are nonzero  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] C2   EXACT   [6:D2] the 4κ framed bases B_s = F^[s] B_0 are pairwise distinct  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] C3   EXACT   [6:D2] F^[s+2κ] = F^[s] J, so B_{s+2κ} = B_s as unordered bases: 4κ framed domains, exactly 2κ measurement bases  --  p=5: 4 framed, 2 unordered; p=13: 12 framed, 6 unordered; p=17: 16 framed, 8 unordered; p=29: 28 framed, 14 unordered; p=37: 36 framed, 18 unordered; p=41: 40 framed, 20 unordered
#   [PASS] C4   EXACT   [6:D4] S_r(M_m) = M_{m+r} on every (m, r), as ordered lists  --  4096 pairs over p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] C5   EXACT   [6:D4] consecutive entries of M_m differ by the effective step g^m; S_{r+(p−1)} = S_r  --  p ∈ [5, 13, 17, 29, 37, 41]
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:D2 (p06025) [T] — the deciding check C2
# The $4\kap$ framed domains are pairwise distinct; read as unordered measurement bases $B_{s+2\kap}=B_s$,
# since $\Ft^{[s+2\kap]}=\Ft^{[s]}J$ and $J$ permutes the standard basis, and the cycle carries exactly
# $2\kap$ of them.
from frc_6_fourier import predicate; predicate("6:D2")
# Out:
# — fourier.py:669 (the check that decides 6:D2: C2)
#   669      # 6:D2 (p06025)
#   670      check("C2", "the 4κ framed bases B_s = F^[s] B_0 are pairwise distinct", ok, f"p ∈ {SHELLS}")
#   671
#   672      # C3 — unordered bases: the parity identification
#   673      ok, det = True, []
#   674      for p in SHELLS:
#   675          f = frames[p]; k = f.kap
#   676          ok &= all(eq(f._fam[(s + 2 * k) % f.n], mm(f._fam[s], f.J, p), p) for s in range(f.n))
#   677          unordered = {frozenset(map(tuple, M.T)) for M in f._fam}
#   678          ok &= (len(unordered) == 2 * k)
#   679          det.append(f"p={p}: {f.n} framed, {len(unordered)} unordered")
#   680      check("C3", "F^[s+2κ] = F^[s] J, so B_{s+2κ} = B_s as unordered bases: 4κ framed domains, exactly 2κ measurement bases", ok, "; ".join(det))
#   681
#   682      # C4 — meridian-scale covariance
#   [PASS] C2   (deciding)       p ∈ [5, 13, 17, 29, 37, 41]
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:D4 (p06027) [T] — the deciding check C4
# Meridian-scale covariance: $S_r(M_m)=M_{m+r}$ for every $(m,r)$, as ordered lists; consecutive entries of
# $M_m$ differ by the effective step $\gen^{m}$; $S_{r+(\p-1)}=S_r$, the periodicity of A5 in meridian form.
from frc_6_fourier import predicate; predicate("6:D4")
# Out:
# — fourier.py:690 (the check that decides 6:D4: C4)
#   690      # 6:D4 (p06027)
#   691      check("C4", "S_r(M_m) = M_{m+r} on every (m, r), as ordered lists", ok, f"{npairs} pairs over p ∈ {SHELLS}")
#   692
#   693      # C5 — the effective step and the periodicity
#   694      ok = True
#   695      for p in SHELLS:
#   696          f = frames[p]
#   697          for m in range(f.n):
#   698              Mm = f.meridian(m)
#   699              ok &= all((Mm[a + 1] - Mm[a]) % p == f.gpow(m) for a in range(f.pi))
#   700          ok &= all(f.S(r + p - 1, x) == f.S(r, x) for r in range(f.n) for x in range(p))
#   701      check("C5", "consecutive entries of M_m differ by the effective step g^m; S_{r+(p−1)} = S_r", ok, f"p ∈ {SHELLS}")
#   702
#   703      # C6 — the ladder at p = 13 and the no-wrap window
#   [PASS] C4   (deciding)       4096 pairs over p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] C5   (corroborating)  p ∈ [5, 13, 17, 29, 37, 41]
# 6:D4: VERIFIED — 2 record(s)

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:D5 (p06028) [T] — the deciding check C6
# Meridian zoom [chart]: $M_m$ reads the meridian-coordinate vector at step $\lambda^{\tilde m}$, the forward
# shift zoom-out and the inverse shift zoom-in, the seam an aliasing return; at $\p=13$, $\gen=2$ the ladder
# $M_0,\dots,M_3$ at steps $1,2,4,8$, unwrapped within $w\gen^{r}<\p$ ($w=\pi=6$: $r\le1$) and wrapping from
# $M_2$.
from frc_6_fourier import predicate; predicate("6:D5")
# Out:
# — fourier.py:712 (the check that decides 6:D5: C6)
#   712      # 6:D5 (p06028)
#   713      check("C6", "p = 13, g = 2: M_0…M_3 = the printed ladder at steps 1, 2, 4, 8; the no-wrap window w·g^r < p with w = π = 6 holds for r ≤ 1 and the listing wraps from M_2", ok, f"unwrapped meridians {unwrapped}, wrapping {wraps}")
#   714
#   715  # ------------------------------------------------------------------------------------------------------------
#   716  # Block D — the Weil dictionary and the operator-level comparison (EXACT, integer-pinned)
#   717  # =======================================================================================
#   718  # Paper statements decided (Section 8):
#   719  #
#   720  #   D1  lem:Rs-rotation       c_s² + d_s² = 1 and det R_s = 1 for every s: R_s ∈ SO(2, F_p)
#   721  #   D2  prop:rotation-isom    s ↦ R_s is a homomorphism Z_{4κ} → SO(2, F_p), injective, onto: |SO(2, F_p)| = p−1
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:E2 (p06031) [T] — the deciding check D2
# $R_s\in SO(2,\Fp)$, and $s\mapsto R_s$ is an isomorphism $\Phit\simeq SO(2,\Fp)$ with
# $|SO(2,\Fp)|=\p-1=4\kap$: the full rotation group of the $\p^{2}$-point plane is the meridian cycle.
from frc_6_fourier import predicate; predicate("6:E2")
# Out:
# block D — the Weil dictionary and the operator-level comparison
#   [PASS] D1   EXACT   [6:E2] c_s² + d_s² = 1, det R_s = 1: R_s ∈ SO(2, F_p) for every s  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] D2   EXACT   [6:E2] R_{s+r} = R_s R_r, s ↦ R_s injective, |SO(2, F_p)| = p−1 = 4κ: an isomorphism  --  p=5: |SO(2)|=4; p=13: |SO(2)|=12; p=17: |SO(2)|=16; p=29: |SO(2)|=28; p=37: |SO(2)|=36; p=41: |SO(2)|=40
#   [PASS] D3   EXACT   [6:E3] R_0 = I, R_κ = [[0,−1],[1,0]] (Table tab:checks), R_{2κ} = −I, R_{3κ} = w⁻¹; z_κ = g^{−κ} = i  --  p ∈ [5, 13, 17, 29, 37, 41]
#   [PASS] D4   EXACT   [6:E5] σ has the 4κ simple eigenvalues F_p^×; F^[1] has at most four; for κ ≥ 2 ⟨σ⟩ and ⟨F^[1]⟩ are not conjugate  --  p=5: σ has 4 simple eigenvalues, F^[1] has 3; p=13: σ has 12 simple eigenvalues, F^[1] has 4; p=17: σ has 16 simple eigenvalues, F^[1] has 4; p=29: σ has 28 simple eigenvalues, F^[1] has 4; p=37: σ has 36 simple eigenvalues, F^[1] has 4; p=41: σ has 40 simple eigenvalues, F^[1] has 4
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:E3 (p06032) [T] — the deciding check D3
# The cardinal-skeleton dictionary $M_s\leftrightarrow s\leftrightarrow z_s\leftrightarrow R_s$ with $R_0=I$,
# $R_\kap=w$, $R_{2\kap}=-I$, $R_{3\kap}=w^{-1}$ (the $R_\kap$ column of Table~\ref{tab:checks}),
# $z_\kap=\im$; the FRC-native and Weil families stand in cardinal Weil correspondence, the Weil side by the
# normalization of A2.
from frc_6_fourier import predicate; predicate("6:E3")
# Out:
# — fourier.py:781 (the check that decides 6:E3: D3)
#   781      # 6:E3 (p06032)
#   782      check("D3", "R_0 = I, R_κ = [[0,−1],[1,0]] (Table tab:checks), R_{2κ} = −I, R_{3κ} = w⁻¹; z_κ = g^{−κ} = i", ok, f"p ∈ {SHELLS}")
#   783
#   784      # D4 — the spectral obstruction
#   785      ok, det = True, []
#   786      for p in SHELLS:
#   787          f = frames[p]; n = f.n
#   788          sig = shift(n)
#   789          ok &= eq(matpow(sig, n, p), f.I(), p) and all(not eq(matpow(sig, r, p), f.I(), p) for r in range(1, n))
#   790          ok &= all(rank_mod_p((sig - a * f.I()) % p, p) == n - 1 for a in range(1, p))      # every a ∈ F_p^× a simple eigenvalue
#   791          ok &= all(rank_mod_p((f.frft(1) - a * f.I()) % p, p) == n for a in range(1, p) if a not in {f.gpow(-l) for l in range(4)})
#   792          neig = sum(1 for a in range(1, p) if rank_mod_p((f.frft(1) - a * f.I()) % p, p) < n)
#   793          ok &= (neig <= 4) and (f.kap == 1 or neig < n)
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:E5 (p06034) [T] — the deciding check D4
# Spectral obstruction: the exponent shift $\sigma$ has the $4\kap$ simple eigenvalues $\Fpx$, every
# $\Ft^{[s]}$ at most four; for $\kap\ge2$ the cyclic groups $\langle\sigma\rangle$ and
# $\langle\Ft^{[1]}\rangle$ are not conjugate.
from frc_6_fourier import predicate; predicate("6:E5")
# Out:
# — fourier.py:795 (the check that decides 6:E5: D4)
#   795      # 6:E5 (p06034)
#   796      check("D4", "σ has the 4κ simple eigenvalues F_p^×; F^[1] has at most four; for κ ≥ 2 ⟨σ⟩ and ⟨F^[1]⟩ are not conjugate", ok, "; ".join(det))
#   797
#   798      # D5 — the common character sector
#   799      ok, det = True, []
#   800      for p in SHELLS:
#   801          f = frames[p]; n = f.n
#   802          P1 = f.Pi[1]; m1 = rank_mod_p(P1, p)
#   803          ok &= (m1 >= 1) if f.kap >= 2 else True
#   804          if m1 == 0:
#   805              det.append(f"p={p}: E_1 = 0 (κ = 1)"); continue
#   806          cols = [P1[:, j] for j in range(n) if np.any(P1[:, j])]
#   807          for s in range(n):
#   808              Fs = f.frft(s)
#   [PASS] D4   (deciding)       p=5: σ has 4 simple eigenvalues, F^[1] has 3; p=13: σ has 12 simple eigenvalues, F^[1] has 4; p=17: σ has 16 simple eigenvalues, F^[1] has 4; p=29: σ
# 6:E5: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:E6 (p06035) [T] — the deciding check D5
# Common character sector: on $E_1=\operatorname{im}\Pi_1\neq0$ ($\kap\ge2$) $\Ft^{[s]}=\gen^{-s}I$, the
# intertwiner $\Ft^{[s]}T_v=T_vS_{-s}$ on every $x\in\Fp$ and $s$, and $R_s(1,-\im)^{\mathsf
# T}=\gen^{-s}(1,-\im)^{\mathsf T}$.
from frc_6_fourier import predicate; predicate("6:E6")
# Out:
# — fourier.py:818 (the check that decides 6:E6: D5)
#   818      # 6:E6 (p06035)
#   819      check("D5", "E_1 ≠ 0 for κ ≥ 2; F^[s] = g^{−s} on E_1; F^[s] T_v = T_v S_{−s} on every x and s; R_s (1,−i)ᵀ = g^{−s} (1,−i)ᵀ", ok, "; ".join(det))
#   820
#   821      # D6 — cardinal Heisenberg covariance and the expansion
#   822      ok = True
#   823      for p in SHELLS:
#   824          f = frames[p]; n = f.n
#   825          sig = shift(n); D1 = np.diag([f.gpow(k) for k in range(n)]).astype(np.int64)
#   826          Finv = matpow(f.F, 3, p)
#   827          ok &= eq(mm(mm(f.F, sig, p), Finv, p), D1, p)
#   828          ok &= eq(mm(mm(f.F, D1, p), Finv, p), matpow(sig, n - 1, p), p)
#   829          sigs = [sig, D1, matpow(sig, n - 1, p), np.diag([f.gpow(-k) for k in range(n)]).astype(np.int64)]
#   830          for r in range(4):
#   831              ok &= eq(mm(f.Fpow(r), sig, p), mm(sigs[r], f.Fpow(r), p), p)
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:E7 (p06036) [T] — the deciding check D6
# Cardinal Heisenberg covariance: $\Ft\sigma\Ft^{-1}=D_1$, $\Ft D_1\Ft^{-1}=\sigma^{-1}$;
# $\Ft^{r}\sigma=\sigma_r\Ft^{r}$ with $(\sigma,D_1,\sigma^{-1},D_1^{-1})$; the expansion
# \eqref{eq:conj-expansion}; $\Ft^{[s]}\sigma\Ft^{[s]-1}$ monomial exactly at the four cardinal indices and
# non-monomial at every one of the $112$ intermediate indices of $\p\in\{13,17,29,37,41\}$.
from frc_6_fourier import predicate; predicate("6:E7")
# Out:
# — fourier.py:838 (the check that decides 6:E7: D6)
#   838      # 6:E7 (p06036)
#   839      check("D6", "F σ F⁻¹ = D_1, F D_1 F⁻¹ = σ⁻¹; F^r σ = σ_r F^r with (σ, D_1, σ⁻¹, D_1⁻¹); F^[s] = Σ_r c_r(s) F^r, c_r(s) = ¼ Σ_ℓ (g^{rκ−s})^ℓ", ok, f"p ∈ {SHELLS}")
#   840
#   841      # D7 — the monomial sweep
#   842      ok, n_int, n_card, det = True, 0, 0, []
#   843      for p in SHELLS:
#   844          f = frames[p]; n = f.n; k = f.kap
#   845          sig = shift(n)
#   846          mono = []
#   847          for s in range(n):
#   848              Fs = f.frft(s); Fsinv = f.frft(-s)
#   849              mono.append(is_monomial(mm(mm(Fs, sig, p), Fsinv, p)))
#   850          card = {0, k, 2 * k, 3 * k}
#   851          ok &= all(mono[s] for s in card) and all(not mono[s] for s in range(n) if s not in card)
#   [PASS] D6   (deciding)       p ∈ [5, 13, 17, 29, 37, 41]
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F2 (p06038) [T] — the deciding check E1
# $\widehat G^{2}=2n\,X^{\kap}$ in $A$, exact modulo $\Phi_n(X)$; under $\sigma_\C$,
# $(\sum_k\zeta_n^{k^{2}})^{2}=2n\,i$; under $\rho$, $G^{2}=2\im$, the reduction the proof of C7 uses.
from frc_6_fourier import predicate; predicate("6:F2")
# Out:
# block E — the cyclotomic observer readout
#   [PASS] E1   EXACT   [6:F2] Ĝ² = 2n X^κ modulo Φ_n(X) (exact integer arithmetic); under σ_C: (Σ ζ^{k²})² = 2n i; under ρ: G² = 2i in F_p  --  n=4: deg Φ_n = 2; n=12: deg Φ_n = 4; n=16: deg Φ_n = 8; n=28: deg Φ_n = 12; n=36: deg Φ_n = 12; n=40: deg Φ_n = 16
#   [PASS] E2   [approx] [6:F3] H(0) = H(2κ) = 0, H(κ) = H(3κ) = log n for every δ_j  --  n ∈ [4, 12, 16, 28, 36, 40]
#   [PASS] E3   [approx] [6:F3] B_0, B_κ mutually unbiased (overlaps 1/n); H_{B_0} + H_{B_κ} ≥ log n on random states, saturated by δ_j; the comb (δ_0+δ_6)/√2 at n = 12: log 2 + log 6 = log 12  --  comb: H_0 = 0.6931 = log 2, H_κ = 1.7918 = log 6; 200 random states per shell
#   [PASS] E4   [approx] [6:F4] F^[s] δ_0 has the two-valued readout p_0 = 1 − (n−1)t_s/n, p_j = t_s/n, t_s = (2−ζ^{2s}−ζ^{−2s})/4 = sin²(πs/2κ); H(s) the closed form, strictly increasing on [0, κ], period 2κ, strictly intermediate off the cardinal indices  --  n ∈ [4, 12, 16, 28, 36, 40]
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F3 (p06039) [T] — the deciding check E2
# Entropic cardinal values $H(0)=H(2\kap)=0$, $H(\kap)=H(3\kap)=\log n$ for every site-localized input; $B_0$
# and $B_\kap$ mutually unbiased, $H_{B_0}+H_{B_\kap}\ge\log n$ saturated by the localized states and by the
# comb $(\delta_0+\delta_6)/\sqrt2$ at $n=12$, $\log2+\log6=\log12$ [approx].
from frc_6_fourier import predicate; predicate("6:F3")
# Out:
# — fourier.py:985 (the check that decides 6:F3: E2)
#   985      # 6:F3 (p06039)
#   986      check("E2", "H(0) = H(2κ) = 0, H(κ) = H(3κ) = log n for every δ_j", ok, f"n ∈ {[p - 1 for p in SHELLS]}", kind="[approx]")
#   987
#   988      # E3 — mutually unbiased bases, Maassen–Uffink, the comb
#   989      ok, rng = True, np.random.default_rng(6)
#   990      for p in SHELLS:
#   991          n = p - 1; k = n // 4
#   992          D, P, frft = dft_family(n)
#   993          Bk = frft(k)                                                    # the columns of B_κ = F^[κ] B_0
#   994          ok &= np.allclose(np.abs(Bk) ** 2, 1.0 / n)                     # every overlap |<b_0,j|b_κ,l>|² = 1/n
#   995          for _ in range(200):
#   996              psi = rng.normal(size=n) + 1j * rng.normal(size=n); psi /= np.linalg.norm(psi)
#   997              ok &= entropy(psi) + entropy(Bk.conj().T @ psi) >= np.log(n) - 1e-9
#   998          e = delta(n, 0)
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F4 (p06040) [T] — the deciding check E4
# The closed form for $\delta_0$: $p_0=1-\tfrac{n-1}{n}t_s$, $p_{j\neq0}=t_s/n$,
# $t_s=(2-\zeta_n^{2s}-\zeta_n^{-2s})/4$, read as $\sin^{2}(\pi s/2\kap)$; $H(s)$ strictly increasing on
# $[0,\kap]$, two oscillations per cycle, strictly intermediate off the cardinal indices [approx].
from frc_6_fourier import predicate; predicate("6:F4")
# Out:
# — fourier.py:1031 (the check that decides 6:F4: E4)
#  1031      # 6:F4 (p06040)
#  1032      check("E4", "F^[s] δ_0 has the two-valued readout p_0 = 1 − (n−1)t_s/n, p_j = t_s/n, t_s = (2−ζ^{2s}−ζ^{−2s})/4 = sin²(πs/2κ); H(s) the closed form, strictly increasing on [0, κ], period 2κ, strictly intermediate off the cardinal indices",
#  1033            ok, f"n ∈ {[p - 1 for p in SHELLS]}", kind="[approx]")
#  1034
#  1035      # E5 — the p = 13 table and the figure
#  1036      n = 12; H = curves[13]; Hn = H / np.log(n)
#  1037      table = [0, .44, .91, 1, .91, .44, 0, .44, .91, 1, .91, .44]
#  1038      ok = all(abs(round(float(Hn[s]), 2) - table[s]) < 1e-9 for s in range(n))
#  1039      try:
#  1040          import matplotlib
#  1041          matplotlib.use("Agg")
#  1042          import matplotlib.pyplot as plt
#  1043          plt.rcParams.update({"font.family": "serif", "font.size": 11, "mathtext.fontset": "cm", "axes.linewidth": 0.8})
#  1044          s = np.arange(n)
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F5 (p06041) [T] — the deciding check E5
# $\p=13$: $H(s)/\log n=0,\,.44,\,.91,\,1,\,.91,\,.44$ over each half-cycle; Figure~\ref{fig:entropy13}
# regenerated [approx].
from frc_6_fourier import predicate; predicate("6:F5")
# Out:
# — fourier.py:1067 (the check that decides 6:F5: E5)
#  1067      # 6:F5 (p06041)
#  1068      check("E5", "p = 13: H(s)/log n = 0, .44, .91, 1, .91, .44, 0, .44, .91, 1, .91, .44 (fig:entropy13)", ok,
#  1069            "H/log n = " + ", ".join(f"{x:.4f}" for x in Hn) + "; " + figmsg, kind="[approx]")
#  1070
#  1071      # E6 — input dependence
#  1072      D, P, frft = dft_family(12)
#  1073      H1 = np.array([entropy(frft(s) @ delta(12, 1)) for s in range(12)]) / np.log(12)
#  1074      H6 = np.array([entropy(frft(s) @ delta(12, 6)) for s in range(12)]) / np.log(12)
#  1075      ok = abs(round(float(H1[1]), 2) - 0.55) < 1e-9 and abs(round(float(Hn[1]), 2) - 0.44) < 1e-9
#  1076      ok &= np.allclose(H6, Hn) and not np.allclose(H1, Hn)
#  1077      for p in SHELLS:
#  1078          nn = p - 1; kk = nn // 4
#  1079          Dp, Pp, fr = dft_family(nn)
#  1080          for j in range(nn):
# ...

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F6 (p06042) [T] — the deciding check E6
# Input dependence: $\delta_1$ gives $H(1)/\log n=0.55$ against $0.44$ for $\delta_0$; $\delta_j$ meets the
# odd projectors exactly for $j\notin\{0,2\kap\}$, and $\delta_{2\kap}$ reproduces the $\delta_0$ curve
# [approx].
from frc_6_fourier import predicate; predicate("6:F6")
# Out:
# — fourier.py:1083 (the check that decides 6:F6: E6)
#  1083      # 6:F6 (p06042)
#  1084      check("E6", "δ_1 at p = 13: H(1)/log n = 0.55 against 0.44 for δ_0; δ_j meets the odd projectors exactly when j ∉ {0, 2κ}; δ_{2κ} reproduces the δ_0 curve",
#  1085            ok, f"δ_1: H(1)/log n = {H1[1]:.4f}; δ_0: {Hn[1]:.4f}", kind="[approx]")
#  1086
#  1087      # E7 — the Galois twist
#  1088      ok, n_units = True, 0
#  1089      for p in SHELLS:
#  1090          nn = p - 1; kk = nn // 4
#  1091          base = curves[p]
#  1092          D1_, P1_, fr1 = dft_family(nn)
#  1093          for u in range(1, nn):
#  1094              if np.gcd(u, nn) != 1:
#  1095                  continue
#  1096              Du, Pu, fru = dft_family(nn, u); n_units += 1
#   [PASS] E6   (deciding)       δ_1: H(1)/log n = 0.5499; δ_0: 0.4378
# 6:F6: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
# 6:F7 (p06043) [T] — the deciding check E7
# The Galois twist $X\mapsto\zeta_n^{u}$ relabels the $\delta_0$ curve by $s\mapsto us$ for every unit $u$ and
# leaves the cardinal values of every $\delta_j$ invariant; the conjugate twist $u=-1$ relabels the curve of
# every $\delta_j$, while for $j\notin\{0,2\kap\}$ a twist $u\not\equiv\pm1$ changes the intermediate curve
# ($n=12$, $\delta_1$, $u=5$: $0.55\mapsto0.44$ at $s=1$) [approx].
from frc_6_fourier import predicate; predicate("6:F7")
# Out:
# — fourier.py:1109 (the check that decides 6:F7: E7)
#  1109      # 6:F7 (p06043)
#  1110      check("E7", "X ↦ ζ^u relabels the δ_0 curve by s ↦ us on every unit u; the cardinal values of every δ_j are invariant under every twist; u = −1 relabels every δ_j; δ_1 at n = 12 under u = 5: H(1)/log n 0.55 ↦ 0.44",
#  1111            ok, f"{n_units} twists over the six shells; δ_1, u = 5: {h5:.4f}", kind="[approx]")
#  1112
#  1113
#  1114  if __name__ == "__main__":
#  1115      import time
#  1116      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#  1117      bad = [b for b in want if b not in BLOCK]
#  1118      if bad: sys.exit(f"no block {', '.join(bad)}: the blocks are {', '.join(sorted(BLOCK))}")
#  1119      t0 = time.time()
#  1120      for b in want:
#  1121          t = time.time(); _run_block(b); print(f"    [block {b}: {time.time() - t:.1f} s]")
#  1122      ok = summary(write=(want == sorted(BLOCK)))
# ...

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, check by check, is `python3 fourier.py`
# (36 checks, `results.json`; numpy, and matplotlib for the one figure), `python3 -m frc_6_fourier` once installed.

# %%
# !pip install -q frc-6-fourier --find-links https://finitering.space/pkg/
from frc_6_fourier import verify_all
assert verify_all(), "a check failed"
print("all checks pass")
# Out:
# SUMMARY: 36/36 checks passed
# all checks pass

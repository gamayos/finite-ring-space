# %% [markdown]
# ## Geometry and Constants in Finite Ring Continuum, [Akhtman, Symmetry 2026](https://doi.org/10.3390/sym18050751)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Appendix A; [finitering.space/2-geometry/](https://finitering.space/2-geometry/)): it runs the
# blocks of [`geometry.py`](https://finitering.space/src/2-geometry/geometry.html) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 10 s).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:B3 (p02007) [T] — the deciding check A2
# Primitive generators form one orbit: every generator is $\gen^{u}$ with $u\in\Z_{\p-1}^{\times}$, a torsor
# for $\operatorname{Aut}(C_{\p-1})$ (Props.~\ref{prop:primitive-orbit}, \ref{prop:no-canonical-e}).
from frc_2_geometry import predicate; predicate("2:B3")
# Out:
#   [PASS] A1   EXACT  [2:D1, 2:D2, 2:D3, 2:D4] half-period g^pi = -1; i = -g^k of order 4 with i^2 = -1; Q_p = {±1, ±i}; 2pi = -1; e = g^i  --  p=5: g=2, i=3, e=g^i=3, pi=2; p=13: g=2, i=5, e=g^i=6, pi=6; p=17: g=3, i=4, e=g^i=13, pi=8
#   [PASS] A2   EXACT  [2:B3] generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor
#   [PASS] A3   EXACT  [2:D5] orientation classes of the quarter-turn under g -> g^u: kept for u = 1, flipped for u = 3 (mod 4)  --  p=5: 1 of 2 generators keep i; p=13: 2 of 4 generators keep i; p=17: 4 of 8 generators keep i; p=29: 6 of 12 generators keep i; p=37: 6 of 12 generators keep i; p=41: 8 of 16 generators keep i
#   [PASS] A4   EXACT  [2:D6] Euler identity e^{i pi} = (-1)^i with i the residue representative; F13 g=2 odd, F17 g=3 even  --  p=5: i odd for g in [2] (1/2); p=13: i odd for g in [2, 6] (2/4); p=17: i odd for g in [6, 7, 10, 11] (4/8)
#   [PASS] A5   EXACT  [2:D7] R, I commuting involutions; <R,I>-orbits off Q_p have four elements, k-1 of them
#   [PASS] A6   EXACT  [2:D8] conjugation is an involution of the pairs, not of the field (the pair map is p-to-one)
# — geometry.py:185 (the check that decides 2:B3: A2)
#   185      # 2:B3 (p02007)
#   186      check("A2", "generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor", ok)
#   187
#   188      # A3 orientation classes: i' = i iff u ≡ 1 (mod 4), i' = −i iff u ≡ 3 (mod 4) (2:D5)
#   189      ok = True; det = []
#   190      for p, k in SHELLS:
#   191          g = generators(p)[0]; i = quarter_turn(p, g)
#   192          for u in units(p - 1):
#   193              ip = quarter_turn(p, pow(g, u, p))
#   194              ok &= (ip == i) == (u % 4 == 1) and (ip == (-i) % p) == (u % 4 == 3)
#   195          same = sum(1 for u in units(p - 1) if u % 4 == 1)
#   196          det.append(f"p={p}: {same} of {len(generators(p))} generators keep i")
#   197      # 2:D5 (p02017)
#   198      check("A3", "orientation classes of the quarter-turn under g -> g^u: kept for u = 1, flipped for u = 3 (mod 4)", ok, "; ".join(det))
#   [PASS] A2   (deciding)
# 2:B3: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:B4 (p02008) [T] — the deciding check B3
# Cellular automorphisms of the index grid: $m\mapsto\pm m+c$, the dihedral group of the phase cycle; on the
# completion also meridian reversal $a\mapsto\pi-a$, exchanging the poles. The reindexing $\rho_{u}\colon
# m\mapsto um$ preserves latitude adjacency only for $u\equiv\pm1\pmod{\p-1}$; $\sigma$ is not a map of $\Sp$
# ($\north$ one vertex, $L_{\pi}$ has $\p-1$); decided on $\p\le29$.
from frc_2_geometry import predicate; predicate("2:B4")
# Out:
#   [PASS] B1   EXACT  [2:C2] cell counts of S_p and of its completion, chi = 1 and chi = 2 (Remark 3.4)  --  p=5: |V|,|E|,|F| = 9,16,8, chi=1; completion 6,12,8, chi=2; p=13: |V|,|E|,|F| = 73,144,72, chi=1; completion 62,132,72, chi=2; p=17: |V|,|E|,|F| = 129,256,128, chi=1; completion 114,240,128, chi=2; p=29: |V|,|E|,|F| = 393,784,392, chi=1; completion 366,756,392, chi=2
#   [PASS] B2   EXACT  [2:C3] the completion is a closed surface with chi = 2 (a sphere) by exhaustive incidence; S_p has a boundary  --  p=5: completion closed=True, S_p closed=False; p=13: completion closed=True, S_p closed=False; p=17: completion closed=True, S_p closed=False; p=29: completion closed=True, S_p closed=False
#   [PASS] B3   EXACT  [2:B4, 2:C4] rho_u (m -> um) is cellular iff u = ±1; the dihedral maps are; meridian reversal is a map of the completion only  --  p=5: rho_u cellular only for u in [1, 3] of 2 units; p=13: rho_u cellular only for u in [1, 11] of 4 units; p=17: rho_u cellular only for u in [1, 15] of 8 units; p=29: rho_u cellular only for u in [1, 27] of 12 units
# — geometry.py:339 (the check that decides 2:B4: B3)
#   339      # 2:B4 (p02008), 2:C4 (p02012)
#   340      check("B3", "rho_u (m -> um) is cellular iff u = ±1; the dihedral maps are; meridian reversal is a map of the completion only", ok, "; ".join(det))
#   341
#   342  # ------------------------------------------------------------------------------------------------------------
#   343  # block C: the external spherical comparison (2:E2, E3, E4)
#   344  # Section 5 of the paper.  C1 (CHART): the base-grid covering radius of the comparison map Xi_{13,g} against the
#   345  # bound sqrt2·pi/(p−1) of prop:grid-density.  C2 (EXACT, rationals): the fixed-shell scale grid {x/g^n : |x| ≤ 2κ}
#   346  # has a covering radius in [0, 1] bounded below by ½ min(g^−m, 1 − 2κ g^−(m+1)) at every depth — the bounded
#   347  # precision of a fixed shell, prop:fixed-shell-density and thm:operational-precision (C2b: the covering radius
#   348  # exceeds ε = 1/20 on every tested shell).  C3 (CHART): across the tower of shells the grids resolve every target (1:G2).
#   349  def fib_sphere(N):
#   350      pts = []
#   351      ga = math.pi * (3 - math.sqrt(5))
#   352      for j in range(N):
#   [PASS] B3   (deciding)       p=5: rho_u cellular only for u in [1, 3] of 2 units; p=13: rho_u cellular only for u in [1, 11] of 4 units; p=17: rho_u cellular only for u in [1, 15]
# 2:B4: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:C2 (p02010) [T] — the deciding check B1
# Counts: $|V|=\pi(\p-1)+1$, $|E|=2\pi(\p-1)$, $|F|=\pi(\p-1)$, $\chi(\Sp)=1$; the completion has
# $(\pi-1)(\p-1)+2$ vertices, $(2\pi-1)(\p-1)$ edges, $\pi(\p-1)$ faces, $\chi=2$
# (Rem.~\ref{rem:cell-counts}).
from frc_2_geometry import predicate; predicate("2:C2")
# Out:
# — geometry.py:306 (the check that decides 2:C2: B1)
#   306      # 2:C2 (p02010)
#   307      check("B1", "cell counts of S_p and of its completion, chi = 1 and chi = 2 (Remark 3.4)", ok, "; ".join(det))
#   308
#   309      # B2 the completion is a closed surface (chi = 2, a sphere); S_p itself is not closed (2:C3)
#   310      ok = True; det = []
#   311      for p in B_SHELLS:
#   312          V, E, F, Vc, Ec, Fc = shell(p)
#   313          closed = closed_surface(Vc, Ec, Fc)
#   314          ok &= closed and not closed_surface(V, E, F)
#   315          det.append(f"p={p}: completion closed={closed}, S_p closed=False")
#   316      # 2:C3 (p02011)
#   317      check("B2", "the completion is a closed surface with chi = 2 (a sphere) by exhaustive incidence; S_p has a boundary", ok, "; ".join(det))
#   318
#   319      # B3 cellular automorphisms: rho_u iff u = ±1; the dihedral maps; meridian reversal on the completion only (2:B4, 2:C4)
#   [PASS] B1   (deciding)       p=5: |V|,|E|,|F| = 9,16,8, chi=1; completion 6,12,8, chi=2; p=13: |V|,|E|,|F| = 73,144,72, chi=1; completion 62,132,72, chi=2; p=17: |V|,|E|,|F| = 129
# 2:C2: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:C3 (p02011) [T] — the deciding check B2
# Canonical spherical completion: collapsing $L_{\pi}$ to $\south$ gives a closed orientable surface --- every
# edge in two faces, every vertex link a cycle --- with $\chi=2$, hence $S^{2}$ (A3), on every shell
# (Thm.~\ref{thm:combinatorial-sphere}; decided on $\p\in\{5,13,17,29\}$ by exhaustive incidence).
from frc_2_geometry import predicate; predicate("2:C3")
# Out:
# — geometry.py:316 (the check that decides 2:C3: B2)
#   316      # 2:C3 (p02011)
#   317      check("B2", "the completion is a closed surface with chi = 2 (a sphere) by exhaustive incidence; S_p has a boundary", ok, "; ".join(det))
#   318
#   319      # B3 cellular automorphisms: rho_u iff u = ±1; the dihedral maps; meridian reversal on the completion only (2:B4, 2:C4)
#   320      ok = True; det = []
#   321      for p in B_SHELLS:
#   322          k = (p - 1) // 4; pi = 2 * k; n = p - 1
#   323          V, E, F, Vc, Ec, Fc = shell(p)
#   324          faces = lambda FF, f: sorted(Counter(tuple(sorted(map(str, map(f, x)))) for x in FF).items())
#   325          cellular = lambda f, EE, FF: {frozenset(map(f, e)) for e in EE} == EE and faces(FF, f) == faces(FF, lambda v: v)
#   326          good = []
#   327          for u in units(n):
#   328              rho = lambda v: v if v in ("N", "S") else (v[0], v[1] * u % n)
#   329              if cellular(rho, E, F): good.append(u)
#   [PASS] B2   (deciding)       p=5: completion closed=True, S_p closed=False; p=13: completion closed=True, S_p closed=False; p=17: completion closed=True, S_p closed=False; p=29: c
# 2:C3: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:C4 (p02012) [T] — the deciding check B3
# Frame covariance: $\Sp$ is one complex for every generator --- the index grid $I_{\p}\times\Phi_{\p}$ with
# its step relations; the frame $\gen'=\gen^{u}$ moves the field labels, $a\gen^{m}\mapsto a\gen^{um}$, by the
# automorphism $\rho_{u}$ of $\Phi_{\p}$, not the cells. The map $\varphi_{u}$ of
# Prop.~\ref{prop:shell-covariance} is cellular only for $u\equiv\pm1$.
from frc_2_geometry import predicate; predicate("2:C4")
# Out:
# — geometry.py:339 (the check that decides 2:C4: B3)
#   339      # 2:B4 (p02008), 2:C4 (p02012)
#   340      check("B3", "rho_u (m -> um) is cellular iff u = ±1; the dihedral maps are; meridian reversal is a map of the completion only", ok, "; ".join(det))
#   341
#   342  # ------------------------------------------------------------------------------------------------------------
#   343  # block C: the external spherical comparison (2:E2, E3, E4)
#   344  # Section 5 of the paper.  C1 (CHART): the base-grid covering radius of the comparison map Xi_{13,g} against the
#   345  # bound sqrt2·pi/(p−1) of prop:grid-density.  C2 (EXACT, rationals): the fixed-shell scale grid {x/g^n : |x| ≤ 2κ}
#   346  # has a covering radius in [0, 1] bounded below by ½ min(g^−m, 1 − 2κ g^−(m+1)) at every depth — the bounded
#   347  # precision of a fixed shell, prop:fixed-shell-density and thm:operational-precision (C2b: the covering radius
#   348  # exceeds ε = 1/20 on every tested shell).  C3 (CHART): across the tower of shells the grids resolve every target (1:G2).
#   349  def fib_sphere(N):
#   350      pts = []
#   351      ga = math.pi * (3 - math.sqrt(5))
#   352      for j in range(N):
#   [PASS] B3   (deciding)       p=5: rho_u cellular only for u in [1, 3] of 2 units; p=13: rho_u cellular only for u in [1, 11] of 4 units; p=17: rho_u cellular only for u in [1, 15]
# 2:C4: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D1 (p02013) [T] — the deciding check A1
# The half-period: $\gen^{\pi}=-1$ for every primitive $\gen$, $\pi=2\kap$ (Prop.~\ref{prop:half-period});
# $2\pi\equiv-1$ (00:C1).
from frc_2_geometry import predicate; predicate("2:D1")
# Out:
# — geometry.py:176 (the check that decides 2:D1: A1)
#   176      # 2:D1 (p02013), 2:D2 (p02014), 2:D3 (p02015), 2:D4 (p02016)
#   177      check("A1", "half-period g^pi = -1; i = -g^k of order 4 with i^2 = -1; Q_p = {±1, ±i}; 2pi = -1; e = g^i", ok, "; ".join(det[:3]))
#   178
#   179      # A2 the primitive generators form one orbit g^u, u a unit mod p−1 (2:B3)
#   180      ok = True
#   181      for p, k in SHELLS:
#   182          gens = set(generators(p)); g = min(gens)
#   183          orbit = {pow(g, u, p) for u in units(p - 1)}
#   184          ok &= orbit == gens and len(gens) == len(units(p - 1))
#   185      # 2:B3 (p02007)
#   186      check("A2", "generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor", ok)
#   187
#   188      # A3 orientation classes: i' = i iff u ≡ 1 (mod 4), i' = −i iff u ≡ 3 (mod 4) (2:D5)
#   189      ok = True; det = []
#   [PASS] A1   (deciding)       p=5: g=2, i=3, e=g^i=3, pi=2; p=13: g=2, i=5, e=g^i=6, pi=6; p=17: g=3, i=4, e=g^i=13, pi=8
# 2:D1: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D2 (p02014) [T] — the deciding check A1
# The quarter-turn subgroup $\Qp=\{x:x^{4}=1\}$ is the unique subgroup of order four; $\gen^{\kap}$ has order
# four with $(\gen^{\kap})^{2}=-1$; $\Qp=\{\pm1,\pm\It\}$ (Def.~\ref{def:quarter-turn-subgroup},
# Prop.~\ref{prop:quarter-turn}; 1:B2).
from frc_2_geometry import predicate; predicate("2:D2")
# Out:
# — geometry.py:176 (the check that decides 2:D2: A1)
#   176      # 2:D1 (p02013), 2:D2 (p02014), 2:D3 (p02015), 2:D4 (p02016)
#   177      check("A1", "half-period g^pi = -1; i = -g^k of order 4 with i^2 = -1; Q_p = {±1, ±i}; 2pi = -1; e = g^i", ok, "; ".join(det[:3]))
#   178
#   179      # A2 the primitive generators form one orbit g^u, u a unit mod p−1 (2:B3)
#   180      ok = True
#   181      for p, k in SHELLS:
#   182          gens = set(generators(p)); g = min(gens)
#   183          orbit = {pow(g, u, p) for u in units(p - 1)}
#   184          ok &= orbit == gens and len(gens) == len(units(p - 1))
#   185      # 2:B3 (p02007)
#   186      check("A2", "generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor", ok)
#   187
#   188      # A3 orientation classes: i' = i iff u ≡ 1 (mod 4), i' = −i iff u ≡ 3 (mod 4) (2:D5)
#   189      ok = True; det = []
#   [PASS] A1   (deciding)       p=5: g=2, i=3, e=g^i=3, pi=2; p=13: g=2, i=5, e=g^i=6, pi=6; p=17: g=3, i=4, e=g^i=13, pi=8
# 2:D2: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D3 (p02015) [D] — the deciding check A1
# The oriented quarter-turn $\It=-\gen^{\kap}=\gen^{-\kap}$, $\It^{2}=-1$, orientation by A2
# (Rem.~\ref{rem:observer-canonical-e}); on $\F_{13}(\chron;0,1,2)$: $\It=5$, $-\It=8$, $\pi=6$ [value]
# (Fig.~\ref{fig:f13-constant-datum}).
from frc_2_geometry import predicate; predicate("2:D3")
# Out:
# — geometry.py:176 (the check that decides 2:D3: A1)
#   176      # 2:D1 (p02013), 2:D2 (p02014), 2:D3 (p02015), 2:D4 (p02016)
#   177      check("A1", "half-period g^pi = -1; i = -g^k of order 4 with i^2 = -1; Q_p = {±1, ±i}; 2pi = -1; e = g^i", ok, "; ".join(det[:3]))
#   178
#   179      # A2 the primitive generators form one orbit g^u, u a unit mod p−1 (2:B3)
#   180      ok = True
#   181      for p, k in SHELLS:
#   182          gens = set(generators(p)); g = min(gens)
#   183          orbit = {pow(g, u, p) for u in units(p - 1)}
#   184          ok &= orbit == gens and len(gens) == len(units(p - 1))
#   185      # 2:B3 (p02007)
#   186      check("A2", "generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor", ok)
#   187
#   188      # A3 orientation classes: i' = i iff u ≡ 1 (mod 4), i' = −i iff u ≡ 3 (mod 4) (2:D5)
#   189      ok = True; det = []
#   [PASS] A1   (deciding)       p=5: g=2, i=3, e=g^i=3, pi=2; p=13: g=2, i=5, e=g^i=6, pi=6; p=17: g=3, i=4, e=g^i=13, pi=8
# 2:D3: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D4 (p02016) [D] — the deciding check A1
# The exponential unit $\eu:=\gen^{\It}$, $\It$ read as an exponent in $\Phi_{\p}$ through its residue
# representative; derived, generator-dependent (Rem.~\ref{rem:exponential-unit}; 00:C1, convention~3); on
# $\F_{13}$, $\eu=6=\pi$ [value].
from frc_2_geometry import predicate; predicate("2:D4")
# Out:
# — geometry.py:176 (the check that decides 2:D4: A1)
#   176      # 2:D1 (p02013), 2:D2 (p02014), 2:D3 (p02015), 2:D4 (p02016)
#   177      check("A1", "half-period g^pi = -1; i = -g^k of order 4 with i^2 = -1; Q_p = {±1, ±i}; 2pi = -1; e = g^i", ok, "; ".join(det[:3]))
#   178
#   179      # A2 the primitive generators form one orbit g^u, u a unit mod p−1 (2:B3)
#   180      ok = True
#   181      for p, k in SHELLS:
#   182          gens = set(generators(p)); g = min(gens)
#   183          orbit = {pow(g, u, p) for u in units(p - 1)}
#   184          ok &= orbit == gens and len(gens) == len(units(p - 1))
#   185      # 2:B3 (p02007)
#   186      check("A2", "generators = {g^u : gcd(u, p-1) = 1}, one Aut(C_{p-1})-torsor", ok)
#   187
#   188      # A3 orientation classes: i' = i iff u ≡ 1 (mod 4), i' = −i iff u ≡ 3 (mod 4) (2:D5)
#   189      ok = True; det = []
#   [PASS] A1   (deciding)       p=5: g=2, i=3, e=g^i=3, pi=2; p=13: g=2, i=5, e=g^i=6, pi=6; p=17: g=3, i=4, e=g^i=13, pi=8
# 2:D4: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D5 (p02017) [T] — the deciding check A3
# Orientation classes: for $\gen'=\gen^{u}$, $\It'=-\gen'^{\kap}$ equals $\It$ when $u\equiv1\pmod4$ and
# $-\It$ when $u\equiv3\pmod4$; the oriented quarter-turn is frame-covariant within one class of generators,
# not under every generator change.
from frc_2_geometry import predicate; predicate("2:D5")
# Out:
# — geometry.py:197 (the check that decides 2:D5: A3)
#   197      # 2:D5 (p02017)
#   198      check("A3", "orientation classes of the quarter-turn under g -> g^u: kept for u = 1, flipped for u = 3 (mod 4)", ok, "; ".join(det))
#   199
#   200      # A4 the Euler identity e^{iπ} = g^{2κ i²} = (−1)^i, −1 iff the residue i is odd (2:D6, 00:C14)
#   201      ok = True; det = []
#   202      for p, k in SHELLS:
#   203          for g in generators(p):
#   204              i = quarter_turn(p, g); e = pow(g, i, p)
#   205              ok &= pow(e, i * 2 * k, p) == (p - 1 if i % 2 else 1)
#   206          odd = [g for g in generators(p) if quarter_turn(p, g) % 2 == 1]
#   207          det.append(f"p={p}: i odd for g in {odd[:6]}{'...' if len(odd) > 6 else ''} ({len(odd)}/{len(generators(p))})")
#   208      ok &= quarter_turn(13, 2) == 5 and quarter_turn(17, 3) == 4 and quarter_turn(17, 6) == 13
#   209      # 2:D6 (p02018)
#   210      check("A4", "Euler identity e^{i pi} = (-1)^i with i the residue representative; F13 g=2 odd, F17 g=3 even", ok, "; ".join(det[:3]))
#   [PASS] A3   (deciding)       p=5: 1 of 2 generators keep i; p=13: 2 of 4 generators keep i; p=17: 4 of 8 generators keep i; p=29: 6 of 12 generators keep i; p=37: 6 of 12 generato
# 2:D5: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D6 (p02018) [T] — the deciding check A4
# The Euler identity on the shell: $\eu^{\It\pi}=\gen^{2\kap\It^{2}}=(-1)^{\It}$, equal to $-1$ exactly when
# the representative of $\It$ is odd (00:C14); the oriented frames of a shell are those with $-\gen^{\kap}$
# odd --- on $\F_{13}$, $\gen=2$ ($\It=5$) is one, on $\F_{17}$, $\gen=3$ ($\It=4$) is not.
from frc_2_geometry import predicate; predicate("2:D6")
# Out:
# — geometry.py:209 (the check that decides 2:D6: A4)
#   209      # 2:D6 (p02018)
#   210      check("A4", "Euler identity e^{i pi} = (-1)^i with i the residue representative; F13 g=2 odd, F17 g=3 even", ok, "; ".join(det[:3]))
#   211
#   212      # A5 negation/inversion orbits: F_p^x \ Q_p splits into κ−1 orbits of size four (2:D7, 1:B2)
#   213      ok = True
#   214      for p, k in SHELLS:
#   215          Q = {x for x in range(1, p) if pow(x, 4, p) == 1}
#   216          seen, orbits = set(), 0
#   217          for x in range(1, p):
#   218              if x in Q or x in seen: continue
#   219              orb = {x, (-x) % p, pow(x, -1, p), (-pow(x, -1, p)) % p}
#   220              ok &= len(orb) == 4; seen |= orb; orbits += 1
#   221          ok &= len(Q) == 4 and orbits == k - 1
#   222          R = lambda x: (-x) % p; I = lambda x: pow(x, -1, p)
#   [PASS] A4   (deciding)       p=5: i odd for g in [2] (1/2); p=13: i odd for g in [2, 6] (2/4); p=17: i odd for g in [6, 7, 10, 11] (4/8)
# 2:D6: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D7 (p02019) [T] — the deciding check A5
# Negation $R(x)=-x$ and inversion $I(x)=x^{-1}$ are commuting involutions; off $\Qp$ the $\langle
# R,I\rangle$-orbit $\{x,-x,x^{-1},-x^{-1}\}$ has four elements, and $\Fpx\setminus\Qp$ splits into $\kap-1$
# such orbits (Props.~\ref{prop:shell-negation}, \ref{prop:k4-shell}; 1:B2).
from frc_2_geometry import predicate; predicate("2:D7")
# Out:
# — geometry.py:224 (the check that decides 2:D7: A5)
#   224      # 2:D7 (p02019)
#   225      check("A5", "R, I commuting involutions; <R,I>-orbits off Q_p have four elements, k-1 of them", ok)
#   226
#   227      # A6 Euclidean conjugation: an involution of pairs; the pair map (a, b) -> a + b i is p-to-one (2:D8)
#   228      ok = True
#   229      for p, k in SHELLS:
#   230          g = generators(p)[0]; i = quarter_turn(p, g)
#   231          fibres = Counter((a + b * i) % p for a in range(p) for b in range(p))
#   232          ok &= set(fibres.values()) == {p} and len(fibres) == p
#   233          C = lambda a, b: (a, (-b) % p)
#   234          ok &= all(C(*C(a, b)) == (a, b) for a in range(p) for b in range(p))
#   235          a, b = 0, 1; a2, b2 = i, 0        # 0 + 1·i = i + 0·i, but the conjugates differ: not a map of the field
#   236          ok &= (a + b * i) % p == (a2 + b2 * i) % p and (a - b * i) % p != (a2 - b2 * i) % p
#   237      # 2:D8 (p02020)
#   [PASS] A5   (deciding)
# 2:D7: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:D8 (p02020) [D] — the deciding check A6
# Euclidean conjugation $C_{\gen}\colon(a,b)\mapsto(a,-b)$ is an involution of the coordinate pairs $\Fp^{2}$;
# on the shell $a+b\It$ is a field element and the pair map $\Fp^{2}\to\Fp$ is $\p$-to-one (1:E2), so
# $C_{\gen}$ is a chart-level involution, not a field automorphism.
from frc_2_geometry import predicate; predicate("2:D8")
# Out:
# — geometry.py:237 (the check that decides 2:D8: A6)
#   237      # 2:D8 (p02020)
#   238      check("A6", "conjugation is an involution of the pairs, not of the field (the pair map is p-to-one)", ok)
#   239
#   240  # ------------------------------------------------------------------------------------------------------------
#   241  # block B: the orbital shell and its spherical completion (2:B4, C2, C3, C4)
#   242  # Section 3 of the paper: the complex S_p of def:orbital-shell coded as vertices, edges and faces; the
#   243  # completion (the terminal latitude collapsed to S); the counts of rem:cell-counts (B1); closedness — every edge
#   244  # in two faces, every vertex link one cycle — of thm:combinatorial-sphere, exhaustive on p ∈ {5, 13, 17, 29} (B2);
#   245  # the cellular automorphisms: the reindexing ρ_u is cellular only for u = ±1, the dihedral maps are, the meridian
#   246  # reversal is a map of the completion only (prop:phase-frame-change, prop:shell-covariance; B3).
#   247  B_SHELLS = (5, 13, 17, 29)                    # the shells of block B (the package's SHELLS carry κ)
#   248
#   249  def shell(p):
#   250      """The orbital shell S_p of Def. 3.1: vertices, edges, faces; and its completion."""
#   [PASS] A6   (deciding)
# 2:D8: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:E2 (p02022) [T] — the deciding check C1
# Base-grid estimate [chart]: every point of $S^{2}$ lies within geodesic distance $\sqrt2\,\pi_{\R}/(\p-1)$
# of $\Xi_{\p,\gen}(V(\Sp))$; measured covering radius $0.360$ at $\p=13$ against the bound $0.370$
# (Prop.~\ref{prop:grid-density}).
from frc_2_geometry import predicate; predicate("2:E2")
# Out:
#   [PASS] C1   CHART  [2:E2] base-grid covering radius at p = 13 within the bound sqrt2 pi/(p-1)  --  measured 0.3604 rad, bound 0.3702 rad
#   [PASS] C2   EXACT  [2:E3] fixed-shell covering radius stabilises at >= 1/2 min(g^-m, 1 - H g^-(m+1)) for every depth (H = 2k and H = p-1)  --  (13,2): radius 1/8 >= 1/8; (13,11): radius 5/22 >= 5/22; (13,6): radius 1/12 >= 1/12; (17,3): radius 1/18 >= 1/18
#   [PASS] C2b  EXACT  [2:E3] fixed-shell density at eps = 1/20: the covering radius exceeds 1/20 on every tested shell  --  shells with covering radius > 1/20 at N = 40: [(13, 2), (13, 11), (17, 3), (29, 2)]
#   [PASS] C3   CHART  [2:E4] the tower of shells (p = 13..4093, g = 2) brings every target within 1/2048; the single shell (13, 2) does not  --  tower errors 9.77e-05, 8.14e-05, 2.42e-04, 9.31e-05; single shell 0.100, 0.021, 0.035, 0.039
# — geometry.py:392 (the check that decides 2:E2: C1)
#   392      # 2:E2 (p02022)
#   393      check("C1", "base-grid covering radius at p = 13 within the bound sqrt2 pi/(p-1)", cov <= bound,
#   394               f"measured {cov:.4f} rad, bound {bound:.4f} rad", kind="CHART")
#   395
#   396      # C2 the fixed-shell refinement is bounded (2:E3) — exact rationals
#   397      ok = True; det = []
#   398      for p, g in [(13, 2), (13, 11), (13, 6), (17, 3), (29, 2), (173, 2)]:
#   399          radii = [fixed_shell_radius(p, g, N) for N in (3, 6, 12, 24)]
#   400          lb = lower_bound(p, g)
#   401          radii_p = [fixed_shell_radius(p, g, N, p - 1) for N in (12, 24)]; lb_p = lower_bound(p, g, p - 1)
#   402          ok &= all(r >= lb for r in radii) and radii[-1] == radii[-2] and all(r >= lb_p for r in radii_p) and radii_p[0] == radii_p[1]
#   403          det.append(f"({p},{g}): radius {radii[-1]} >= {lb}")
#   404      # 2:E3 (p02023)
#   405      check("C2", "fixed-shell covering radius stabilises at >= 1/2 min(g^-m, 1 - H g^-(m+1)) for every depth (H = 2k and H = p-1)", ok, "; ".join(det[:4]))
#   [PASS] C1   (deciding)       measured 0.3604 rad, bound 0.3702 rad
# 2:E2: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:E3 (p02023) [T] — the deciding check C2
# Fixed-shell refinement is bounded: with $m=\lfloor\log_{\gen}(2\kap+1)\rfloor$ no point $x/\gen^{n}$,
# $|x|\le2\kap$, lies in $(\max(1-\gen^{-m},2\kap\gen^{-m-1}),1)$ at any depth, so the covering radius of the
# scale grid in $[0,1]$ is $\ge\tfrac12\min(\gen^{-m},1-2\kap\gen^{-m-1})$ for every $N$: $1/8$ at $(13,2)$,
# $5/22$ at $(13,11)$.
from frc_2_geometry import predicate; predicate("2:E3")
# Out:
# — geometry.py:404 (the check that decides 2:E3: C2)
#   404      # 2:E3 (p02023)
#   405      check("C2", "fixed-shell covering radius stabilises at >= 1/2 min(g^-m, 1 - H g^-(m+1)) for every depth (H = 2k and H = p-1)", ok, "; ".join(det[:4]))
#   406      eps = Fraction(1, 20)
#   407      viol = [(p, g) for p, g in [(13, 2), (13, 11), (17, 3), (29, 2)] if fixed_shell_radius(p, g, 40) > eps]
#   408      check("C2b", "fixed-shell density at eps = 1/20: the covering radius exceeds 1/20 on every tested shell", viol == [(13, 2), (13, 11), (17, 3), (29, 2)],
#   409               f"shells with covering radius > 1/20 at N = 40: {viol}")
#   410
#   411      # C3 the tower of shells resolves every target (2:E4, 1:G2) — chart
#   412      targets = [0.9, 1 / 3, math.pi / 4, math.sqrt(2) - 1]
#   413      tower = [(p, 2) for p in (13, 29, 173, 1013, 4093)]
#   414      errs = [tower_best(t, tower) for t in targets]
#   415      single = [tower_best(t, [(13, 2)]) for t in targets]
#   416      # 2:E4 (p02024)
#   417      check("C3", "the tower of shells (p = 13..4093, g = 2) brings every target within 1/2048; the single shell (13, 2) does not",
#   [PASS] C2   (deciding)       (13,2): radius 1/8 >= 1/8; (13,11): radius 5/22 >= 5/22; (13,6): radius 1/12 >= 1/12; (17,3): radius 1/18 >= 1/18
#   [PASS] C2b  (corroborating)  shells with covering radius > 1/20 at N = 40: [(13, 2), (13, 11), (17, 3), (29, 2)]
# 2:E3: VERIFIED — 2 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:E4 (p02024) [T] — the deciding check C3
# Finite precision across the tower [chart]: for every $L$-bounded observable family, $\varepsilon>0$ and
# configuration on $(S^{2})^{r}$ some shell $\p$ carries grid points within $\varepsilon$ (1:G2 with the path
# bound of E2); on one shell the precision is bounded by E3.
from frc_2_geometry import predicate; predicate("2:E4")
# Out:
# — geometry.py:416 (the check that decides 2:E4: C3)
#   416      # 2:E4 (p02024)
#   417      check("C3", "the tower of shells (p = 13..4093, g = 2) brings every target within 1/2048; the single shell (13, 2) does not",
#   418               all(e <= 1 / 2048 for e in errs) and max(single) > 1 / 16,
#   419               "tower errors " + ", ".join(f"{e:.2e}" for e in errs) + "; single shell " + ", ".join(f"{e:.3f}" for e in single), kind="CHART")
#   420
#   421  # ------------------------------------------------------------------------------------------------------------
#   422  # block D: Fourier duality on the phase cycle (2:F1, F3, F4, F5, F6)
#   423  # Section 6 of the paper, on (13, 2), (13, 11), (17, 3), (29, 2): the principal root (prop:principal-root, D1);
#   424  # the inversion W^−1 = −(g^−jk) (prop:ring-dft-inverse, D2); the polynomial reading F(v)_k = P_v(g^k)
#   425  # (prop:polynomial-form, D3); the covariance under g → g^u (prop:ring-dft-covariance, D4); and the external
#   426  # transport chi(g^m) = exp(−2 pi i m/n) with its step, half-period and quarter-turn identities
#   427  # (prop:datum-role-transport, D5; CHART).
#   428  FRAMES = [(13, 2), (13, 11), (17, 3), (29, 2)]
#   429
#   [PASS] C3   (deciding)       tower errors 9.77e-05, 8.14e-05, 2.42e-04, 9.31e-05; single shell 0.100, 0.021, 0.035, 0.039
# 2:E4: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:F1 (p02025) [T] — the deciding check D1
# $\gen$ is a principal $n$-th root of unity, $n=\p-1$: $\gen^{n}=1$, $\sum_{j<n}\gen^{jk}=0$ for $0<k<n$, and
# $n^{-1}=-1$ in $\Fp$ (Prop.~\ref{prop:principal-root}; $2\pi\equiv-1$).
from frc_2_geometry import predicate; predicate("2:F1")
# Out:
#   [PASS] D1   EXACT  [2:F1] g a principal root: g^n = 1, sum_j g^{jk} = 0 for 0 < k < n, n^-1 = -1
#   [PASS] D2   EXACT  [2:F3] inversion W^-1 = -(g^{-jk}) on (13, 2), (13, 11), (17, 3), (29, 2)
#   [PASS] D3   EXACT  [2:F4] polynomial reading F(v)_k = P_v(g^k)
#   [PASS] D4   EXACT  [2:F5] covariance F_{g^u}(v') = F_g(v) with v'_j = v_{uj}
#   [PASS] D5   CHART  [2:F6] external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn
# — geometry.py:460 (the check that decides 2:F1: D1)
#   460      # 2:F1 (p02025)
#   461      check("D1", "g a principal root: g^n = 1, sum_j g^{jk} = 0 for 0 < k < n, n^-1 = -1", ok[0])
#   462      # 2:F3 (p02027)
#   463      check("D2", "inversion W^-1 = -(g^{-jk}) on (13, 2), (13, 11), (17, 3), (29, 2)", ok[1])
#   464      # 2:F4 (p02028)
#   465      check("D3", "polynomial reading F(v)_k = P_v(g^k)", ok[2])
#   466      # 2:F5 (p02029)
#   467      check("D4", "covariance F_{g^u}(v') = F_g(v) with v'_j = v_{uj}", ok[3])
#   468      # 2:F6 (p02030)
#   469      check("D5", "external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn", ok[4], kind="CHART")
#   470
#   471  if __name__ == "__main__":
#   472      import time
#   473      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#   [PASS] D1   (deciding)
# 2:F1: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:F3 (p02027) [T] — the deciding check D2
# Inversion: $v_{j}=-\sum_{k<n}\mathcal F_{\gen}(v)_{k}\gen^{-jk}$, i.e.\
# $W_{\gen}^{-1}=-(\gen^{-jk})_{jk}=-W_{\gen}J$ (Prop.~\ref{prop:ring-dft-inverse}; 6:B5), exact on every
# shell.
from frc_2_geometry import predicate; predicate("2:F3")
# Out:
# — geometry.py:462 (the check that decides 2:F3: D2)
#   462      # 2:F3 (p02027)
#   463      check("D2", "inversion W^-1 = -(g^{-jk}) on (13, 2), (13, 11), (17, 3), (29, 2)", ok[1])
#   464      # 2:F4 (p02028)
#   465      check("D3", "polynomial reading F(v)_k = P_v(g^k)", ok[2])
#   466      # 2:F5 (p02029)
#   467      check("D4", "covariance F_{g^u}(v') = F_g(v) with v'_j = v_{uj}", ok[3])
#   468      # 2:F6 (p02030)
#   469      check("D5", "external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn", ok[4], kind="CHART")
#   470
#   471  if __name__ == "__main__":
#   472      import time
#   473      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#   474      bad = [b for b in want if b not in BLOCK]
#   475      if bad: sys.exit(f"no block {', '.join(bad)}: the blocks are {', '.join(sorted(BLOCK))}")
#   [PASS] D2   (deciding)
# 2:F3: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:F4 (p02028) [T] — the deciding check D3
# Polynomial reading: $\mathcal F_{\gen}(v)_{k}=P_{v}(\gen^{k})$ with $P_{v}=\sum_{j}v_{j}X^{j}$; the
# transform exchanges coefficients with values on the phase cycle (Prop.~\ref{prop:polynomial-form}).
from frc_2_geometry import predicate; predicate("2:F4")
# Out:
# — geometry.py:464 (the check that decides 2:F4: D3)
#   464      # 2:F4 (p02028)
#   465      check("D3", "polynomial reading F(v)_k = P_v(g^k)", ok[2])
#   466      # 2:F5 (p02029)
#   467      check("D4", "covariance F_{g^u}(v') = F_g(v) with v'_j = v_{uj}", ok[3])
#   468      # 2:F6 (p02030)
#   469      check("D5", "external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn", ok[4], kind="CHART")
#   470
#   471  if __name__ == "__main__":
#   472      import time
#   473      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#   474      bad = [b for b in want if b not in BLOCK]
#   475      if bad: sys.exit(f"no block {', '.join(bad)}: the blocks are {', '.join(sorted(BLOCK))}")
#   476      t0 = time.time()
#   477      for b in want:
#   [PASS] D3   (deciding)
# 2:F4: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:F5 (p02029) [T] — the deciding check D4
# Covariance under generator change: for $\gen'=\gen^{u}$, $v^{(\gen')}_{j}=v^{(\gen)}_{uj}$ and $\mathcal
# F_{\gen'}(v^{(\gen')})=\mathcal F_{\gen}(v^{(\gen)})$ (Prop.~\ref{prop:ring-dft-covariance}).
from frc_2_geometry import predicate; predicate("2:F5")
# Out:
# — geometry.py:466 (the check that decides 2:F5: D4)
#   466      # 2:F5 (p02029)
#   467      check("D4", "covariance F_{g^u}(v') = F_g(v) with v'_j = v_{uj}", ok[3])
#   468      # 2:F6 (p02030)
#   469      check("D5", "external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn", ok[4], kind="CHART")
#   470
#   471  if __name__ == "__main__":
#   472      import time
#   473      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#   474      bad = [b for b in want if b not in BLOCK]
#   475      if bad: sys.exit(f"no block {', '.join(bad)}: the blocks are {', '.join(sorted(BLOCK))}")
#   476      t0 = time.time()
#   477      for b in want:
#   478          t = time.time(); _run_block(b); print(f"    [block {b}: {time.time() - t:.1f} s]")
#   479      ok = summary(write=(want == sorted(BLOCK)))
#   [PASS] D4   (deciding)
# 2:F5: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
# 2:F6 (p02030) [T] — the deciding check D5
# Exact external transport [chart]: $\chi(\gen^{m})=e^{-2\pi_{\R}\It m/n}$ is an isomorphism of $\Fpx$ onto
# the complex $n$-th roots of unity with $\chi(\gen^{m+1})=e^{-2\pi_{\R}\It/n}\chi(\gen^{m})$,
# $\chi(\gen^{m+\pi})=-\chi(\gen^{m})$, $\chi(\It\gen^{m})=\It\,\chi(\gen^{m})$,
# $\chi(\gen^{jr})=e^{-2\pi_{\R}\It jr/n}$ (Prop.~\ref{prop:datum-role-transport}).
from frc_2_geometry import predicate; predicate("2:F6")
# Out:
# — geometry.py:468 (the check that decides 2:F6: D5)
#   468      # 2:F6 (p02030)
#   469      check("D5", "external transport chi(g^m) = exp(-2 pi i m/n), injective: step, half-period, quarter-turn", ok[4], kind="CHART")
#   470
#   471  if __name__ == "__main__":
#   472      import time
#   473      want = [a.upper() for a in sys.argv[1:]] or sorted(BLOCK)
#   474      bad = [b for b in want if b not in BLOCK]
#   475      if bad: sys.exit(f"no block {', '.join(bad)}: the blocks are {', '.join(sorted(BLOCK))}")
#   476      t0 = time.time()
#   477      for b in want:
#   478          t = time.time(); _run_block(b); print(f"    [block {b}: {time.time() - t:.1f} s]")
#   479      ok = summary(write=(want == sorted(BLOCK)))
#   480      kinds = {}
#   481      for r in RESULTS: kinds[r["kind"]] = kinds.get(r["kind"], 0) + 1
#   [PASS] D5   (deciding)
# 2:F6: VERIFIED — 1 record(s)

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, check by check, is `python3 geometry.py`
# (18 checks, `results.json`), `python3 -m frc_2_geometry` once installed.

# %%
# !pip install -q frc-2-geometry --find-links https://finitering.space/pkg/
from frc_2_geometry import verify_all
assert verify_all(), "a check failed"
print("all checks pass")
# Out:
# SUMMARY: 18/18 checks passed
# all checks pass

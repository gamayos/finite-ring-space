# %% [markdown]
# ## De Sitter Entropy Estimates over Finite Holographic Substrate, [Akhtman & Voether, Preprints 2026](https://doi.org/10.20944/preprints202608.0310.v1)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Section 5.3; [finitering.space/14-entropy/](https://finitering.space/14-entropy/)): it runs the
# blocks of [`entropy.py`](https://finitering.space/src/14-entropy/entropy.html) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 5 s).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:A2 (p14002) [I] — the deciding family est.F1
# The Carrier congruences, relations certified by the realisations (the $c$-square $\dS$ even, the triality
# centre $\dS\equiv1\pmod3$, completeness $4\dS+1$ prime); instantiated on the laboratory Carrier as
# host-decided values.
from frc_14_entropy import predicate; predicate("14:A2")
# Out:
# exact faces (counts): Om = 4S+1; S even; S = 1 mod 3; 4S+1 prime
#   [PASS] Om = 4S+1  (lab Carrier Om=2408561)
#   [PASS] S even (octant sector Z_8 exists: 8 | 4S iff 2 | S)  (lab Carrier Om=2408561)
#   [PASS] S = 1 mod 3  (lab Carrier Om=2408561)
#   [PASS] 4S+1 prime  (lab Carrier Om=2408561)
#   [PASS] octant count S/2 is an integer  (lab Carrier Om=2408561)
# area law (row B9): quarter identity and quarter-turn chain (counts)
#   [PASS] quarter identity 4S = Om - 1
#   [PASS] quarter-turn at the Carrier: 4 | Om - 1
#   [PASS] quarter-turn at the Subject: q_H = 4 kap_H + 1 = 13, prime
# area law chart face (row B9) [approx]: 4 pi n_A = 4 S(r_H)
#   [PASS] r_H = 1 m
#   [PASS] r_H = 1.5e+26 m
#
# #  instrument                            r_H [m]          S    sqrt(S)   sig%
# 1  Lambda (CMB, Planck alone)          1.661e+26  3.32e+122   1.82e+61    1.0
# 2a ladder H0=73.0 (Cepheid)            1.267e+26  1.93e+122   1.39e+61    1.4
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:B9 (p14017) [T|R] — the deciding family est.B9
# The area law: the projected horizon area in Planck cells is the full phase cycle, $A=4\dS$ \apx{} at the
# horizon ($4\pi n_A=4\dS$, $n_A=(r_H/\lP)^{2}$ \apx); the Bekenstein--Hawking quarter $\dS=A/4$ is the
# quarter-turn $Q_4$, the generative four of $\Om=4\dS+1$ and $\p=4\kap+1$; area is a Subject-projection
# property, the Carrier carrying none.
from frc_14_entropy import predicate; predicate("14:B9")
# Out:
# — entropy.py:263 (the check that decides 14:B9; family est.B9)
#   263      # 14:B9 (p14017)
#   264      b9_checks = [
#   265          ("quarter identity 4S = Om - 1", 4 * S_LAB == OM_LAB - 1),
#   266          ("quarter-turn at the Carrier: 4 | Om - 1", (OM_LAB - 1) % 4 == 0),
#   267          ("quarter-turn at the Subject: q_H = 4 kap_H + 1 = 13, prime",
#   268           Q_H == 13 and is_prime(Q_H) and (Q_H - 1) % 4 == 0),
#   269      ]
#   270      family("est", "B9")
#   271      for name, ok in b9_checks:
#   272          print(f"  [{'PASS' if ok else 'FAIL'}] {name}")
#   273          chk(name, ok)
#   274
#   275      # ------------------------------------------------------------ chart channel
#   276      # laboratory channel [I]
#   [PASS] est.B9   (deciding)       5 micro-checks
# 14:B9: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C1 (p14018) [T] — the deciding family est.T1
# Two faces: a frame supplies one spatial and one temporal datum, so every instrument reading the size of the
# totality is one of exactly two faces, converted by $c$.
from frc_14_entropy import predicate; predicate("14:C1")
# Out:
# — entropy.py:331 (the check that decides 14:C1; family est.T1)
#   331      # 14:C1 (p14018)
#   332      family("est", "T1")
#   333      TABLE = {"1": (1.66, 3.3, 1), "2a": (1.27, 1.9, 1.4), "2b": (1.33, 2.1, 2.4), "3": (1.19, 1.7, 20), "4a": (1.29, 2.0, 2.5), "4b": (1.64, 3.2, 2.5)}
#   334      for key, name, rH in rows:
#   335          r_t, S_t, sg_t = TABLE[key]
#   336          chk(f"row {key}: r_H = {r_t} e26 m, S = {S_t} e122, sigma = {sg_t}% as tabulated",
#   337              abs(rH / 1e26 - r_t) < 0.006 and abs(Svals[key] / 1e122 - S_t) < 0.06 and abs(100 * sigma[key] - sg_t) < 0.1)
#   338
#   339      EVIDENCE = [k for k, _, _ in rows if k not in GAUGE]   # five evidence readings
#   340      sq = {k: sqrt(Svals[k]) for k in EVIDENCE}
#   341      m = sum(sq.values()) / len(sq)
#   342      half = 100 * (max(sq.values()) - min(sq.values())) / 2 / m
#   343      fac = (max(sq.values()) / min(sq.values())) ** 2
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C3 (p14020) [T] — the deciding family est.A1
# The same-channel demotion: $t_0H_\Lambda=\tfrac23\artanh\sqrt{\Omega_\Lambda}$ \lcdm{} depends on the one
# fitted parameter, so the $0.2\%$ landing on $\pi/4$ restates the fit (by B5).
from frc_14_entropy import predicate; predicate("14:C3")
# Out:
# — entropy.py:388 (the check that decides 14:C3; family est.A1)
#   388      # 14:C3 (p14020), 14:C7 (p14024), 14:X3 (p14030), 14:X6 (p14033)
#   389      family("est", "A1")
#   390      chk("t0 H_Lambda = (2/3) artanh(sqrt(OmL)) = 0.7871 at OmL = 0.685 [LCDM]", abs(ratio - 0.7871) < 5e-4)
#   391      chk("within 0.2% of pi/4 = 0.7854", dev < 0.25)
#   392      chk("the inversion: pi/4 corresponds to OmL = tanh^2(3pi/8) = 0.6837", abs(OmL_pi4 - 0.6837) < 5e-5)
#   393      chk("a 0.19-sigma landing on the fitted 0.685 +/- 0.007", abs(sig - 0.19) < 0.01)
#   394
#   395      # octant lemma prediction: Omega_Lambda as an output of the realisation set
#   396      print(f"\noctant lemma: t_age = (pi/4) r_H/c  =>  predicted OmL = tanh^2(3pi/8) = {OmL_pi4:.4f}"
#   397            f"  (fitted {OmL}: {sig:.2f} sigma)")
#   398      print("saturation test (fit-independent): oldest-object ages cap at (pi/4) r_H/c = 13.8 Gyr,"
#   399            " at every observational frame chronon")
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C4 (p14021) [T] — the deciding family est.C1
# The concordance: five evidence readings return $\sqrt{\dS}=(1.3\text{--}1.8)\times10^{61}$ \apx, $\pm17\%$
# half-range on the count face, factor $1.9$ on $\dS$; the gauge reading 4a is displayed and excluded from
# every statistic.
from frc_14_entropy import predicate; predicate("14:C4")
# Out:
# — entropy.py:348 (the check that decides 14:C4; family est.C1)
#   348      # 14:C4 (p14021)
#   349      family("est", "C1")
#   350      chk("five evidence readings, gauge row 4a excluded", EVIDENCE == ["1", "2a", "2b", "3", "4b"])
#   351      chk("sqrt(S) = (1.3..1.8) e61 across the five readings", 1.25e61 < min(sq.values()) < 1.35e61 and 1.75e61 < max(sq.values()) < 1.85e61)
#   352      chk("half-range +/-17% on the count face (16.5 +/- 0.5)", abs(half - 16.5) < 0.5)
#   353      chk("full-range spread on S a factor 1.9 (1.94 +/- 0.05)", abs(fac - 1.94) < 0.05)
#   354      print("[PASS] concordance: +/-17% half-range, factor 1.9 on S")
#   355
#   356      CONV = ["1", "2a", "2b"]                       # conventional channels alone
#   357      sqc = {k: sqrt(Svals[k]) for k in CONV}
#   358      mcv = sum(sqc.values()) / len(sqc)
#   359      half_cv = 100 * (max(sqc.values()) - min(sqc.values())) / 2 / mcv
#   360      fac_cv = (max(sqc.values()) / min(sqc.values())) ** 2
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C5 (p14022) [T|R] — the deciding family est.P2
# The octant lemma: the measured age is $\dS/2$ chronons, $(\pi/4)\,r_H/c$ in the chart \apx; the halving and
# the sector are exact through the enumerated realisation set $B_{\mathrm{oct}}=\{$A4, A5, B2, B3, B6, B7$\}$,
# the same class as the constants correspondence.
from frc_14_entropy import predicate; predicate("14:C5")
# Out:
# [PASS] constrained k=3: c~ = m/R^3 = 9.66e+02 kg/m^3 (a cubic coefficient, not a density); over-closure band (1.39e+08 .. 2.83e+08) Msun across the four fit variants
# [PASS] slope decomposition: k = 3 + dc/dlogR, drift +0.0318 (0.61 dex over 19.1 dex), mean c = 2.99
# [PASS] diagonal: k = 3.0318 (13 mid-wedge), intercept 1.00e+03 at the metre pivot (density units only at k = 3); sensitivity k = 3.0071 (15 incl. walls)
# [PASS] boundaries: Compton entry R = 5.32e-12 m; over-closure exit M = 1.80e+08 Msun
# [PASS] wall residents on-wall to <0.01 dex: electron (Compton, +1.1 dex beyond entry), Sgr A* (Schwarzschild, +1.6 dex before exit)
# [WROTE] out/registrable-wedge.png, .pdf
# [WROTE] out/registrable-wedge-plain.png, .pdf
# [WROTE] out/wall-channels.png, .pdf
# ok
#   [PASS] tri.A   CHART       [14:C5, 14:C8, 14:C9] the triangle's audit identities before drawing: the octant t_oct = (√π/4)√S t_P to 10⁻¹²; the two-cl  --  5 micro-checks
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C6 (p14023) [T] — the deciding family est.F1
# The octant sector: $C_{8}\subset C_{4\dS}$ exists exactly when $\dS$ is even, its character $\zeta_8$ the
# residue the Tsirelson identity carries; the octant count $\dS/2$ is an integer on every admissible Carrier.
from frc_14_entropy import predicate; predicate("14:C6")
# Out:
# — entropy.py:243 (the check that decides 14:C6; family est.F1)
#   243      # 14:A2 (p14002), 14:C6 (p14023)
#   244      checks = [
#   245          ("Om = 4S+1", OM_LAB == 2_408_561),
#   246          ("S even (octant sector Z_8 exists: 8 | 4S iff 2 | S)", S_LAB % 2 == 0),
#   247          ("S = 1 mod 3", S_LAB % 3 == 1),
#   248          ("4S+1 prime", is_prime(OM_LAB)),
#   249          ("octant count S/2 is an integer", (S_LAB // 2) * 2 == S_LAB),
#   250      ]
#   251      family("est", "F1")
#   252      for name, ok in checks:
#   253          print(f"  [{'PASS' if ok else 'FAIL'}] {name}  (lab Carrier Om={OM_LAB})")
#   254          chk(name, ok)
#   255
#   256      # ------------------------------------------------------- area law (row B9)
#   [PASS] est.F1   (deciding)       5 micro-checks
# 14:C6: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C7 (p14024) [T|R] — the deciding family est.A1
# The dark-energy output: $\Omega_\Lambda=\tanh^{2}(3\pi/8)=0.6837$ \lcdm{} against the fitted
# $0.685\pm0.007$, a $0.19\sigma$ landing --- a zero-freedom derivation, not an independent measurement
# (two-register separation, \S\ref{sec:audit}).
from frc_14_entropy import predicate; predicate("14:C7")
# Out:
# — entropy.py:388 (the check that decides 14:C7; family est.A1)
#   388      # 14:C3 (p14020), 14:C7 (p14024), 14:X3 (p14030), 14:X6 (p14033)
#   389      family("est", "A1")
#   390      chk("t0 H_Lambda = (2/3) artanh(sqrt(OmL)) = 0.7871 at OmL = 0.685 [LCDM]", abs(ratio - 0.7871) < 5e-4)
#   391      chk("within 0.2% of pi/4 = 0.7854", dev < 0.25)
#   392      chk("the inversion: pi/4 corresponds to OmL = tanh^2(3pi/8) = 0.6837", abs(OmL_pi4 - 0.6837) < 5e-5)
#   393      chk("a 0.19-sigma landing on the fitted 0.685 +/- 0.007", abs(sig - 0.19) < 0.01)
#   394
#   395      # octant lemma prediction: Omega_Lambda as an output of the realisation set
#   396      print(f"\noctant lemma: t_age = (pi/4) r_H/c  =>  predicted OmL = tanh^2(3pi/8) = {OmL_pi4:.4f}"
#   397            f"  (fitted {OmL}: {sig:.2f} sigma)")
#   398      print("saturation test (fit-independent): oldest-object ages cap at (pi/4) r_H/c = 13.8 Gyr,"
#   399            " at every observational frame chronon")
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C8 (p14025) [T|R] — the deciding family est.C3
# The entailed-rate consistency: with the channel-1 $\Lambda$ the age--rate locus returns the channel-1 $H_0$
# (to $0.1\%$), same-channel by the definition $\Lambda=3\Omega_\Lambda H_0^{2}/c^{2}$, a corollary of C7 and
# not a prediction --- the floor value itself consumed as import (A6) under the role realisation (B4), not
# derived here; the two-cluster ratio is the chart identity $(H_{\mathrm{rate}}/H_0)^2/\Omega_\Lambda$,
# displayed, not claimed.
from frc_14_entropy import predicate; predicate("14:C8")
# Out:
# — entropy.py:407 (the check that decides 14:C8; family est.C3)
#   407      # 14:C8 (p14025)
#   408      family("est", "C3")
#   409      chk("H_Lambda = 55.7 km/s/Mpc from the fit's Lambda (1/H_Lambda = 17.55 Gyr) [LCDM]", abs(H_L - 55.7) < 0.05 and abs(1 / (H_L * 1e3 / Mpc) / Gyr - 17.55) < 0.01)
#   410      chk("the locus at the channel-1 Lambda returns H0 = 67.4, the fit's own value to 0.1%", abs(H0_ent - 67.4) < 0.15 and abs(H0_ent / 67.36 - 1.0) < 0.002)
#   411      print("[PASS] channel-1 consistency: the locus returns the fit's H0 to 0.1%")
#   412
#   413      # the age-rate locus (row P3): t_age * H0 = (pi/4)/tanh(3pi/8), exact for the realisation set; read on the
#   414      # fit-independent stellar age it is a prediction of H0 independent of the expansion fit.
#   415      locus = (pi / 4) / tanh(3 * pi / 8)
#   416      t_star, dt_star = 13.61, sqrt(0.25 ** 2 + 0.23 ** 2)   # Gyr, Valcin 2026 (stat+sys)
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C9 (p14026) [T] — the deciding family tri.D
# The registrable triangle \apx: width $\log_{10}(r_H/\lP)=61.0$ dex --- the count face $\sqrt{\dS}$ in its
# chart dress $\sqrt{\dS/\pi}$, the solid angle the declared transport; the thirteen-object diagonal, slope
# $3.03$ (intercept $1.00\times10^{3}$ at the metre pivot); the constrained $k=3$ cubic coefficient $\tilde
# c=m/R^{3}=0.97\times10^{3}\,\mathrm{kg\,m^{-3}}$ (not a density: a sphere's is $0.62$ dex lower); the
# Compton entry returns its input, the Schwarzschild exit is the chart's one derived quantity, the
# over-closure bound $1.8\times10^{8}M_\odot$ within the $(1.4\text{--}2.8)\times10^{8}$ sensitivity band ---
# a bound, no observed scale predicted (X5); classified a consistency chart, not a channel.
from frc_14_entropy import predicate; predicate("14:C9")
# Out:
# [PASS] constrained k=3: c~ = m/R^3 = 9.66e+02 kg/m^3 (a cubic coefficient, not a density); over-closure band (1.39e+08 .. 2.83e+08) Msun across the four fit variants
# [PASS] slope decomposition: k = 3 + dc/dlogR, drift +0.0318 (0.61 dex over 19.1 dex), mean c = 2.99
# [PASS] diagonal: k = 3.0318 (13 mid-wedge), intercept 1.00e+03 at the metre pivot (density units only at k = 3); sensitivity k = 3.0071 (15 incl. walls)
# [PASS] boundaries: Compton entry R = 5.32e-12 m; over-closure exit M = 1.80e+08 Msun
# [PASS] wall residents on-wall to <0.01 dex: electron (Compton, +1.1 dex beyond entry), Sgr A* (Schwarzschild, +1.6 dex before exit)
# [WROTE] out/registrable-wedge-capacity.png, .pdf
#   [PASS] cap.A   CHART       [14:C9] the audit and diagonal identities re-asserted in the capacity-axis variant (identical to tri.A, tri.  --  14 micro-checks
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:C10 (p14027) [T] — the deciding family cap.K
# The capacity axis \apx: holographic ring capacity $\log_{10}\kap_{q}$, zero at hydrogen ($\kap_H=3$;
# $\kap_{q}=2$ has no shell), one dex per chart dex, terminating at the count face $\sqrt{\dS}$ --- the
# triangle's own sixty dex; the one-gram horizontal lands on $N_A$ to $0.0035$ dex (the $1.008$\,u offset),
# asserted before drawing.
from frc_14_entropy import predicate; predicate("14:C10")
# Out:
# — entropy.py:1129 (the check that decides 14:C10; family cap.K)
#  1129      # 14:C10 (p14027)
#  1130      family("cap", "K")
#  1131      axi.remove()
#  1132
#  1133      # right axis, same format as the left mass axis: log10 capacity, kappa
#  1134      # primary, zero at the H atom (kappa_H = 3, the first Object), one dex of
#  1135      # capacity per dex of the chart.
#  1136      yH = log10(1.674e-27)                    # the H-atom mass line [approx SI]
#  1137      fig.subplots_adjust(left=0.11, right=0.90, top=0.945, bottom=0.05)
#  1138      fig.canvas.draw()
#  1139      chk("the pin held: no datalim drift", ax.get_ylim() == (-45.0, 62.0))
#  1140      pos = ax.get_position()
#  1141
#  1142      rax = fig.add_axes([pos.x1, pos.y0, 0.0001, pos.height])
#   [PASS] cap.K    (deciding)       2 micro-checks
# 14:C10: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:X2 (p14029) [T|R] — the deciding family est.L1
# \textbf{Milgrom's coincidence} $a_0\approx cH_0/2\pi$, on record since 1983, becomes a value with zero
# freedom: the $2\pi$ is the fixed cycle convention, the reverse rebooking of $h=2\pi\hbar$, and the $H$ is
# the observer's registered rate.
from frc_14_entropy import predicate; predicate("14:X2")
# Out:
# — entropy.py:459 (the check that decides 14:X2; family est.L1)
#   459      # 14:X2 (p14029)
#   460      family("est", "L1")
#   461      chk("floor landing c H0/a0 = 5.46 at H0 = 67.4 [approx]", abs(land - 5.46) < 0.02)
#   462      chk("+/-1.1 (20%), 0.8 sigma from 2 pi", abs(0.2 * land - 1.09) < 0.02 and abs((2 * pi - land) / (0.2 * land) - 0.76) < 0.03)
#   463
#   464      # temporal-face confrontation: octant bound vs Valcin et al. 2026 (IV) [LCDM]
#   465      t_oct = (pi / 4) * sqrt(3.0 / Lam) / c / Gyr
#   466      dv = sqrt(0.25 ** 2 + 0.23 ** 2)
#   467      sig_gc = (t_oct - 13.61) / dv
#   468      sig_tu = (t_oct - 13.81) / dv
#   469      print(f"\noctant bound {t_oct:.2f} Gyr vs Valcin IV (one vintage everywhere):"
#   470            f" oldest population {sig_gc:+.2f} sigma below (fit-independent, carries P2);"
#   471            f" prior-dependent inferred age {sig_tu:+.2f} sigma (straddles within 0.1 sigma)")
#   472      # 14:C5 (p14022), 14:P2 (p14037)
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:X3 (p14030) [T|R] — the deciding family est.A1
# \textbf{The age coincidence} $t_0H_\Lambda\approx\pi/4$ becomes the octant:
# $\Omega_\Lambda=\tanh^{2}(3\pi/8)=0.6837$ \lcdm{} is an output of the realisation set, landing at
# $0.19\sigma$ on the fitted $0.685\pm0.007$ --- never an independent measurement of $\dS$ (same-channel, X6),
# a zero-freedom derivation in full standing; the $(\Lambda,H_0)$ entailment at the channel-1 $\Lambda$ is
# this same landing read on $H_0$, not a further prediction.
from frc_14_entropy import predicate; predicate("14:X3")
# Out:
# — entropy.py:388 (the check that decides 14:X3; family est.A1)
#   388      # 14:C3 (p14020), 14:C7 (p14024), 14:X3 (p14030), 14:X6 (p14033)
#   389      family("est", "A1")
#   390      chk("t0 H_Lambda = (2/3) artanh(sqrt(OmL)) = 0.7871 at OmL = 0.685 [LCDM]", abs(ratio - 0.7871) < 5e-4)
#   391      chk("within 0.2% of pi/4 = 0.7854", dev < 0.25)
#   392      chk("the inversion: pi/4 corresponds to OmL = tanh^2(3pi/8) = 0.6837", abs(OmL_pi4 - 0.6837) < 5e-5)
#   393      chk("a 0.19-sigma landing on the fitted 0.685 +/- 0.007", abs(sig - 0.19) < 0.01)
#   394
#   395      # octant lemma prediction: Omega_Lambda as an output of the realisation set
#   396      print(f"\noctant lemma: t_age = (pi/4) r_H/c  =>  predicted OmL = tanh^2(3pi/8) = {OmL_pi4:.4f}"
#   397            f"  (fitted {OmL}: {sig:.2f} sigma)")
#   398      print("saturation test (fit-independent): oldest-object ages cap at (pi/4) r_H/c = 13.8 Gyr,"
#   399            " at every observational frame chronon")
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:X5 (p14032) [T] — the deciding family tri.D
# \textbf{The termination of the single-object sequence} is a consistency of the wall structure, the exit of
# C9 read as a bound: the typical-density diagonal over-closes at $1.8\times10^{8}M_\odot$ \apx{} (sensitivity
# band $(1.4\text{--}2.8)\times10^{8}$ across fit variants), so every heavier single object continuing the
# condensed-density sequence is necessarily wall-bound; the supermassive holes are that continuation, not an
# anomaly beyond it. Classified with the triangle: consistency, not derivation of an observed scale.
from frc_14_entropy import predicate; predicate("14:X5")
# Out:
# — entropy.py:685 (the check that decides 14:X5; family tri.D)
#   685      # 14:C9 (p14026), 14:X5 (p14032)
#   686      family("tri", "D")
#   687      chk("slope 3 within 1.1%", abs(k_fit - 3.032) < 0.005)
#   688      chk("coefficient 1.00e3 kg/m^3", abs(10 ** b_fit / 1.00e3 - 1) < 0.05)
#   689      chk("sensitivity: walls included", abs(k_full - 3.007) < 0.005)
#   690      chk("over-closure bound [Msun]", abs(M_exit / 1.8e8 - 1) < 0.05)
#   691      chk("constrained k=3 coefficient", abs(10 ** b_c13 / 0.97e3 - 1) < 0.05)
#   692
#   693
#   694      def exit_of(k, b):                                # exit mass of a fit variant
#   695          xh = (-log10(2 * G / c**2) - b) / (k - 1)
#   696          return 10 ** (xh - log10(2 * G / c**2)) / 1.989e30
#   697
#   698
#   [PASS] tri.D    (deciding)       6 micro-checks
# 14:X5: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:X6 (p14033) [T] — the deciding family est.A1
# \textbf{The celebrated sub-percent age agreement} is judged: same-channel by the circularity criterion, a
# restatement of the fitted dark-energy fraction --- consistency, not evidence --- and the criterion locates
# exactly which confrontations do carry weight.
from frc_14_entropy import predicate; predicate("14:X6")
# Out:
# — entropy.py:388 (the check that decides 14:X6; family est.A1)
#   388      # 14:C3 (p14020), 14:C7 (p14024), 14:X3 (p14030), 14:X6 (p14033)
#   389      family("est", "A1")
#   390      chk("t0 H_Lambda = (2/3) artanh(sqrt(OmL)) = 0.7871 at OmL = 0.685 [LCDM]", abs(ratio - 0.7871) < 5e-4)
#   391      chk("within 0.2% of pi/4 = 0.7854", dev < 0.25)
#   392      chk("the inversion: pi/4 corresponds to OmL = tanh^2(3pi/8) = 0.6837", abs(OmL_pi4 - 0.6837) < 5e-5)
#   393      chk("a 0.19-sigma landing on the fitted 0.685 +/- 0.007", abs(sig - 0.19) < 0.01)
#   394
#   395      # octant lemma prediction: Omega_Lambda as an output of the realisation set
#   396      print(f"\noctant lemma: t_age = (pi/4) r_H/c  =>  predicted OmL = tanh^2(3pi/8) = {OmL_pi4:.4f}"
#   397            f"  (fitted {OmL}: {sig:.2f} sigma)")
#   398      print("saturation test (fit-independent): oldest-object ages cap at (pi/4) r_H/c = 13.8 Gyr,"
#   399            " at every observational frame chronon")
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:P1 (p14036) [T|R] — the deciding family est.P1
# \textbf{(Lead.)} The floor runs with the registered rate, $a_0(z)\propto H(z)$, the role statement of the
# floor closure, against both a constant fundamental $a_0$ and feedback-emergent scaling. Status: the
# constant-floor branch is excluded --- four redshift bins rising from $1.99$ to
# $2.71\times10^{-10}\,\mathrm{m/s^2}$ over $z=0.50$--$1.28$ \citep{ciocan2026}, $\Delta\chi^2=23$ against
# $A\,H(z)/H_0$ \lcdm{} --- and the running form fits the bins at free amplitude ($A=1.39\pm0.03$,
# $\chi^2=5.4/3$); the binned rate sits on the $\propto H(z)$ chord while the authors' global linear fit runs
# above it, so the shape waits on the likelihood refit of the resolved tracks, and the amplitude's $0.12$\,dex
# excess over $cH_0/2\pi$ lies inside the $0.2$\,dex gas systematic. Falsifier: a likelihood refit or a
# wider-redshift sample excluding the $\propto H(z)$ form after the baryonic-mass and pressure-support
# systematics close.
from frc_14_entropy import predicate; predicate("14:P1")
# Out:
# — entropy.py:491 (the check that decides 14:P1; family est.P1)
#   491      # 14:P1 (p14036)
#   492      family("est", "P1")
#   493      chk("a0(z=1) on the H(z) chord: 2.15e-10 (flat LCDM E(z=1) = 1.79) [LCDM]", abs(a0_pred - 2.15) < 0.01 and abs(Hz - 1.79) < 0.005)
#   494      chk("endpoint 0.5 sigma from the measured 2.38 +/- 0.10 with the anchor's systematic band", abs(sig_end - 0.5) < 0.1)
#   495      chk("the fitted linear rate 1.59 +/- 0.10 exceeds the chord's 0.95 per unit redshift by ~3 sigma (pre-systematics)", abs(slope_pred - 0.95) < 0.01 and abs(sig_slope - 3.0) < 0.1)
#   496      # the four bins (Fig. 3 of Ciocan et al. 2026, digitised in the corpus paper 43-muse, validation/muse_bins.py): z centre, a0 in 1e-10 m/s^2, error [import]
#   497      zb, ab, eb = [0.503, 0.825, 1.047, 1.276], [1.990, 2.200, 2.571, 2.710], [0.086, 0.105, 0.112, 0.136]
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:P2 (p14037) [T|R] — the deciding family est.P2
# The registered record depth is bounded by $(\pi/4)\,r_H/c=13.79$ Gyr \apx{} (channel-1 anchor) at every
# observational frame chronon, against a $\Lambda$CDM $t_0$ that grows with chart time: degenerate to $0.2\%$
# now, separating at ${\sim}7\%$ per Gyr; the octant carries zero parameter freedom at fixed $\Lambda$. Status
# \citep{valcin2026}: the oldest cluster population $0.5\sigma$ below the bound, the inferred age straddling
# it within $0.1\sigma$ (\S\ref{sec:open}). Falsifier: one well-dated object older than the octant value, in
# any frame --- fit-independent, fatal; the same bound excludes interior-bounce black-hole cosmology (X8).
from frc_14_entropy import predicate; predicate("14:P2")
# Out:
# — entropy.py:472 (the check that decides 14:P2; family est.P2)
#   472      # 14:C5 (p14022), 14:P2 (p14037)
#   473      family("est", "P2")
#   474      chk("the octant bound (pi/4) sqrt(3/Lambda)/c = 13.79 Gyr at the channel-1 Lambda [approx]", abs(t_oct - 13.79) < 0.01)
#   475      chk("the LCDM age 13.80 Gyr is degenerate with the bound to 0.2%", abs(13.80 / t_oct - 1) < 0.0025)
#   476      chk("oldest cluster population 13.61 +/- 0.34: 0.5 sigma below the bound (0.53)", abs(sig_gc - 0.53) < 0.05)
#   477      chk("inferred cosmic age 13.81: straddles the bound within 0.1 sigma (-0.06)", abs(sig_tu + 0.06) < 0.05)
#   478      print("[PASS] Valcin IV: population 0.5 sigma below the bound; inferred age a"
#   479            " prior-dependent consistency, statistically consistent with saturation")
#   480
#   481      # floor-running confrontation: MUSE-DARK III (Ciocan et al. 2026) [LCDM]
#   482      Om_m = 0.315
# ...

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
# 14:P3 (p14038) [T|R] — the deciding family est.P3
# The age--rate locus $t_{\mathrm{age}}H_0=(\pi/4)/\tanh(3\pi/8)=0.950$, exact for the realisation set. Read
# on the fit-independent stellar age ($13.61\pm0.34$ Gyr): $H_0=68.2\pm1.7$ km/s/Mpc \apx, $0.5\sigma$ from
# Planck, $0.65\sigma$ from TRGB, $2.4\sigma$ from the Cepheid ladder --- the framework favours the CMB/TRGB
# value at that significance, and forbids the $\Omega_\Lambda\approx0.76$ by which the rival chart would
# accommodate the ladder value at the same age. Read on the channel-1 $\Lambda$ it returns the channel-1 $H_0$
# (to $0.1\%$): a consistency, not a prediction (C8). Falsifier: a confirmed ladder $H_0$ with the stellar age
# standing ($t_\star H_0\ge1.0$ against $0.950$).
from frc_14_entropy import predicate; predicate("14:P3")
# Out:
# — entropy.py:427 (the check that decides 14:P3; family est.P3)
#   427      # 14:P3 (p14038)
#   428      family("est", "P3")
#   429      chk("the age-rate locus t_age H0 = (pi/4)/tanh(3pi/8) = 0.950 (0.9499)", abs(locus - 0.9499) < 5e-4)
#   430      chk("flat LCDM returns 0.951 at the fitted OmL (the X3 coincidence read on H0)", abs(lcdm_locus - 0.9510) < 5e-4)
#   431      chk("read on t_star = 13.61 +/- 0.34 Gyr: H0 = 68.2 +/- 1.7 km/s/Mpc [approx]", abs(H0_age - 68.2) < 0.1 and abs(dH0_age - 1.7) < 0.05)
#   432      chk("confrontations: Planck 0.5 sigma, TRGB 0.65 sigma, Cepheid 2.4 sigma", abs(sig_shoes - 2.4) < 0.1 and abs(sig_trgb - 0.65) < 0.05 and abs(abs(sig_planck) - 0.5) < 0.05)
#   433      chk("the ladder pair (13.61 Gyr, 73): t_star H0 = 1.016, above the locus", abs(73.0 * 1e3 / Mpc * t_star * Gyr - 1.016) < 0.002)
#   434      print("[PASS] P3: H0 = 68.2 +/- 1.7 from the stellar age through the octant; Cepheid 2.4 sigma, TRGB 0.65, Planck 0.5")
#   435
# ...

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, family by family, is `python3 entropy.py`
# (19 family checks, 92 micro-checks — EXACT counts on the laboratory Carrier and CHART computations on the published data — `results.json`, the figures in `out/`), `python3 -m frc_14_entropy` once installed.

# %%
# !pip install -q frc-14-entropy --find-links https://finitering.space/pkg/
from frc_14_entropy import verify_all
assert verify_all(), "a family check failed"
print("all family checks pass")
# Out:
# SUMMARY: 19/19 checks passed (92 micro-checks)
# all family checks pass

# %% [markdown]
# ## Relativistic Algebra over Finite Ring Continuum, [Akhtman, Axioms 2025](https://doi.org/10.3390/axioms14080636)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Appendix A; [finitering.space/1-algebra/](https://finitering.space/1-algebra/)): it runs the
# blocks of [`algebra.py`](https://finitering.space/src/1-algebra/algebra.html) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 30 s).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:B2 (p01004) [T] — the deciding check A1
# Symmetry completeness (Thm.~\ref{thm:symmetric-completeness}): the fourth roots of unity form the unique
# order-four subgroup $Q_4=\{1,\im,-1,-\im\}$; under the Klein four-group $\langle x\mapsto-x,\,x\mapsto
# x^{-1}\rangle$, $Q_4$ is the union of the two size-two orbits $\{\pm1\}$, $\{\pm\im\}$, and $\Fpx\setminus
# Q_4$ splits into exactly $\kap-1$ orbits of size four. For $\p\equiv3\pmod4$ no $\im$ exists.
from frc_1_algebra import predicate; predicate("1:B2")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:B3 (p01005) [T] — the deciding check A2
# The oriented quarter-turn: $\im=-\gen^{\kap}$ satisfies $\im^{2}=-1$ for every primitive root $\gen$; the
# two square roots of $-1$ are $\{-\gen^{\kap},\gen^{\kap}\}$, so the drive fixes which is $\im$. On
# $\F_{13}$, $\gen=2$: $\im=5$.
from frc_1_algebra import predicate; predicate("1:B3")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:B4 (p01006) [T] — the deciding check A3
# Affine reframing (Def.~\ref{def:framed-field}, Lemma~\ref{lem:affine-invariance}): $\varphi_{a,b}(x)=a+bx$,
# $b\neq0$, is a ring isomorphism $(\Fp,+,\cdot)\to(\Fp,\oplus,\otimes)$ with origin $a$ and unit $a+b$; every
# polynomial identity is frame-covariant.
from frc_1_algebra import predicate; predicate("1:B4")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:C2 (p01009) [T] — the deciding check A4
# The frame group (Prop.~\ref{prop:frame-group}): $\langle T_a,S_m\rangle$ is the affine group of order
# $\p(\p-1)$, acting simply transitively on the frames $(a,b)$, $b\neq0$; the set of frames is a torsor under
# it (00:C5, 00:D13).
from frc_1_algebra import predicate; predicate("1:C2")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:C4 (p01011) [T] — the deciding check A5
# Involutions and counts (Def.~\ref{def:orbit-sphere}\,(a)--(c)): $M_n(a)=M_{n+2\kap}(-a)$ and
# $L_a(m)=L_{-a}(m+2\kap)$ since $\gen^{2\kap}=-1$; $\p-1$ distinct meridian lists in $2\kap$ great circles;
# $2\kap$ latitude pairs; one-sided vertex count $(\p-1)^{2}/2+1$, the double cover $(\p-1)^{2}$ (00:B11).
from frc_1_algebra import predicate; predicate("1:C4")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:D2 (p01013) [T] — the deciding check B1
# The window law: $z\mapsto z\bmod\p$ is injective on $W_H$ when $2H<\p$; for $x,y\in W_H$ the residue of
# $x\pm y$ reads back the integer when $4H<\p$, and that of $xy$ when $2H^{2}<\p$ (the same injectivity on the
# windows $2H$ and $H^{2}$).
from frc_1_algebra import predicate; predicate("1:D2")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:D4 (p01015) [T] — the deciding check B2
# Scale-periodicity (Lemma~\ref{thm:scale-periodicity}, in the field): $S_n(x)=x\gen^{-n}$ satisfies
# $S_{n+(\p-1)}=S_n$; the grids $G_n$ are $(\p-1)$-periodic as ordered lists; the zoom $[x,n]\mapsto[x,n+1]$
# has order $\p-1$. As lists of rationals $x/\gen^{n}$ ($\gen$ lifted to $\Z$) the grids are not periodic: the
# periodicity is a relation of the field.
from frc_1_algebra import predicate; predicate("1:D4")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:E2 (p01019) [T] — the deciding check B4
# The extension by $X^{2}+1$ is trivial (Prop.~\ref{prop:Cp-field} reversed): on the shell
# $\Fp[X]/(X^{2}+1)\cong\Fp\times\Fp$ has zero divisors, $(X+\im)(X-\im)=0$, so it is not a field;
# $\Fp[X]/(X^{2}+1)$ is a field exactly when $\p\equiv3\pmod4$; the quadratic extension of the shell is
# $\Fp[\eta]$, $\eta^{2}=\nu$ a non-square (8-dirac B6).
from frc_1_algebra import predicate; predicate("1:E2")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:F1 (p01020) [T] — the deciding check B5
# No element of additive order two (Thm.~\ref{thm:no-south-pole}): $2s=0$ forces $s=0$; the antipode of the
# origin on the additive cycle is not a residue; it sits between $2\kap=(\p-1)/2$ and
# $2\kap+1=(\p+1)/2=2^{-1}$ (20-rh B8).
from frc_1_algebra import predicate; predicate("1:F1")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:G1 (p01026) [T] — the deciding check C1
# Solving in the substrate (first clause): $f\in\Fp[X]$ has a root in $\Fp$ iff $f$ and
# $X^{\p}-X=\prod_{a}(X-a)$ are not coprime; the gcd counts the distinct roots and Cantor--Zassenhaus
# splitting finds them, exactly. An equation without a root in $\Fp$ is recognised, not extended (E2).
from frc_1_algebra import predicate; predicate("1:G1")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:G2 (p01027) [T] — the deciding check C2
# Limit-like approximation (second clause), across the tower: for every real $r$ and $\varepsilon>0$ some
# shell $\p=4\kap+1$ carries a framed rational $x/2^{n}$, $|x|\le2\kap$, within $\varepsilon$ of $r$ (primes
# $\equiv1\pmod4$ beyond every bound). One shell resolves to D5's bound; the limit is the tower, not a
# completion.
from frc_1_algebra import predicate; predicate("1:G2")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:G3 (p01028) [T] — the deciding check C3
# Continuous symmetry, the abelian case (third clause): $\Fpx\simeq C_{\p-1}\simeq SO(2,\Fp)$ (6:E2) is a
# $\pi/(\p-1)$-net of $U(1)$ under $k\mapsto e^{2\pi\im k/(\p-1)}$; the rounding
# $k(\theta)=\lfloor(\p-1)\theta/2\pi+\tfrac12\rfloor$ has angle and chord error $\le\pi/(\p-1)$ and group-law
# defect at most one step.
from frc_1_algebra import predicate; predicate("1:G3")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:G4 (p01029) [T] — the deciding check C4
# Continuous symmetry, the non-abelian obstruction: no finite subgroup of $SO(3)$ is an $\varepsilon$-net for
# $\varepsilon<\varepsilon_0=\arccos\big((3\sqrt5-1)/8\big)\approx44.5^\circ$, the covering radius of the
# icosahedral group (A3); the tetrahedral, cyclic and dihedral groups have radius $\ge\pi/2$, the octahedral
# $\approx62.8^\circ$. Finite subgroups cannot approximate $SO(3)$; the window does (G5).
from frc_1_algebra import predicate; predicate("1:G4")

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
# 1:G5 (p01030) [T] — the deciding check C5
# Continuous symmetry, the non-abelian case resolved by the window: the framed quaternions $W_H^{4}$, read in
# a shell $\p>8H^{2}$, compose exactly (products land in $W_{4H^{2}}$); normalised, they are an
# $\varepsilon$-net of $SO(3)$ with $\varepsilon\le2\arcsin(1/H)$ (round $Hs$ to the lattice). At $H=3$,
# $\p=73$: $38.9^\circ<\varepsilon_0$, finer than any finite subgroup; measured $30.0^\circ$.
from frc_1_algebra import predicate; predicate("1:G5")

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, check by check, is `python3 algebra.py`
# (16 checks, `results.json`), `python3 -m frc_1_algebra` once installed.

# %%
# !pip install -q frc-1-algebra --find-links https://finitering.space/pkg/
from frc_1_algebra import verify_all
assert verify_all(), "a check failed"
print("all checks pass")

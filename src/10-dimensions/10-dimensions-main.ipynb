# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gamayos/finite-ring-space/blob/main/src/10-dimensions/10-dimensions-main.ipynb)
#
# ## Dimensional Analysis over Finite Holographic Substrate (Akhtman, 2026) — the predicate ledger, one cell per row
#
# **One cell per row.** Each cell below verifies one row of the paper's predicate ledger (Appendix B; the public copy
# `docs/10-dimensions/10-dimensions-ledger.html`): it installs the package (`pip install` from the site, a no-op after the first), states
# the row, runs the scripts of the families that cite it (`verify_domains.py`, `check_lift.py` — each once per session),
# prints the check that decides the row from the script's own source, and lists every family record that cites the row
# with its verdict. Any cell can be run first. The ledger page links each row here, at its cell.
#
# **Run.** Any cell on its own, or *Runtime → Run all*; ≈ 10 s on Colab.

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the row.

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:C2 [T] — the deciding family dom.A
# The modular unit-domain group and the grading: $\{U_{r,s}\}$ is a finite abelian group isomorphic to $\Dp$
# under $U_{r,s}U_{r',s'}=U_{r+r',s+s'}$, and $\Ap$ is $\Dp$-graded,
# $\Ap^{(r,s)}\Ap^{(r',s')}\subseteq\Ap^{(r+r',s+s')}$.
from frc_10_dimensions import row; row("10:C2")
# Out:
#   [PASS] dom.A    EXACT [10:C2, 10:C3, 10:D2, 10:D6, 10:F2, 10:F4, 10:G1, 10:G3] shell datum and domain algebra on F_13: frame datum (g = 2, i = −g^κ, π = 2κ, 4κ = p−1); the group law, invers  --  33 exact micro-checks
#   [PASS] dom.B    EXACT [10:E2, 10:E3] the quartet at the unit face: exponent-vector relation lattice over {ℓ_P, t_P, ħ} (both faces of c and ħ diffe  --  30 exact micro-checks
#   [PASS] dom.C    EXACT [10:E4] the defining congruences on the lab Carrier Ω = 2 408 561 (S = 602 140): admissibility; 2G ≡ −1 unique; ħ² ≡ −  --  13 exact micro-checks
#   [PASS] dom.D    EXACT [10:E4, 10:E5, 10:E9, 10:F3, 10:G1] both Carriers (233 and the lab Carrier): the congruence-and-closure system, ħcG⁻¹ landing in the k_B pair; the  --  50 exact micro-checks
#   [PASS] dom.E    EXACT [10:C5] covariance: the naive character ill-defined on the modular projection; (p−1, 0) trivial character yet non-neut  --  18 exact micro-checks
#   [PASS] dom.F    EXACT [10:C5, 10:D1] the (0, π) witness forcing H < 2κ; the σ-twisted action equivariant by full sweep on p = 13 and 229 with the p  --  15 exact micro-checks
#   [PASS] dom.G    EXACT [10:C5, 10:D2, 10:F5, 10:G2, 10:G4] realized action against the Z³-representative failure; the flagged label (0, 0; 1) moving under ε = −1; the wi  --  21 exact micro-checks
#   [PASS] dom.H    EXACT [10:E4, 10:E5] the pair layer: pair multiplication well defined; the linkage {±k_B}{±c} = {±ħ} derived at pair level; ħcG⁻¹ i  --  27 exact micro-checks
# — verify_domains.py:54 (the check that decides 10:C2; family dom.A)
#    54      # row 10:C2
#    55      # domain group D_p = Z_p x Z_{p-1} with flag component mod 4
#    56      def dmul(a, b):
#    57          return ((a[0] + b[0]) % P, (a[1] + b[1]) % (P - 1), (a[2] + b[2]) % 4)
#    58
#    59      def dinv(a):
#    60          return ((-a[0]) % P, (-a[1]) % (P - 1), (-a[2]) % 4)
#    61
#    62      ONE = (0, 0, 0)
#    63      L = (1, 0, 0)
#    64      T = (0, 1, 0)
#    65      FLAG = (0, 0, 1)                 # the unit flag Iq
#    66
#    67      check("group identity", dmul(ONE, L) == L)
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:C2: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:C3 [T] — the deciding family dom.A
# Fibrewise addition and the neutral-domain criterion: a sum of homogeneous quantities is homogeneous exactly
# when its nonzero summands share a domain, the fibre components adding separately; a monomial $\prod
# Q_j^{k_j}$ has domain $\sum k_j(r_j,s_j)$ and is a neutral-domain invariant iff that sum is $(0,0)$ in
# $\Dp$.
from frc_10_dimensions import row; row("10:C3")
# Out:
# — verify_domains.py:127 (the check that decides 10:C3; family dom.A)
#   127      # row 10:C3
#   128      check("squaring leaves fibre: dom(Q) != dom(Q^2) for [L]", L != dpow(L, 2))
#   129      H = 5
#   130      # row 10:G1, 10:G3
#   131      check("local recovery bound: p-1 > 2H", P - 1 > 2 * H)
#   132      pairs = [(r, s) for r in range(-H, H + 1) for s in range(-H, H + 1)]
#   133      images = {(r % P, s % (P - 1)) for (r, s) in pairs}
#   134      check("local recovery: all |r|,|s| <= 5 distinguished", len(images) == len(pairs))
#   135      # the energy--momentum relation E^2 = p^2 c^2 + m^2 c^4: its three terms in one fibre, at crossing degree two (the
#   136      # half-period sector) -- Example ex:dispersion, row 10:G3
#   137      E2 = dpow(E_dom, 2); pc2 = dpow(dmul(p_dom, v_dom), 2); mc4 = dpow(dmul(m_dom, dpow(v_dom, 2)), 2)
#   138      check("dispersion: [E]^2 = [pc]^2 = [mc^2]^2, one fibre at sector 2", E2 == pc2 == mc4 and E2[2] == 2)
#   139
#   140      # B. the quartet at the unit face (exact rationals over free scales)
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:C3: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:C5 [T] — the deciding family dom.E
# Window covariance: on a bounded window $|r|,|s|\le H<2\kap$ in the flag-free sector the labels are covariant
# under every admissible reframing; the bound is sharp (the label $(0,\pi)$ is pushforward-invariant yet
# non-neutral); the naive character is ill-defined on the modular projection and the would-be temporal
# character fails composition ($5^{2}\equiv1$ in $\Z_{12}^{\times}$); on the realized lattice the invariant
# labels are exactly $\{0,2\kap\}$; the $\sigma$-twisted action is equivariant by full sweep on $\p=13$ and
# $229$; the flagged label $(0,0;1)$ moves under $\eps=-1$.
from frc_10_dimensions import row; row("10:C5")
# Out:
#   [PASS] lift.L1  EXACT [10:D3] operator four-cycle: F = iW on F_p^{p−1}, F² = J, F⁴ = I, F² ≠ I (p = 13, 173)  --  2 exact micro-checks
#   [PASS] lift.L2  EXACT [10:D3] chart shadow of order two: F exchanges the two dual charts, J exchanges none; the cardinal skeleton acts on ch  --  2 exact micro-checks
#   [PASS] lift.L3  EXACT [10:D3] record map s ↦ I_q^s an isomorphism Z_4 → the flag subgroup {0, κ, 2κ, 3κ}; the quotient by {0, 2κ} returns s   --  2 exact micro-checks
#   [PASS] lift.L4  EXACT [10:D3] Carrier face: ħ² = −1 (mod Ω), ħ⁴ = 1, ħ² ≠ 1 — the crossing quantum has order four, never two (Ω = 233, 2 408  --  2 exact micro-checks
#   [PASS] lift.L5  EXACT [10:C5, 10:D3] invariance on the realized lattice: {u : εu = u for every admissible ε} = {0, 2κ}; witnesses (κ,1) ↦ 2κ and (−  --  2 exact micro-checks
# — verify_domains.py:404 (the check that decides 10:C5; family dom.E)
#   404      # row 10:C5
#   405      # window covariance (Theorem 5, repaired form)
#   406      H = 5
#   407      check("r02: window dilation: trivial character forces r=0 in window",
#   408            all(not all(pow(m, -r, 13) == 1 for m in range(2, 13))
#   409                for r in range(-H, H + 1) if r != 0))
#   410      # pushforward invariant sublattice on the realized lattice is {0, pi}
#   411      units12 = [e for e in range(1, 12) if __import__("math").gcd(e, 12) == 1]
#   412      inv_labels = [s_ for s_ in range(12) if all((e * s_) % 12 == s_ for e in units12)]
#   413      check("r02: pushforward-invariant labels are exactly {0, pi}", inv_labels == [0, 6])
#   414      check("r02: eps=-1 admissible always", __import__("math").gcd(11, 12) == 1)
#   415      # flag pair behaviour under pushforward: eps mod 4 in {1,3} decides fix/swap
#   416      check("r02: quarter-turn labels fixed iff eps=1 mod 4",
#   417            all(((e * 3) % 12 == 3) == (e % 4 == 1) for e in units12))
#   [PASS] dom.E    (deciding)             18 exact micro-checks
#   [PASS] dom.F    (corroborating)        15 exact micro-checks
#   [PASS] dom.G    (corroborating)        21 exact micro-checks
#   [PASS] lift.L5  (corroborating)        2 exact micro-checks
# 10:C5: VERIFIED — 4 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:D1 [T] — the deciding family dom.F
# Chart duality: $[f]=\unitT^{-1}$; $\delta_S:D\mapsto D^{-1}$ is an involution of the domain group whose
# orbit on the generators is the four-domain structure (space, momentum, time, energy); $\delta_C$ the second
# involution, carrying $\unitL\mapsto[p]$, $\unitT\mapsto\unitE$.
from frc_10_dimensions import row; row("10:D1")
# Out:
# — verify_domains.py:473 (the check that decides 10:D1; family dom.F)
#   473      # row 10:D1
#   474      # delta_S / delta_C: involutions; delta_C carries primal domains to dual horizon domains
#   475      def dS_(a):
#   476          return dinv(a)
#   477      def dC_(a):
#   478          return dmul(FLAG, dinv(a))
#   479      check("r03: delta_S involution", all(dS_(dS_(a)) == a for a in [L, T, FLAG, (3, 5, 2)]))
#   480      check("r03: delta_C involution", all(dC_(dC_(a)) == a for a in [L, T, FLAG, (3, 5, 2)]))
#   481      check("r03: delta_C[L] = [p] domain", dC_(L) == p_dom)
#   482      check("r03: delta_C[T] = [E] domain", dC_(T) == E_dom)
#   483      check("r03: delta_S flag-free", dS_(L)[2] == 0 and dS_(T)[2] == 0)
#   484
#   485
#   486      # G. round-04 layer: realized action, j-restriction, ladder, k_B linkage typing
#   [PASS] dom.F    (deciding)             15 exact micro-checks
# 10:D1: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:D2 [T] — the deciding family dom.A
# The internal flag: $\Dp$ contains exactly one subgroup of order four, $\langle\unitT^{\kap}\rangle$,
# entirely in the time-exponent factor; $\Iq:=\unitT^{\kap}$, $\Iq^{4}=1$, $\Iq^{2}=\unitT^{\pi}$; no flag of
# space ($\Z_\p$ has no element of order four); the two periods interfere, $(\unitL\unitT^{\kap})^{\p}=\Iq$,
# on three shells.
from frc_10_dimensions import row; row("10:D2")
# Out:
# — verify_domains.py:70 (the check that decides 10:D2; family dom.A)
#    70      # row 10:D2
#    71      # fork B: the flag is internal, Iq = [T]^kappa; realized label of (r,s;j) is
#    72      # (r mod p, (s + j*kappa) mod (p-1)) with sector j mod 4
#    73      def realize(a):
#    74          return (a[0] % P, (a[1] + a[2] * KAPPA) % (P - 1))
#    75      check("realized flag label = (0, kappa)", realize(FLAG) == (0, KAPPA))
#    76      o4 = [(r, s) for r in range(P) for s in range(P - 1)
#    77            if (4 * r) % P == 0 and (4 * s) % (P - 1) == 0
#    78            and not ((2 * r) % P == 0 and (2 * s) % (P - 1) == 0)]
#    79      check("unique order-four subgroup: exactly two generators", sorted(o4) == [(0, KAPPA), (0, 3 * KAPPA)])
#    80      check("no flag of space: all order-four elements have r = 0", all(r == 0 for r, _ in o4))
#    81      check("flag horizon-inaccessible on window H<kappa",
#    82            all((0, KAPPA) != (r % P, s % (P - 1))
#    83                for r in range(-1, 2) for s in range(-1, 2)))
#   [PASS] dom.A    (deciding)             33 exact micro-checks
#   [PASS] dom.G    (corroborating)        21 exact micro-checks
# 10:D2: VERIFIED — 2 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:D3 [T] — the deciding family lift.L1
# The lift: the flag records the quarter the chart duality forgets --- on charts the cardinal skeleton acts as
# $s\bmod2$ ($F$ exchanges the conjugate charts, $J$ fixes them), on labels $s\mapsto\Iq^{s}$ is an
# isomorphism $\Z_4\to\langle\Iq\rangle$ whose quotient by $\{0,2\kap\}$ returns the chart action; on the
# Carrier $\hbar^{2}=-1$, $\hbar^{4}=1$, $\hbar^{2}\ne1$, the crossing quantum of order four, never two.
# Shells $(13,2)$, $(173,3)$; Carriers $233$, $2\,408\,561$.
from frc_10_dimensions import row; row("10:D3")
# Out:
# — check_lift.py:40 (the check that decides 10:D3; family lift.L1)
#    40      # row 10:D3
#    41      # shell Fourier matrix W_{jk} = g^{jk} on F_p^{n}; F = i*W
#    42      W = [[pow(g, (j * l) % n, p) for l in range(n)] for j in range(n)]
#    43      F = [[(i_res * W[j][l]) % p for l in range(n)] for j in range(n)]
#    44
#    45      F2 = modmat_mul(F, F, p)
#    46      F4 = modmat_mul(F2, F2, p)
#    47      I = [[1 if a == b else 0 for b in range(n)] for a in range(n)]
#    48      # parity J: index inversion j -> -j mod n
#    49      J = [[1 if b == (-a) % n else 0 for b in range(n)] for a in range(n)]
#    50
#    51      l1 = (F2 == J) and (F4 == I) and (F2 != I)
#    52
#    53      # L2: chart shadow. Charts = the primal/dual pair; F steps the cardinal
#   [PASS] lift.L1  (deciding)             2 exact micro-checks
#   [PASS] lift.L2  (corroborating)        2 exact micro-checks
#   [PASS] lift.L3  (corroborating)        2 exact micro-checks
#   [PASS] lift.L4  (corroborating)        2 exact micro-checks
#   [PASS] lift.L5  (corroborating)        2 exact micro-checks
# 10:D3: VERIFIED — 5 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:D6 [T] — the deciding family dom.A
# The flagged readings over the counts: $\unitE=[h][f]=\Iq\unitT^{-1}$, $[p]=\unithbar[k]=\Iq\unitL^{-1}$, one
# quantity per pair, the flagged reading one capacity step above its count; $[S]=\unitE\unitT=\Iq$ and every
# phase count neutral, $\unitE\unitT\unithbar^{-1}=1$; the absolute unit is horizon-inaccessible (no monomial
# of a window $H\ll\kap$ expresses the flag) and becomes visible at $\kap\le H<2\kap$.
from frc_10_dimensions import row; row("10:D6")
# Out:
# — verify_domains.py:101 (the check that decides 10:D6; family dom.A)
#   101      # row 10:D6
#   102      E_dom = dmul(FLAG, dinv(T))                       # [E] = Iq T^-1
#   103      p_dom = dmul(FLAG, dinv(L))                       # [p] = Iq L^-1
#   104      v_dom = dmul(L, dinv(T))                          # [v] = L T^-1
#   105      m_dom = dmul(E_dom, dinv(dpow(v_dom, 2)))         # [m] = [E][v]^-2
#   106      check("[m] = Iq L^-2 T", m_dom == ((-2) % P, 1, 1))
#   107      F_dom = dmul(m_dom, dmul(L, dpow(dinv(T), 2)))    # [F] = [m][a]
#   108      check("[F] = Iq L^-1 T^-1", F_dom == ((-1) % P, (-1) % (P - 1), 1))
#   109      S_dom = dmul(E_dom, T)
#   110      check("[S] = Iq (action carries the flag)", S_dom == FLAG)
#   111      check("phase count neutral: [E][T][hbar]^-1 = 1", dmul(S_dom, dinv(FLAG)) == ONE)
#   112      G_dom = dmul(F_dom, dmul(dpow(L, 2), dinv(dpow(m_dom, 2))))
#   113      check("[G] = Iq^-1 L^5 T^-3", G_dom == (5, (-3) % (P - 1), 3))
#   114      check("Planck area flag-free: [G][hbar][c]^-3",
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:D6: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:E2 [T] — the deciding family dom.B
# One crossing, one action, and pairing closure: $\lP\pP=\tPl\EP=\hbar$ (the two faces of $c$ and $\hbar$
# differ by the single relation $\ell p=tE$); the cross-domain relations reduce to the two generators $c$,
# $\hbar$, the mixed products their monomials, $|k_B|=\hbar/c$ derived; the relation lattice over
# $\{\lP,\tPl,\hbar\}$ has rank two and $k_B$, $\lP\EP$ add nothing; $4-1=3$ free scales in bijection with
# $\{c,\hbar,G\}$, the classical arity derived.
from frc_10_dimensions import row; row("10:E2")
# Out:
# — verify_domains.py:180 (the check that decides 10:E2; family dom.B)
#   180      # row 10:E2
#   181      # pairing lattice mod the relation has rank TWO: mix = hbar - c, lE = hbar + c
#   182      check("mix = hbar' - c' (exponent identity: k_B derived)",
#   183            mix_vec == sub(hbar_vec2, c_vec2))
#   184      check("pairing rank 2 mod relation: rank{c,hbar,rel} = 3",
#   185            rank_int([c_vec, hbar_vec, rel]) == 3)
#   186      check("mix adds nothing: rank{c,hbar,mix,rel} = 3",
#   187            rank_int([c_vec, hbar_vec, mix_vec, rel]) == 3)
#   188      check("lE adds nothing: rank{c,hbar,mix,lE,rel} = 3",
#   189            rank_int([c_vec, hbar_vec, mix_vec, lE_vec, rel]) == 3)
#   190
#   191      # row 10:E3
#   192      # numeric instantiation with the identity enforced: choose l,t,p free, E = l*p/t
#   193      l, t, p = Fr(3, 7), Fr(2, 5), Fr(11, 4)
#   [PASS] dom.B    (deciding)             30 exact micro-checks
# 10:E2: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:E3 [T] — the deciding family dom.B
# The cancellation identity $|k_B|c=\hbar$ at the unit face, $(\pP\tPl)(\lP/\tPl)=\lP\pP$; mass derived,
# $m_P=\pP/c=\EP/c^{2}$; the temperature horizon $\Theta_P=\EP/|k_B|$; the flag positions $(0,0,1,1)$ and the
# closure of every quartet relation on the flag component; no $\hbar$ of space and time.
from frc_10_dimensions import row; row("10:E3")
# Out:
# — verify_domains.py:191 (the check that decides 10:E3; family dom.B)
#   191      # row 10:E3
#   192      # numeric instantiation with the identity enforced: choose l,t,p free, E = l*p/t
#   193      l, t, p = Fr(3, 7), Fr(2, 5), Fr(11, 4)
#   194      E = l * p / t
#   195      c_u, hbar_u = l / t, l * p
#   196      check("unit face: c = l/t = E/p", c_u == E / p)
#   197      check("unit face: hbar = l p = t E", hbar_u == t * E)
#   198      check("cancellation: (p t)(l/t) = l p  [k_B c = -hbar]", (p * t) * (l / t) == hbar_u)
#   199      check("mixed partner: l E = hbar c", l * E == hbar_u * c_u)
#   200      m_P = p / c_u
#   201      check("m_P = p/c = E/c^2", m_P == E / c_u ** 2)
#   202      G_num = hbar_u * c_u / m_P ** 2
#   203      check("G = hbar c / m_P^2 = l^2 c^3 / hbar", G_num == l ** 2 * c_u ** 3 / hbar_u)
#   204      # bijection {c, hbar, G} <-> quartet: recover the free scale from G
#   [PASS] dom.B    (deciding)             30 exact micro-checks
# 10:E3: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:E4 [T] — the deciding family dom.C
# The defining congruences, pair form: on the Carrier chart $2G+1\equiv0$, $2c^{2}\equiv1$,
# $\hbar^{2}\equiv-1$, $k_B^{2}\equiv-2\pmod\Om$ determine the constants uniquely at pair level --- $G=2\dS$
# exact, the quadratics each with exactly two roots $\{x,-x\}$ (admissibility guarantees the residues:
# $\Om\equiv1\bmod4$, $\dS$ even for $2$, hence $-2$) --- and the linkage $\{\pm k_B\}\{\pm c\}=\{\pm\hbar\}$
# is derived at pair level; the root pair of $-1$ is $\{\hbar,h\}$ with $h=2\pi\hbar\equiv-\hbar$. Exhaustive
# on both Carriers.
from frc_10_dimensions import row; row("10:E4")
# Out:
# — verify_domains.py:257 (the check that decides 10:E4; family dom.C)
#   257      # row 10:E4
#   258      # congruence 1: 2G + 1 = 0 -- linear, unique
#   259      G_pin = [x for x in (pow(2, -1, Om) * (Om - 1) % Om,) ]
#   260      G_val = (Om - 1) // 2
#   261      check("congruence 2G+1=0 unique: G = 2S = 1,204,280", (2 * G_val + 1) % Om == 0 and G_val == 2 * S == 1_204_280)
#   262
#   263      # quadratic defining congruences: exhaustive-root verification via the known values
#   264      hbar_val = 18_688
#   265      kB_val = 1_880_160
#   266      check("congruence hbar^2 = -1", (hbar_val * hbar_val) % Om == Om - 1)
#   267      check("congruence k_B^2 = -2", (kB_val * kB_val) % Om == Om - 2)
#   268      c2 = (2 * S + 1) % Om
#   269      check("congruence 2c^2 = 1: c^2 = 2S+1", (2 * c2) % Om == 1)
#   270      # each quadratic congruence has exactly two roots: x and Om - x
#   [PASS] dom.C    (deciding)             13 exact micro-checks
#   [PASS] dom.D    (corroborating)        50 exact micro-checks
#   [PASS] dom.H    (corroborating)        27 exact micro-checks
# 10:E4: VERIFIED — 3 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:E5 [T] — the deciding family dom.H
# Pair consequences and representative inertness: $G=-c^{2}$, $G^{2}\equiv4^{-1}$, $\hbar^{4}\equiv1$,
# $(k_Bc)^{2}\equiv-1$, and $\hbar cG^{-1}$ lands in $\{\pm k_B\}$; of the eight sign assignments exactly the
# four with $\sigma_\hbar=\sigma_c\sigma_k$ are admissible, a $(\Z/2)^{2}$, every identity holding on each and
# the $\hbar$-flip relabelling within $\{\hbar,h\}$; what a bounded observer registers is exactly the
# pair-inert content.
from frc_10_dimensions import row; row("10:E5")
# Out:
# — verify_domains.py:580 (the check that decides 10:E5; family dom.H)
#   580          # row 10:E5
#   581      # representative inertness: exactly the assignments with s_h = s_c*s_k are
#   582          # admissible (a (Z/2)^2 group), and every checked identity holds on each
#   583          admissible_count = 0
#   584          for s_c in (1, -1):
#   585              for s_h in (1, -1):
#   586                  for s_k in (1, -1):
#   587                      hb2, c2_, kB2 = (s_h * R["hbar"]) % Om_, (s_c * R["c"]) % Om_, (s_k * R["kB"]) % Om_
#   588                      quad = ((2 * c2_ * c2_) % Om_ == 1 and (hb2 * hb2) % Om_ == Om_ - 1
#   589                              and (kB2 * kB2) % Om_ == Om_ - 2)
#   590                      link = (kB2 * c2_) % Om_ == (Om_ - hb2) % Om_
#   591                      if quad and link:
#   592                          admissible_count += 1
#   593                          h2 = (Om_ - hb2) % Om_
#   [PASS] dom.D    (corroborating)        50 exact micro-checks
#   [PASS] dom.H    (deciding)             27 exact micro-checks
# 10:E5: VERIFIED — 2 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:E9 [T] — the deciding family dom.D
# The minimal admissible pair: under the programme's admissibility predicate ($\p=4\kap+1$ prime, $\kap>1$;
# $\Om=4\dS+1$ prime, $\dS$ even, $\dS\equiv1\bmod3$; $\p^{2}<\Om$) the smallest instance is
# $(\p,\Om)=(13,233)$, by exhaustive scan, with the counterfactuals: dropping the mod-$3$ clause admits
# $(13,193)$, dropping $\kap>1$ admits $(5,41)$, $\kap=2$ gives the composite $9$.
from frc_10_dimensions import row; row("10:E9")
# Out:
# — verify_domains.py:341 (the check that decides 10:E9; family dom.D)
#   341      # row 10:E9
#   342      # minimality scan under the complete predicate (Appendix A)
#   343      def admissible(p_, Om__):
#   344          kap_ = (p_ - 1) // 4
#   345          S__ = (Om__ - 1) // 4
#   346          return (kap_ > 1 and is_prime(p_) and p_ % 4 == 1
#   347                  and Om__ % 4 == 1 and is_prime(Om__)
#   348                  and S__ % 2 == 0 and S__ % 3 == 1
#   349                  and p_ * p_ < Om__)
#   350      adm = [(p_, Om__) for p_ in range(5, 40, 4) for Om__ in range(p_ * p_ + 1, 234)
#   351             if admissible(p_, Om__)]
#   352      check("minimality: (13,233) admissible", (13, 233) in adm)
#   353      check("minimality: no admissible pair below 233", min(o for _, o in adm) == 233)
#   354      check("counterfactual: dropping mod-3 admits (13,193)",
#   [PASS] dom.D    (deciding)             50 exact micro-checks
# 10:E9: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:F2 [T] — the deciding family dom.A
# The mechanical and gravitational domains: $[m]=\Iq\unitL^{-2}\unitT$; $[a]=\unitL\unitT^{-2}$,
# $[F]=\Iq\unitL^{-1}\unitT^{-1}$, $[p]=\Iq\unitL^{-1}$, $[S]=\Iq$, $[P]=\Iq\unitT^{-2}$,
# $[\text{pressure}]=\Iq\unitL^{-3}\unitT^{-1}$; $[G]=\Iq^{-1}\unitL^{5}\unitT^{-3}$; the geometric
# conversions $[G\hbar/c^{3}]=\unitL^{2}$, $[Gm/c^{2}]=\unitL$, $[Gm/c^{3}]=\unitT$, $[G\rho_m]=\unitT^{-2}$;
# mass derived, not primitive.
from frc_10_dimensions import row; row("10:F2")
# Out:
# — verify_domains.py:92 (the check that decides 10:F2; family dom.A)
#    92      # row 10:F2
#    93      # derived domains
#    94      def dpow(a, k):
#    95          out = ONE
#    96          step = a if k >= 0 else dinv(a)
#    97          for _ in range(abs(k)):
#    98              out = dmul(out, step)
#    99          return out
#   100
#   101      # row 10:D6
#   102      E_dom = dmul(FLAG, dinv(T))                       # [E] = Iq T^-1
#   103      p_dom = dmul(FLAG, dinv(L))                       # [p] = Iq L^-1
#   104      v_dom = dmul(L, dinv(T))                          # [v] = L T^-1
#   105      m_dom = dmul(E_dom, dinv(dpow(v_dom, 2)))         # [m] = [E][v]^-2
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:F2: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:F3 [T] — the deciding family dom.D
# Temperature carries the acceleration domain: $[\Theta]=\unitE[k_B]^{-1}=\unitL\unitT^{-2}=[a]$, flag-free;
# the Unruh combination $\hbar a/c\,k_B$ closes flag-free in the algebra; neither mass nor temperature is
# primitive, the classical $M$-$L$-$T$-plus-thermal system the torsion-free shadow of two generators plus the
# flag.
from frc_10_dimensions import row; row("10:F3")
# Out:
# — verify_domains.py:361 (the check that decides 10:F3; family dom.D)
#   361      # row 10:F3
#   362      # temperature and Unruh closures in (r, s, j) bookkeeping
#   363      kB_dom = (-1, 1, 1)                    # Iq L^-1 T
#   364      E_dom3 = (0, -1, 1)                    # Iq T^-1
#   365      acc = (1, -2, 0)
#   366      Theta = tuple(a - b for a, b in zip(E_dom3, kB_dom))
#   367      check("[Theta] = [E][k_B]^-1 = L T^-2, flag-free", Theta == acc)
#   368      c_dom3 = (1, -1, 0)
#   369      hb_dom3 = (0, 0, 1)
#   370      unruh = tuple(h + a - c - k for h, a, c, k in zip(hb_dom3, acc, c_dom3, kB_dom))
#   371      check("Unruh closure: [hbar a / (c k_B)] = [Theta]", unruh == acc)
#   372
#   373      # crossing-degree recovery (Cor recovery-crossings)
#   374      def embed(u, a, b):
#   [PASS] dom.D    (deciding)             50 exact micro-checks
# 10:F3: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:F4 [T] — the deciding family dom.A
# Count-valued comparisons are flag-free: every ratio of two quantities of equal crossing degree ($Gm/r^{3}$,
# the phase exponent $[E][T]/[\hbar]$) is a neutral or flag-free label, the flag entering unitful measures
# only; $F/a=[m]$, crossing degrees $1$ and $0$, is the flagged boundary case.
from frc_10_dimensions import row; row("10:F4")
# Out:
# — verify_domains.py:120 (the check that decides 10:F4; family dom.A)
#   120      # row 10:F4
#   121      check("[Gm/r^3] = T^-2 flag-free",
#   122            dmul(G_dom, dmul(m_dom, dpow(dinv(L), 3))) == (0, (-2) % (P - 1), 0))
#   123      check("Compton flag-free: [m][c][hbar]^-1 = L^-1",
#   124            dmul(m_dom, dmul(v_dom, dinv(FLAG))) == ((-1) % P, 0, 0))
#   125
#   126      # fibrewise addition / neutral criterion / local recovery
#   127      # row 10:C3
#   128      check("squaring leaves fibre: dom(Q) != dom(Q^2) for [L]", L != dpow(L, 2))
#   129      H = 5
#   130      # row 10:G1, 10:G3
#   131      check("local recovery bound: p-1 > 2H", P - 1 > 2 * H)
#   132      pairs = [(r, s) for r in range(-H, H + 1) for s in range(-H, H + 1)]
#   133      images = {(r % P, s % (P - 1)) for (r, s) in pairs}
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:F4: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:F5 [T|D] — the deciding family dom.G
# The electromagnetic domain: with the Coulomb constant neutral (declared),
# $[q]^{2}=\unitE\unitL=\Iq\unitL\unitT^{-1}$; charge is an integer degree on the lift realised as
# $\unitL^{2\kap+1}\unitT^{(\kap-1)/2}$, existing iff $\kap$ is odd, unique up to $\Iq^{2}$, never
# window-covariant ($|r|=2\kap$); no further generator within C1's two charts; on the even capacities no label
# squares to $[q]^{2}$.
from frc_10_dimensions import row; row("10:F5")
# Out:
# — verify_domains.py:535 (the check that decides 10:F5; family dom.G)
#   535      # row 10:F5
#   536      check("charge: [q]^2 = [E][L] = I_q [L][T]^-1 = (1, 2) on F_13, its roots exactly (7,1) and (7,7), differing by the half-period (0, 6)",
#   537            ((0 + 1) % 13, (3 - 1 + 0) % 12) == (1, 2) and charge_roots(3) == [(7, 1), (7, 7)] and ((7 - 7) % 13, (7 - 1) % 12) == (0, 6))
#   538      check("charge: the roots exist iff kappa is odd, then exactly (2 kappa+1, (kappa-1)/2) and its half-period partner (every prime p = 4 kappa+1, kappa <= 30)",
#   539            all((charge_roots(k) == sorted([(2 * k + 1, (k - 1) // 2), (2 * k + 1, (k - 1) // 2 + 2 * k)])) if k % 2 else charge_roots(k) == []
#   540                for k in range(1, 31) if all((4 * k + 1) % d for d in range(2, 4 * k + 1))))
#   541      check("charge: the space exponent 2^-1 = 2 kappa+1 = -2 kappa is the meridian half-turn, |r| = 2 kappa, on p = 13, 29, 173, 229",
#   542            all((2 * (2 * k + 1)) % (4 * k + 1) == 1 and (2 * k + 1) - (4 * k + 1) == -2 * k for k in (3, 7, 43, 57)))
#   543      check("charge: on the lift [q]^2 = (1,-1;1) has no half; [phi]^2 = [q]^2 [L]^-2 = [F], [E_field]^2 = [F]^2 [q]^-2 = the energy density, e^2/(hbar c) neutral",
#   544            all(c % 2 for c in (1, -1, 1)) and (1 - 2, -1, 1) == (-1, -1, 1) and (2 * (-1) - 1, 2 * (-1) + 1, 2 - 1) == (0 - 3, -1, 1)
#   545            and (0 + 1, 0 - 1, 1 + 0) == (1, -1, 1))
#   546      check("charge: the dilation character m^-r at r = 2 kappa+1 is m^-1 (m|p) (Euler); a non-square dilation flips the sign, never window-covariant (p = 13, 29)",
#   547            all(pow(m, -(2 * k + 1), 4 * k + 1) == (pow(m, -1, 4 * k + 1) * pow(m, 2 * k, 4 * k + 1)) % (4 * k + 1)
#   548                and pow(m, 2 * k, 4 * k + 1) == (1 if any((x * x) % (4 * k + 1) == m for x in range(1, 4 * k + 1)) else 4 * k)
#   [PASS] dom.G    (deciding)             21 exact micro-checks
# 10:F5: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:G1 [T] — the deciding family dom.A
# Local recovery: for an exponent horizon $H$ with $4\kap>2H$ the modular labels distinguish every
# conventional pair $|r|,|s|\le H$; the flagged sector is recovered through the crossing degree,
# $M^{u}L^{a}T^{b}\mapsto(a-2u,\,b+u;\,u)$ injective and windowed-faithful.
from frc_10_dimensions import row; row("10:G1")
# Out:
# — verify_domains.py:130 (the check that decides 10:G1; family dom.A)
#   130      # row 10:G1, 10:G3
#   131      check("local recovery bound: p-1 > 2H", P - 1 > 2 * H)
#   132      pairs = [(r, s) for r in range(-H, H + 1) for s in range(-H, H + 1)]
#   133      images = {(r % P, s % (P - 1)) for (r, s) in pairs}
#   134      check("local recovery: all |r|,|s| <= 5 distinguished", len(images) == len(pairs))
#   135      # the energy--momentum relation E^2 = p^2 c^2 + m^2 c^4: its three terms in one fibre, at crossing degree two (the
#   136      # half-period sector) -- Example ex:dispersion, row 10:G3
#   137      E2 = dpow(E_dom, 2); pc2 = dpow(dmul(p_dom, v_dom), 2); mc4 = dpow(dmul(m_dom, dpow(v_dom, 2)), 2)
#   138      check("dispersion: [E]^2 = [pc]^2 = [mc^2]^2, one fibre at sector 2", E2 == pc2 == mc4 and E2[2] == 2)
#   139
#   140      # B. the quartet at the unit face (exact rationals over free scales)
#   141      family('dom', 'B')
#   142      # Represent horizons as exponent vectors over (l, t, p, E) and verify the
#   143      # relation lattice; then instantiate with exact rationals satisfying the
#   [PASS] dom.A    (deciding)             33 exact micro-checks
#   [PASS] dom.D    (corroborating)        50 exact micro-checks
# 10:G1: VERIFIED — 2 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:G2 [T] — the deciding family dom.G
# The window ladder: coherence $2\sqrt\kap$ below recovery $\kap/2$ below flag inaccessibility $\kap$ below
# covariance $2\kap$, nested strictly for every $\kap\ge17$ and failing for the toy $\kap=3$, all orderings by
# integer squares; the coherence identity $(2\sqrt\kap)^{2}=\p-1$ and the totality closure
# $(2\sqrt\dS)^{2}=\Om-1$.
from frc_10_dimensions import row; row("10:G2")
# Out:
# — verify_domains.py:498 (the check that decides 10:G2; family dom.G)
#   498      # row 10:G2
#   499      # window ladder: nested for kappa >= 17; toy fails.  All orderings exact:
#   500      # 2 sqrt(k) < k/2  <=>  (4 sqrt(k))^2 < k^2  <=>  16 k < k^2  <=>  k > 16.
#   501      def ladder(k):
#   502          return 16 * k < k * k and 0 < k
#   503      check("r04: ladder nested for kappa=17,387,602140 (integer-square ordering)",
#   504            all(ladder(k) for k in (17, 387, 602140)))
#   505      check("r04: toy kappa=3 below nesting threshold", not ladder(3))
#   506      check("r04: coherence window identity (2 sqrt kappa)^2 = 4 kappa = p-1 exactly",
#   507            all((2 * 2 * k == 4 * k) and (4 * k == (4 * k + 1) - 1) for k in (3, 387, 602140)))
#   508      check("r04: totality closure exact: (2 sqrt S)^2 = Om - 1",
#   509            4 * 602140 == 2408561 - 1)
#   510
#   511      # F/a is flagged (equal-crossing-degree correction): [F]=(-1,-1;1), [a]=(1,-2;0)
#   [PASS] dom.G    (deciding)             21 exact micro-checks
# 10:G2: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:G3 [T] — the deciding family dom.A
# The worked examples: $\kap=3$, $H=5$, $12>10$ so every pair in $[-5,5]^{2}$ is distinguished; kinetic energy
# $[m][v]^{2}=[E]$; $Q+Q^{2}$ inhomogeneous; the phase exponent neutral; flag arithmetic ($G\hbar/c^{3}$
# flag-free, $\Iq^{2}=\unitT^{\pi}$); the Schwarzschild length $[Gm/c^{2}]=\unitL$; the gravitational
# frequency $[Gm/r^{3}]=\unitT^{-2}$; the energy--momentum relation $E^{2}=p^{2}c^{2}+m^{2}c^{4}$ homogeneous
# at crossing degree two, its massless case $E=pc$ at crossing degree one.
from frc_10_dimensions import row; row("10:G3")
# Out:
# — verify_domains.py:130 (the check that decides 10:G3; family dom.A)
#   130      # row 10:G1, 10:G3
#   131      check("local recovery bound: p-1 > 2H", P - 1 > 2 * H)
#   132      pairs = [(r, s) for r in range(-H, H + 1) for s in range(-H, H + 1)]
#   133      images = {(r % P, s % (P - 1)) for (r, s) in pairs}
#   134      check("local recovery: all |r|,|s| <= 5 distinguished", len(images) == len(pairs))
#   135      # the energy--momentum relation E^2 = p^2 c^2 + m^2 c^4: its three terms in one fibre, at crossing degree two (the
#   136      # half-period sector) -- Example ex:dispersion, row 10:G3
#   137      E2 = dpow(E_dom, 2); pc2 = dpow(dmul(p_dom, v_dom), 2); mc4 = dpow(dmul(m_dom, dpow(v_dom, 2)), 2)
#   138      check("dispersion: [E]^2 = [pc]^2 = [mc^2]^2, one fibre at sector 2", E2 == pc2 == mc4 and E2[2] == 2)
#   139
#   140      # B. the quartet at the unit face (exact rationals over free scales)
#   141      family('dom', 'B')
#   142      # Represent horizons as exponent vectors over (l, t, p, E) and verify the
#   143      # relation lattice; then instantiate with exact rationals satisfying the
#   [PASS] dom.A    (deciding)             33 exact micro-checks
# 10:G3: VERIFIED — 1 family record(s)

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
# 10:G4 [T] — the deciding family dom.G
# Buckingham's count: on the integer lift the neutral monomials of $N$ quantities are the kernel of their
# $N\times3$ label matrix, $N-\operatorname{rank}$ independent dimensionless products with rank $\le3$, the
# classical count for quantities whose classical dimensions lie in $M$-$L$-$T$ and the derived-$k_B$ count for
# thermal ones; on the window $2H<\kap$, $|j|\le1$ lifted and realized neutrality coincide; the pendulum
# $(T,\ell,g,m)$: rank $3$, one product.
from frc_10_dimensions import row; row("10:G4")
# Out:
# — verify_domains.py:526 (the check that decides 10:G4; family dom.G)
#   526      # row 10:G4
#   527      check("Buckingham: pendulum (T, l, g, m) rank 3, one product T^2 g/l with label (0,0;0)", rank_int(pend) == 3 and lab_ == (0, 0, 0))
#   528      # The electromagnetic domain (Remark rem:electromagnetic, row 10:F5): with the Coulomb constant neutral, [q]^2 = [E][L] =
#   529      # I_q [L][T]^-1, on the shell (1, kappa-1), on the lift (1,-1;1). Its square roots in D_p = Z_p x Z_{4 kappa}: the space half
#   530      # 2^-1 = 2 kappa + 1 = -2 kappa (the meridian half-turn); the phase equation 2s = kappa-1 (mod 4 kappa) is solvable iff kappa
#   531      # is odd, then two roots differing by the half-period (0, 2 kappa) = I_q^2; on the lift no root at all (odd coordinates).
#   532      def charge_roots(k):
#   533          p_, n_ = 4 * k + 1, 4 * k
#   534          return sorted((r, s) for r in range(p_) for s in range(n_) if ((2 * r) % p_, (2 * s) % n_) == (1, (k - 1) % n_))
#   535      # row 10:F5
#   536      check("charge: [q]^2 = [E][L] = I_q [L][T]^-1 = (1, 2) on F_13, its roots exactly (7,1) and (7,7), differing by the half-period (0, 6)",
#   537            ((0 + 1) % 13, (3 - 1 + 0) % 12) == (1, 2) and charge_roots(3) == [(7, 1), (7, 7)] and ((7 - 7) % 13, (7 - 1) % 12) == (0, 6))
#   538      check("charge: the roots exist iff kappa is odd, then exactly (2 kappa+1, (kappa-1)/2) and its half-period partner (every prime p = 4 kappa+1, kappa <= 30)",
#   539            all((charge_roots(k) == sorted([(2 * k + 1, (k - 1) // 2), (2 * k + 1, (k - 1) // 2 + 2 * k)])) if k % 2 else charge_roots(k) == []
#   [PASS] dom.G    (deciding)             21 exact micro-checks
# 10:G4: VERIFIED — 1 family record(s)

# %% [markdown]
# ## Summary
#
# The rows above are the paper's python-witnessed predicates; the whole package, family by family, is `run_all.py`
# (13 family checks, 217 exact micro-checks, `results.json`).

# %%
# !pip install -q frc-10-dimensions --find-links https://www.finitering.space/pkg/
from frc_10_dimensions import verify_all
assert verify_all(), "a family check failed"
print("all family checks pass")
# Out:
# SUMMARY: 13/13 checks passed (217 exact micro-checks)
# all family checks pass

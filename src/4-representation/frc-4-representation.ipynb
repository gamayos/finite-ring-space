# %% [markdown]
# ## Universal Latent Representation in Finite Ring Continuum, [Akhtman, Entropy 2026](https://doi.org/10.3390/e28010040)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Appendix A; [finitering.space/4-representation/](https://finitering.space/4-representation/)): it runs the
# blocks of [`representation.py`](https://finitering.space/src/4-representation/representation.html) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 15 s).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:B4 (p04008) [T] — the deciding check A1
# Adequacy makes the observation map injective on the latent domain: $g_m(z)=g_m(z')$ forces $z=z'$; $\mathcal
# Z$ is the domain modality $m$ resolves completely.
from frc_4_representation import predicate; predicate("4:B4")
# Out:
#   [PASS] A1   EXACT  [4:B4] adequacy (E o g bijective Z -> W) forces g injective; adequate E number |Z|! |W|^(|X|-|Z|) for injective g, 0 otherwise  --  123 observation maps over 7 model sizes; |Z|=1,|X|=1: 1 maps g; |Z|=1,|X|=2: 2 maps g; |Z|=2,|X|=2: 4 maps g
#   [PASS] A2   EXACT  [4:B5] psi = phi_2 o phi_1^-1 is the unique bijection W1 -> W2 with E2 o g = psi o E1 o g; E2 = psi o E1 on all of X only when X = g(Z)  --  8096 pairs of adequate representations; off g(Z) the equation fails in 5232 of 7872 pairs with X != g(Z)
#   [PASS] A3   EXACT  [4:B5] Lemma 1 as images: psi(E1(X)) = E2(X) = W2 for every pair of adequate representations  --  7872 pairs
#   [PASS] A4   EXACT  [4:C1, 4:C2] Theorem 1: psi_m = iota_m o phi_m injective for every injective iota_m; Psi_{m->n} a bijection of the images with inverse Psi_{n->m}; iota_m = phi_m^-1 makes every chart the inclusion of Z  --  Z of size 3 in F_5, two modalities, 3600 pairs of embeddings (60 x 60)
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:B5 (p04009) [T] — the deciding check A2
# Uniqueness up to bijection: for adequate $E_1$, $E_2$ of one $g$, $\psi=\varphi_2\circ\varphi_1^{-1}:W_1\to
# W_2$ is a bijection with $E_2\circ g=\psi\circ E_1\circ g$ --- $E_2=\psi\circ E_1$ on $g(\mathcal Z)$, on
# all of $\mathcal X$ when $\mathcal X=g(\mathcal Z)$; $\psi$ is the unique map with this property.
from frc_4_representation import predicate; predicate("4:B5")
# Out:
# — representation.py:221 (the check that decides 4:B5: A2)
#   221      # 4:B5 (p04009)
#   222      check("A2", "psi = phi_2 o phi_1^-1 is the unique bijection W1 -> W2 with E2 o g = psi o E1 o g; E2 = psi o E1 on all of X only when X = g(Z)", ok,
#   223               f"{n_pairs} pairs of adequate representations; off g(Z) the equation fails in {n_off} of {n_total_off} pairs with X != g(Z)")
#   224
#   225      # A3 Lemma 1 at the level of images: psi(E1(X)) = E2(X) = W2
#   226      ok = True; n = 0
#   227      for nZ, nX in [(2, 3), (3, 4)]:
#   228          Z, X, W1 = models(nZ, nX, nZ); W2 = [f"v{i}" for i in range(nZ)]
#   229          for g in maps(Z, X):
#   230              if not injective(g, Z): continue
#   231              ads1 = [E for E in maps(X, W1) if adequate(g, E, Z, W1)]
#   232              ads2 = [E for E in maps(X, W2) if adequate(g, E, Z, W2)]
#   233              for E1 in ads1:
#   234                  inv1 = inverse({z: E1[g[z]] for z in Z}, Z)
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:B6 (p04010) [T] — the deciding check B1
# The embedding into the shell: $|W_m|=|\mathcal Z|\le\p$, so an injection $\iota_m:W_m\hookrightarrow\mathcal
# U_t$ exists --- the one place finiteness enters; canonically $\iota_m=\varphi_m^{-1}$ followed by the
# inclusion; $\psi_m:=\iota_m\circ\varphi_m:\mathcal Z\hookrightarrow\mathcal U_t$ is modality $m$'s chart of
# $\mathcal Z$.
from frc_4_representation import predicate; predicate("4:B6")
# Out:
#   [PASS] B1   EXACT  [4:B6] |W_m| = |Z| <= p: the representation space embeds in the shell; the least hosting shell of N states is the least prime p = 4k+1 >= N; the canonical iota_m = phi_m^-1 exhibited on F_13  --  N=13->13, 14->17, 30->37, 42->53, 54->61; Z of size 7 in F_13, three modalities with codes in Z^2, Z^3, Z^5
#   [PASS] B2   EXACT  [4:C5] the arithmetic charts of the shell are its p(p-1) affine frames; Psi_{m->n} between two frames is one invertible affine map (simply transitive)  --  p=5: 20 frames; p=13: 156 frames; p=17: 272 frames
#   [PASS] B3   EXACT  [4:C1, 4:C3] the F_13 instance: canonical charts are the inclusion; for random embeddings the transitions compose, Psi_{n->k} o Psi_{m->n} = Psi_{m->k}; the three lifts recover every latent state  --  50 random triples of embeddings W_m -> F_13; 27 observations lifted
# — representation.py:311 (the check that decides 4:B6: B1)
#   311      # 4:B6 (p04010)
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:C1 (p04011) [T] — the deciding check A4
# Theorem~\ref{thm:UST} (i), (ii): every chart $\psi_m$ is injective, and $\Psi_{m\to
# n}:=\psi_n\circ\psi_m^{-1}:\psi_m(\mathcal Z)\to\psi_n(\mathcal Z)$ is a well-defined bijection, with
# $\Psi_{n\to k}\circ\Psi_{m\to n}=\Psi_{m\to k}$ and $\Psi_{m\to m}$ the identity.
from frc_4_representation import predicate; predicate("4:C1")
# Out:
# — representation.py:262 (the check that decides 4:C1: A4)
#   262      # 4:C1 (p04011), 4:C2 (p04012)
#   263      check("A4", "Theorem 1: psi_m = iota_m o phi_m injective for every injective iota_m; Psi_{m->n} a bijection of the images with inverse Psi_{n->m}; iota_m = phi_m^-1 makes every chart the inclusion of Z", ok,
#   264               f"Z of size 3 in F_5, two modalities, {n} pairs of embeddings (60 x 60)")
#   265
#   266      # A5 Corollaries 1-2: the lifts
#   267      L1 = {x: inv1[E1[x]] for x in X1}; L2 = {x: inv2[E2[x]] for x in X2}
#   268      ok = all(L1[g1[z]] == z and L2[g2[z]] == z for z in Z)                                    # L_m o g_m = id
#   269      ok &= all((E1[x] == phi1[z]) == (L1[x] == z) for x in X1 for z in Z)                     # L_m x the unique z with E_m x = phi_m z
#   270      ok &= all(L1[g1[z]] == L2[g2[z]] for z in Z)                                             # cross-modal consistency
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:C2 (p04012) [T] — the deciding check A4
# Theorem~\ref{thm:UST} (iii): with $\iota_m=\varphi_m^{-1}$ every chart is the inclusion $\mathcal
# Z\hookrightarrow\mathcal U_t$ and $\psi(\mathcal Z)=\mathcal Z$; canonical structurally (unique once
# $\mathcal Z$ is fixed), not algorithmically; ``subspace'' means subset.
from frc_4_representation import predicate; predicate("4:C2")
# Out:
# — representation.py:262 (the check that decides 4:C2: A4)
#   262      # 4:C1 (p04011), 4:C2 (p04012)
#   263      check("A4", "Theorem 1: psi_m = iota_m o phi_m injective for every injective iota_m; Psi_{m->n} a bijection of the images with inverse Psi_{n->m}; iota_m = phi_m^-1 makes every chart the inclusion of Z", ok,
#   264               f"Z of size 3 in F_5, two modalities, {n} pairs of embeddings (60 x 60)")
#   265
#   266      # A5 Corollaries 1-2: the lifts
#   267      L1 = {x: inv1[E1[x]] for x in X1}; L2 = {x: inv2[E2[x]] for x in X2}
#   268      ok = all(L1[g1[z]] == z and L2[g2[z]] == z for z in Z)                                    # L_m o g_m = id
#   269      ok &= all((E1[x] == phi1[z]) == (L1[x] == z) for x in X1 for z in Z)                     # L_m x the unique z with E_m x = phi_m z
#   270      ok &= all(L1[g1[z]] == L2[g2[z]] for z in Z)                                             # cross-modal consistency
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:C3 (p04013) [T] — the deciding check A5
# The canonical lift $L_m:=\varphi_m^{-1}\circ E_m:\mathcal X_m\to\mathcal Z$ satisfies $L_m\circ
# g_m=\mathrm{id}_{\mathcal Z}$, and $L_m(x)$ is the unique $z$ with $E_m(x)=\varphi_m(z)$.
from frc_4_representation import predicate; predicate("4:C3")
# Out:
# — representation.py:272 (the check that decides 4:C3: A5)
#   272      # 4:C3 (p04013), 4:C4 (p04014)
#   273      check("A5", "Corollary 1: L_m = phi_m^-1 o E_m inverts g_m and L_m x is the unique z with E_m x = phi_m z; Corollary 2: L_m(g_m z) = L_n(g_n z), psi o L_m o g_m = psi", ok,
#   274               "the F_5 instance; the observation c (not in g_1(Z)) lifts to the state its code names")
#   275
#   276  # ------------------------------------------------------------------------------------------------------------
#   277  # block B: the shell as host, the frames as charts, the worked instance (4:B6, C1, C3, C5)
#   278  # B1: a representation space of the size of the latent domain embeds in the shell (|W_m| = |Z| ≤ p), the least
#   279  # shell hosting a domain of N states is the least prime p = 4κ+1 ≥ N (tabulated for N ≤ 60), and the canonical
#   280  # ι_m = φ_m⁻¹ is exhibited for Z ⊂ F_13 with three modalities whose representation spaces are quantised integer
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:C4 (p04014) [T] — the deciding check A5
# Cross-modal consistency: $\psi\circ L_m\circ g_m=\psi\circ L_n\circ g_n=\psi$ --- observations of one latent
# state lift to one point --- and $\iota_m(W_m)=\iota_n(W_n)=\psi(\mathcal Z)=\mathcal Z$.
from frc_4_representation import predicate; predicate("4:C4")
# Out:
# — representation.py:272 (the check that decides 4:C4: A5)
#   272      # 4:C3 (p04013), 4:C4 (p04014)
#   273      check("A5", "Corollary 1: L_m = phi_m^-1 o E_m inverts g_m and L_m x is the unique z with E_m x = phi_m z; Corollary 2: L_m(g_m z) = L_n(g_n z), psi o L_m o g_m = psi", ok,
#   274               "the F_5 instance; the observation c (not in g_1(Z)) lifts to the state its code names")
#   275
#   276  # ------------------------------------------------------------------------------------------------------------
#   277  # block B: the shell as host, the frames as charts, the worked instance (4:B6, C1, C3, C5)
#   278  # B1: a representation space of the size of the latent domain embeds in the shell (|W_m| = |Z| ≤ p), the least
#   279  # shell hosting a domain of N states is the least prime p = 4κ+1 ≥ N (tabulated for N ≤ 60), and the canonical
#   280  # ι_m = φ_m⁻¹ is exhibited for Z ⊂ F_13 with three modalities whose representation spaces are quantised integer
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:C5 (p04015) [T] — the deciding check B2
# Charts of the shell itself: for $\mathcal Z=\Fp$ the charts respecting the arithmetic are the frames
# $x\mapsto a+bx$ (1:C2), $\p(\p-1)$ of them, and $\Psi_{m\to n}$ between two frames is the one affine map
# carrying the first to the second (simply transitive) --- the corpus's coordinate systems are the paper's
# charts.
from frc_4_representation import predicate; predicate("4:C5")
# Out:
# — representation.py:333 (the check that decides 4:C5: B2)
#   333      # 4:C5 (p04015)
#   334      check("B2", "the arithmetic charts of the shell are its p(p-1) affine frames; Psi_{m->n} between two frames is one invertible affine map (simply transitive)", ok, "; ".join(det))
#   335
#   336      # B3 the F_13 instance end to end
#   337      ok = True
#   338      (X1, g1, W1, phi1, E1, i1), (X2, g2, W2, phi2, E2, i2), (X3, g3, W3, phi3, E3, i3) = mods
#   339      psi = [{z: io[ph[z]] for z in Z} for ph, io in ((phi1, i1), (phi2, i2), (phi3, i3))]
#   340      ok &= all(ps[z] == z for ps in psi for z in Z)                                            # canonical: every chart the inclusion
#   341      # general iota: random injective embeddings into F_13, the transitions and their composition law
#   342      for _ in range(50):
#   343          ios = [dict(zip(W, random.sample(range(p), len(W)))) for W in (W1, W2, W3)]
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:E1 (p04018) [T] — the deciding check C1
# The hypersphere [chart]: a Euclidean chart $\mathrm{Emb}:\mathcal Z\to\R^{d}$ equivariant for a symmetry
# acting transitively on $\mathcal Z$ and orthogonally on $\R^{d}$ has constant norm ---
# $\mathrm{Emb}(\mathcal Z)\subset S^{d-1}$. The shell's character chart $z\mapsto(\cos2\pi kz/\p,\sin2\pi
# kz/\p)_{k}$ is such a chart under translation, $\|\mathrm{Emb}(z)\|^{2}=\p-1$; in the shell's arithmetic
# $\sum_{k}\g^{kz}\g^{k(n-z)}=n$ for every $z$.
from frc_4_representation import predicate; predicate("4:E1")
# Out:
#   [PASS] C1   CHART  [4:E1] the character chart z -> (cos 2 pi k z/p, sin 2 pi k z/p)_k has |Emb(z)|^2 = p-1 for every z and is translation-equivariant (block rotations); a random chart is not on a sphere  --  p=5: |Emb|^2 = 4; p=13: |Emb|^2 = 12; p=17: |Emb|^2 = 16; p=29: |Emb|^2 = 28; random control: norm spread 9.3
#   [PASS] C2   EXACT  [4:E1] sum_k g^(kz) g^(k(n-z)) = n = p-1 in F_p for every z <= n and every generator; translation multiplies coordinate k by g^(ka)  --  p=5: 2 generators; p=13: 4 generators; p=17: 8 generators; p=29: 12 generators
#   [PASS] C3   CHART  [4:E2] grid points within Delta/2 of the sphere of radius R number ~ (R/Delta)^(d-1): least-squares exponents within 0.15 of d-1 at d = 2, 3  --  d=2: R = 10..100, counts 56..640, slope 1.05; d=3: R = 5..40, counts 350..20234, slope 1.96
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:E2 (p04019) [I] — the deciding check C3
# Quantisation [chart]: a digital embedding has coordinates in a finite $\mathcal Q\subset\R$; at step
# $\Delta$ the distinguishable points on a sphere of radius $R$ number $N(R)\sim C_d(R/\Delta)^{d-1}$ (grid
# counts fit exponent $d-1$ at $d=2,3$); at fixed $d$, $\Delta$ the capacity grows with $R$.
from frc_4_representation import predicate; predicate("4:E2")
# Out:
# — representation.py:424 (the check that decides 4:E2: C3)
#   424      # 4:E2 (p04019)
#   425      check("C3", "grid points within Delta/2 of the sphere of radius R number ~ (R/Delta)^(d-1): least-squares exponents within 0.15 of d-1 at d = 2, 3", ok, "; ".join(det), kind="CHART")
#   426
#   427      # C4 the Goedel code on the box {0..4}^3 over 2, 3, 5; reduction mod q
#   428      box = [(a, b, c) for a in range(5) for b in range(5) for c in range(5)]
#   429      G = {x: 2 ** x[0] * 3 ** x[1] * 5 ** x[2] for x in box}
#   430      ok = len(set(G.values())) == len(box) == 125
#   431      mx = max(G.values()); ok &= mx == 810000
#   432      q = mx + 1
#   433      while not is_prime(q): q += 1
#   434      ok &= q == 810013 and len({v % q for v in G.values()}) == 125
#   435      coll = {m: 125 - len({v % m for v in G.values()}) for m in (101, 1009, 10007, 100003)}
# ...

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
# 4:E3 (p04020) [T] — the deciding check C4
# Gödel collapse: for distinct primes $p_1,\dots,p_d$ the code $G(x)=\prod p_i^{x_i}$ is injective on $\N^{d}$
# (unique factorisation), and $G\bmod q$ stays injective on a finite set once $q$ exceeds its maximum;
# instance $d=3$, $x_i\le4$, primes $2,3,5$: $125$ codes, maximum $810\,000$, $q=810\,013$; signed coordinates
# are shifted first.
from frc_4_representation import predicate; predicate("4:E3")
# Out:
# — representation.py:437 (the check that decides 4:E3: C4)
#   437      # 4:E3 (p04020)
#   438      check("C4", "G(x) = 2^a 3^b 5^c is injective on {0..4}^3 (125 codes, max 810000); mod q = 810013 (the least prime above the maximum) injective by the bound; below it the bound gives nothing: mod 101 there are collisions", ok,
#   439               f"collisions below the maximum: {coll} (none at 1009, 10007, 100003 is the accident of these residues, not the bound)")
#   440
#   441      # C5 the two-prime core instance and signed coordinates
#   442      codes = {(a, b): 2 ** a * 3 ** b for a in range(21) for b in range(21)}
#   443      ok = len(set(codes.values())) == 441
#   444      signed = [(a, b, c) for a in range(-2, 3) for b in range(-2, 3) for c in range(-2, 3)]
#   445      Gs = {x: 2 ** (x[0] + 2) * 3 ** (x[1] + 2) * 5 ** (x[2] + 2) for x in signed}
#   446      ok &= len(set(Gs.values())) == 125 and max(Gs.values()) == 810000
# ...

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, check by check, is `python3 representation.py`
# (13 checks, `results.json`), `python3 -m frc_4_representation` once installed.

# %%
# !pip install -q frc-4-representation --find-links https://finitering.space/pkg/
from frc_4_representation import verify_all
assert verify_all(), "a check failed"
print("all checks pass")
# Out:
# SUMMARY: 13/13 checks passed
# all checks pass

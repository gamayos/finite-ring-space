# %% [markdown]
# ## Paradoxes of Infinity as Reductio ad Absurdum, [Akhtman, Preprints 2025](https://doi.org/10.20944/preprints202508.1744.v1)
#
# Each cell below verifies one predicate of the paper's predicate ledger (Appendix B; [finitering.space/5-reductio/](https://finitering.space/5-reductio/)): it runs the
# blocks of [`reductio.py`](https://finitering.space/src/5-reductio/) whose checks cite the predicate, prints the check and lists every record that cites it with its verdict. Any cell can be run first, or *Runtime → Run all* (≈ 60 s; the Goldbach frames of block A are the slow part).

# %% [markdown]
# Every cell is self-contained: its first line installs the package from the site (pip reports it already satisfied once it is there), its last runs the predicate.

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:B3 (p05007) [T] — the deciding check A2
# Witnessed independence: every three-element subset is satisfiable --- $Q$ itself ($\neg$Cmp, consistent by
# finitary means, the superexponential cost exact); $\mathrm{Th}(W_N)$ ($\neg$IR: consistent, complete,
# decidable, singly axiomatised, interpreting no $Q$ since every model of $Q$ is infinite); the inconsistent
# extension ($\neg$Cns); true arithmetic ($\neg$Eff). Four legs, all load-bearing.
from frc_5_reductio import predicate; predicate("5:B3")
# Out:
#   [PASS] A1   EXACT  [5:B5] Th(W_N) is complete and decidable: every sentence of the sample is decided by evaluation on N = 2..8; sigma_N is categorical — its models on a domain of size N are the N! copies of W_N (N <= 5)  --  10 sentences x 7 frames; N=2: 2 models of sigma_N on [0,N), all copies of W_N; N=3: 6 models of sigma_N on [0,N), all copies of W_N; N=4: 24 models of sigma_N on [0,N), all copies of W_N
#   [PASS] A2   EXACT  [5:B3] no finite model of Q: on N elements no successor map is injective and misses 0 (all N^N maps, N <= 7), so Th(W_N) does not interpret Q  --  N=1: 1 maps, 0 injective-avoiding-0; N=2: 4 maps, 0 injective-avoiding-0; N=3: 27 maps, 0 injective-avoiding-0; N=4: 256 maps, 0 injective-avoiding-0
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:B5 (p05009) [T] — the deciding check A1
# Per-frame completeness: $\mathrm{Th}(W_N)$ is consistent, complete and decidable, axiomatised by the
# categorical sentence $\sigma_N$; truth in any finite structure is decided by evaluation, and the theory of
# any structure is complete.
from frc_5_reductio import predicate; predicate("5:B5")
# Out:
# — reductio.py:300 (the check that decides 5:B5: A1)
#   300      # 5:B5 (p05009)
#   301      check("A1", "Th(W_N) is complete and decidable: every sentence of the sample is decided by evaluation on N = 2..8; sigma_N is categorical — its models on a domain of size N are the N! copies of W_N (N <= 5)", ok,
#   302               "10 sentences x 7 frames; " + "; ".join(det[:3]))
#   303
#   304      # A2 no finite model of Q: no successor on [0,N) is injective with 0 outside its image
#   305      ok = True; det = []
#   306      for N in range(1, 8):
#   307          found = 0
#   308          for S in itertools.product(range(N), repeat=N):
#   309              if len(set(S)) == N and 0 not in S: found += 1
#   310          ok &= found == 0
#   311          det.append(f"N={N}: {N**N} maps, 0 injective-avoiding-0")
#   312      # 5:B3 (p05007)
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:B6 (p05010) [T] — the deciding check A3
# Bounded stability, schema form: a $\Delta_0$ sentence $\varphi$ with bound $t(\varphi)$ has
# $W_N\models\varphi^{*}\iff\N\models\varphi$ for every $N>t(\varphi)$, each instance $\mathrm{St}(\varphi,M)$
# a finite conjunction of finite checks; proved for an explicit $\Delta_0$ language with $t(\varphi)$
# computed; Goldbach below $20$ has $t=400$ and value true (below $10$, $t=100$, decided by the kernel).
from frc_5_reductio import predicate; predicate("5:B6")
# Out:
# — reductio.py:333 (the check that decides 5:B6: A3)
#   333      # 5:B6 (p05010)
#   334      check("A3", "bounded stability: every Delta_0 sentence takes its standard value in every frame above t(phi) — the worked instance (Goldbach below 20, t = 400) in 40 frames above the bound, and a random sample; below the bound frames can disagree", ok,
#   335               f"Goldbach<=20: true, t(phi) = 400 (proved bound), empirical threshold N >= {thresh}; {n_forms} random sentences, {n_disagree} disagree below their bound")
#   336
#   337      # A4 the migration counts
#   338      ok = True; det = []
#   339      for s in (2, 3, 10):
#   340          for K in range(0, 21):
#   341              ok &= sum(s ** i for i in range(K + 1)) < s ** (K + 1)
#   342      for R, N in [(1, 2), (2, 3), (3, 5), (4, 5)]:
#   343          ok &= not any(len(set(f)) == N for f in itertools.product(range(R), repeat=N))   # no injection [0,N) -> [0,R)
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:C2 (p05013) [T] — the deciding check A4
# No internal mirror: fewer than $s^{K+1}$ records exist, so an agent with $s^{K+1}<N$ holds no injective
# representation of the domain of $W_N$ --- a proper part cannot mirror the whole (pigeonhole).
from frc_5_reductio import predicate; predicate("5:C2")
# Out:
# — reductio.py:347 (the check that decides 5:C2: A4)
#   347      # 5:C2 (p05013), 5:C3 (p05014)
#   348      check("A4", "records: sum_{i<=K} s^i < s^(K+1) (s = 2, 3, 10; K <= 20); no injection of N elements into R < N records (exhaustive); the certified fraction s^(K+1)/floor(c^L/2) falls to 0", ok, "; ".join(det))
#   349
#   350      # A5 the horizon separation: a run on C configurations halts within C steps or loops
#   351      ok = True; det = []
#   352      for C in range(1, 6):
#   353          for f in itertools.product(range(C), repeat=C):                   # every deterministic system; halting state = C-1 (fixed)
#   354              if f[C - 1] != C - 1: continue
#   355              for x in range(C):
#   356                  seen = []; y = x
#   357                  while y not in seen and len(seen) <= C:
#   358                      seen.append(y); y = f[y]
#   359                  halts = (C - 1) in seen
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:C3 (p05014) [T] — the deciding check A4
# Vanishing certified fraction: at least $c^{L}$ normal-form sentences of length $\le L$, half of each cohort
# frame truths by completeness, fewer than $s^{K+1}$ certified, so the certified fraction is at most
# $s^{K+1}/\lfloor c^{L}/2\rfloor\to0$.
from frc_5_reductio import predicate; predicate("5:C3")
# Out:
# — reductio.py:347 (the check that decides 5:C3: A4)
#   347      # 5:C2 (p05013), 5:C3 (p05014)
#   348      check("A4", "records: sum_{i<=K} s^i < s^(K+1) (s = 2, 3, 10; K <= 20); no injection of N elements into R < N records (exhaustive); the certified fraction s^(K+1)/floor(c^L/2) falls to 0", ok, "; ".join(det))
#   349
#   350      # A5 the horizon separation: a run on C configurations halts within C steps or loops
#   351      ok = True; det = []
#   352      for C in range(1, 6):
#   353          for f in itertools.product(range(C), repeat=C):                   # every deterministic system; halting state = C-1 (fixed)
#   354              if f[C - 1] != C - 1: continue
#   355              for x in range(C):
#   356                  seen = []; y = x
#   357                  while y not in seen and len(seen) <= C:
#   358                      seen.append(y); y = f[y]
#   359                  halts = (C - 1) in seen
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:C5 (p05016) [T] — the deciding check A5
# Horizon separation: halting for machines of bounded space $K$ is decided from above within $|Q|\,K\,s^{K}$
# steps (a configuration repeats) and never from within (diagonalisation); Turing's theorem is an external
# non-existence theorem, classified with Cantor's, not an instance of the bundle.
from frc_5_reductio import predicate; predicate("5:C5")
# Out:
# — reductio.py:370 (the check that decides 5:C5: A5)
#   370      # 5:C5 (p05016)
#   371      check("A5", "horizon separation: a deterministic run on C configurations halts within C steps or revisits a configuration and never halts — decidable from above by C steps", ok, "; ".join(det))
#   372
#   373  # ------------------------------------------------------------------------------------------------------------
#   374  # block B: the normal forms on a finite universe (5:D2, D3, D4, D9, E8)
#   375  # Sections 2 and 4 of the paper, decided on the bounded universe.  Hereditarily finite sets are coded by Ackermann's
#   376  # bijection (a set with elements a₁, a₂, … is Σ 2^{aᵢ}; x ∈ y iff bit x of y is set), so V₄ is the 65 536 codes below
#   377  # 2¹⁶ and V₃ the 16 codes below 2⁴.  B1 (antinomy normal form, the witness): for every u ∈ V₄ the Russell class
#   378  # {x ∈ u : x ∉ x} is a set of V₄ and is not a member of u; no set of V₄ has every set of V₄ as a member — bounded
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:D2 (p05018) [T] — the deciding check B1
# Antinomy normal form: Cns $+$ AT $+$ comprehension is inconsistent (Russell, Burali--Forti); the witness of
# Cns $+\neg$AT is bounded comprehension --- every set $u$ has a subset not among its members and no universal
# set exists, decided on $V_4$.
from frc_5_reductio import predicate; predicate("5:D2")
# Out:
#   [PASS] B1   EXACT  [5:D2] on V_4 (65536 sets, Ackermann codes) the Russell class of every u is a set not in u; no set of V_4 contains every set of V_4; x notin x throughout — bounded comprehension has no antinomy  --  V_4 exhaustive; the only set containing all of V_3 is V_3 itself, a member of V_4 but not of itself
#   [PASS] B2   EXACT  [5:D3] the external diagonal: for every listing of n strings the diagonal is missing (n <= 3 exhaustive, n = 60 random); no map [n] -> P([n]) is onto (n <= 3); 2^n > n; the diagonal of a complete finite registry is one of its entries  --  no outside-the-list element exists when the registry is complete and finite
#   [PASS] B3   EXACT  [5:D4, 5:E8] on a finite set counting measure is complete and invariant under every bijection (|X| = 6, all 720 permutations x 64 subsets); no injection X + X -> X (|X| <= 4); every ultrafilter on a 3-set is principal (all 3, of the filters enumerated)  --  7 filters on the 3-set, 3 ultrafilters, all principal
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:D3 (p05019) [T] — the deciding check B2
# Diagonal normal form: $\{$Eff, Cns, Cmp, IR$\}$ inconsistent (B2), Tarski a variant with the truth predicate
# for Cmp; the diagonal is a theorem when external --- Cantor's theorem, $n<2^{n}$ on every frame,
# uncountability, halting --- and a paradox engine only over an internalised registry with completeness
# demanded.
from frc_5_reductio import predicate; predicate("5:D3")
# Out:
# — reductio.py:422 (the check that decides 5:D3: B2)
#   422      # 5:D3 (p05019)
#   423      check("B2", "the external diagonal: for every listing of n strings the diagonal is missing (n <= 3 exhaustive, n = 60 random); no map [n] -> P([n]) is onto (n <= 3); 2^n > n; the diagonal of a complete finite registry is one of its entries", ok,
#   424               "no outside-the-list element exists when the registry is complete and finite")
#   425
#   426      # B3 the choice paradoxes vanish on a finite set
#   427      ok = True
#   428      X = range(6)
#   429      for perm in itertools.permutations(X):
#   430          for mask in range(1 << 6):
#   431              A = [x for x in X if mask >> x & 1]
#   432              ok &= len({perm[x] for x in A}) == len(A)                     # counting measure is invariant under every bijection
#   433      for k in (1, 2, 3, 4):
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:D4 (p05020) [T] — the deciding check B3
# Choice normal forms: Vitali (countably additive translation-invariant measure on all subsets $+$ AC$\infty$
# on $\R/\Q$, a countable amenable group) and Banach--Tarski (finitely additive isometry-invariant measure $+$
# AC$\infty$ $+$ a free non-amenable rotation subgroup) are inconsistent bundles with distinct mechanisms; the
# finite witness is counting measure with definable choice.
from frc_5_reductio import predicate; predicate("5:D4")
# Out:
# — reductio.py:446 (the check that decides 5:D4: B3)
#   446      # 5:D4 (p05020), 5:E8 (p05034)
#   447      check("B3", "on a finite set counting measure is complete and invariant under every bijection (|X| = 6, all 720 permutations x 64 subsets); no injection X + X -> X (|X| <= 4); every ultrafilter on a 3-set is principal (all 3, of the filters enumerated)", ok,
#   448               f"{len(filters)} filters on the 3-set, 3 ultrafilters, all principal")
#   449
#   450      # B4 iterated singletons are pairwise distinct and of unbounded rank
#   451      ok = True; s = 0; seen = set(); ranks = []
#   452      for k in range(7):
#   453          ok &= s not in seen; seen.add(s)
#   454          r = 0; t = s
#   455          while t: r += 1; t = max(members(t)) if members(t) else 0      # rank = depth of the singleton chain
#   456          ranks.append(r)
#   457          if k < 6: s = 1 << s                                              # {s}
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:D8 (p05024) [T] — the deciding check D1
# Finiteness of determinate totalities: in ZF with every infinite set Dedekind-infinite, a structure satisfies
# Det iff it is finite --- finite: the full higher-order theory decided by exhaustive evaluation; infinite: a
# copy of $\N$ inside gives an effective reduction of true second-order arithmetic, which is not arithmetical.
# The real field's first-order tameness is silence about its subsets.
from frc_5_reductio import predicate; predicate("5:D8")
# Out:
#   [PASS] D1   EXACT  [5:D8] the full second-order theory of W_3 is decided by exhaustive evaluation: 8 subsets, 512 relations, 27 functions; the well-ordering sentence and Dedekind-finiteness are true, the existence of a linear order true, a false sentence false  --  second-order quantifiers as finite conjunctions/disjunctions
#   [PASS] D2   EXACT  [5:B7] the Pi_1 sentence 'every even number is a sum of two primes' receives a verdict from each frame about its own domain: true in W_N for every 4 <= N <= 400; the closure over all frames is not a sentence of any frame  --  397 frames, all true; no frame decides the unbounded quantifier
# — reductio.py:659 (the check that decides 5:D8: D1)
#   659      # 5:D8 (p05024)
#   660      check("D1", "the full second-order theory of W_3 is decided by exhaustive evaluation: 8 subsets, 512 relations, 27 functions; the well-ordering sentence and Dedekind-finiteness are true, the existence of a linear order true, a false sentence false", ok,
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:D9 (p05025) [T] — the deciding check B4
# Corollaries: no absolute totality is determinate (a universal set is infinite by the iterated singletons);
# Meas is decided content --- a Det totality decides every measure question, trivially on a finite one
# (counting measure). The totalising conjuncts of two normal forms follow from D8.
from frc_5_reductio import predicate; predicate("5:D9")
# Out:
# — reductio.py:459 (the check that decides 5:D9: B4)
#   459      # 5:D9 (p05025)
#   460      check("B4", "the iterated singletons emptyset, {emptyset}, {{emptyset}}, ... (7 of them, the last of 65 537 bits) are pairwise distinct with ranks 0, 1, 2, ...: a universal set would be infinite", ok, f"ranks {ranks}")
#   461
#   462  # ------------------------------------------------------------------------------------------------------------
#   463  # block C: choice recovered on finite and periodic structures (5:E1–E6)
#   464  # Section 5 of the paper.  C1: global choice on a finite universe — ch(A) = min A is a member of every nonempty
#   465  # subset of F₁₃ (all 8191), and finite products are nonempty by induction.  C2: periodic choice — an equality-periodic
#   466  # family receives a choice function of the same period.  C3: equivariant choice — over random finite G-families
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E1 (p05027) [T] — the deciding check C1
# Global choice on a finite universe: with a canonical order, $\operatorname{ch}(A)=\min A$ is a uniform
# pointwise choice rule; over a fixed finite base AC is a definable theorem; finite products are nonempty
# without it.
from frc_5_reductio import predicate; predicate("5:E1")
# Out:
#   [PASS] C1   EXACT  [5:E1] ch(A) = min A is a member and the least element of every nonempty subset of F_13 (8191 subsets); finite products of nonempty sets are nonempty
#   [PASS] C2   EXACT  [5:E2] an equality-periodic family A_{i+N} = A_i on F_13 has the choice f(i) = min A_i of the same period (50 random families, periods 1..7)
#   [PASS] C3   EXACT  [5:E3] a G-equivariant section exists iff every stabiliser action on its fibre has a fixed point: exhaustive on both sides for random G-families, G = Z/2, Z/3, S_3, fibres of size 1..3  --  139 families, 136 with a section; the criterion agrees in every case
#   [PASS] C4   EXACT  [5:E4] every subspace of F_5^3 (64 of them) has the greedy minimal basis, independent and spanning; the involution v -> -v on the line fixes no basis over F_p for odd p <= 13 and fixes 1 over F_2  --  obstruction over F_3, F_5, F_7, F_11, F_13; none over F_2
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E2 (p05028) [T] — the deciding check C2
# Periodic choice: an equality-periodic family $A_{i+N}=A_i$ has the choice $f(i)=\operatorname{ch}(A_i)$ of
# the same period; group-periodic families as equivariant surjections $\pi:A\to I$ with equivariant sections.
from frc_5_reductio import predicate; predicate("5:E2")
# Out:
# — reductio.py:501 (the check that decides 5:E2: C2)
#   501      # 5:E2 (p05028)
#   502      check("C2", "an equality-periodic family A_{i+N} = A_i on F_13 has the choice f(i) = min A_i of the same period (50 random families, periods 1..7)", ok, "")
#   503
#   504      # C3 equivariant choice iff stabiliser fixed points
#   505      ok = True; n_cases = 0; n_exist = 0
#   506      for gname in ("Z2", "Z3", "S3"):
#   507          G = perm_group(gname); nI = len(G[0])
#   508          for _ in range(60):
#   509              # the index set I = orbit of G on {0..nI-1} (one orbit, transitive by construction? use the natural action)
#   510              # a G-family: fibers A_i of size m with an action of G on the total space compatible with the projection.
#   511              # Build it as an induced family: A = I x F with g.(i, a) = (g.i, rho_i(g).a) for a cocycle rho; take
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E3 (p05029) [T] — the deciding check C3
# Equivariant periodic choice: a $G$-equivariant section exists iff each stabiliser action
# $G_i\curvearrowright A_i$ has a fixed point (one orbit at a time); the Fraenkel--Mostowski mechanism in
# positive form.
from frc_5_reductio import predicate; predicate("5:E3")
# Out:
# — reductio.py:533 (the check that decides 5:E3: C3)
#   533      # 5:E3 (p05029)
#   534      check("C3", "a G-equivariant section exists iff every stabiliser action on its fibre has a fixed point: exhaustive on both sides for random G-families, G = Z/2, Z/3, S_3, fibres of size 1..3", ok,
#   535               f"{n_cases} families, {n_exist} with a section; the criterion agrees in every case")
#   536
#   537      # C4 the definable basis and the equivariant obstruction
#   538      p = 5; ok = True
#   539      vecs = list(itertools.product(range(p), repeat=3))
#   540      def span(B):
#   541          S = {(0, 0, 0)}
#   542          for b in B:
#   543              S = {tuple((s[k] + c * b[k]) % p for k in range(3)) for s in S for c in range(p)}
#   544          return S
#   545      subspaces = set()
#   546      for k in range(4):
#   [PASS] C3   (deciding)       139 families, 136 with a section; the criterion agrees in every case
# 5:E3: VERIFIED — 1 record(s)

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E4 (p05030) [T] — the deciding check C4
# The definable basis: every subspace of a finite vector space has the greedy $\min$-basis, one definable
# function on all subspaces; the equivariant obstruction --- $\Z/2$ acting by $v\mapsto-v$ on the line over
# $\F_5$ fixes no basis ($-v\neq v$), over $\F_2$ it does: arithmetic, not formal.
from frc_5_reductio import predicate; predicate("5:E4")
# Out:
# — reductio.py:558 (the check that decides 5:E4: C4)
#   558      # 5:E4 (p05030)
#   559      check("C4", "every subspace of F_5^3 (64 of them) has the greedy minimal basis, independent and spanning; the involution v -> -v on the line fixes no basis over F_p for odd p <= 13 and fixes 1 over F_2", ok,
#   560               "obstruction over F_3, F_5, F_7, F_11, F_13; none over F_2")
#   561
#   562      # C5 periodic Koenig
#   563      ok = True; n_graphs = 0
#   564      for n in (1, 2, 3):
#   565          for out in itertools.product(*[list(itertools.chain.from_iterable(itertools.combinations(range(n), r) for r in range(1, n + 1))) for _ in range(n)]):
#   566              n_graphs += 1
#   567              for r in range(n):
#   568                  walk = [r]
#   569                  while len(walk) <= n:
#   570                      walk.append(min(out[walk[-1]]))
#   571                  seen = {}; period = None
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E5 (p05031) [T] — the deciding check C5
# Periodic K\H{o}nig: in a finite digraph with out-degree $\ge1$ the greedy walk repeats a vertex within
# $|D|+1$ steps and is eventually periodic with period $\le|D|$ --- the pigeonhole on an iteration over
# finitely many states.
from frc_5_reductio import predicate; predicate("5:E5")
# Out:
# — reductio.py:584 (the check that decides 5:E5: C5)
#   584      # 5:E5 (p05031)
#   585      check("C5", "periodic Koenig: in every finite digraph with out-degree >= 1 the greedy walk repeats within |D|+1 steps and is eventually periodic with period <= |D| (exhaustive |D| <= 3, random |D| = 10, 20, 30)", ok,
#   586               f"{n_graphs} digraphs exhaustive")
#   587
#   588      # C6 periodic de Bruijn-Erdos in dimension one
#   589      ok = True; n_col = 0; n_uncol = 0
#   590      for _ in range(40):
#   591          b = rng.randrange(1, 4); c = rng.choice((2, 3))
#   592          intra = [(u, v) for u in range(b) for v in range(u + 1, b) if rng.random() < 0.6]     # edges inside a block
#   593          inter = [(u, v) for u in range(b) for v in range(b) if rng.random() < 0.4]            # block k -> block k+1
#   594          cols = [col for col in itertools.product(range(c), repeat=b) if all(col[u] != col[v] for u, v in intra)]
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E6 (p05032) [T] — the deciding check C6
# Periodic de~Bruijn--Erd\H{o}s, dimension one: a $\sigma$-periodic graph of bounded range whose finite
# subgraphs are $c$-colourable admits a definable $\sigma^{m}$-periodic $c$-colouring (the transfer digraph
# $D_c$, its sub-digraph of vertices beginning walks of every length, E5).
from frc_5_reductio import predicate; predicate("5:E6")
# Out:
# — reductio.py:618 (the check that decides 5:E6: C6)
#   618      # 5:E6 (p05032)
#   619      check("C6", "periodic de Bruijn-Erdos (dimension one): the transfer digraph decides c-colorability of all finite subgraphs of a random periodic graph; when they are colorable, a definable sigma^m-periodic coloring with m <= |D'_c| is produced and verified", ok,
#   620               f"40 random periodic graphs (block <= 3, range 1, c = 2, 3): {n_col} colorable with a periodic coloring found, {n_uncol} with a finite obstruction")
#   621
#   622  def longest_walk(cols, edges):
#   623      best = 0
#   624      for x in cols:
#   625          frontier = {x}; L = 0
#   626          while frontier and L <= len(cols):
#   627              frontier = {y for f in frontier for y in cols if (f, y) in edges}; L += 1 if frontier else 0
#   628          best = max(best, L)
#   629      return best
#   630
# ...

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
# 5:E8 (p05034) [T] — the deciding check B3
# The choice paradoxes vanish: on a finite set counting measure is complete and invariant, no decomposition
# doubles the set ($X\sqcup X$ does not inject into $X$), and every ultrafilter is principal; periodic
# variants inherit this on one period.
from frc_5_reductio import predicate; predicate("5:E8")
# Out:
# — reductio.py:446 (the check that decides 5:E8: B3)
#   446      # 5:D4 (p05020), 5:E8 (p05034)
#   447      check("B3", "on a finite set counting measure is complete and invariant under every bijection (|X| = 6, all 720 permutations x 64 subsets); no injection X + X -> X (|X| <= 4); every ultrafilter on a 3-set is principal (all 3, of the filters enumerated)", ok,
#   448               f"{len(filters)} filters on the 3-set, 3 ultrafilters, all principal")
#   449
#   450      # B4 iterated singletons are pairwise distinct and of unbounded rank
#   451      ok = True; s = 0; seen = set(); ranks = []
#   452      for k in range(7):
#   453          ok &= s not in seen; seen.add(s)
#   454          r = 0; t = s
#   455          while t: r += 1; t = max(members(t)) if members(t) else 0      # rank = depth of the singleton chain
#   456          ranks.append(r)
#   457          if k < 6: s = 1 << s                                              # {s}
# ...

# %% [markdown]
# ## Summary
#
# The cells above are the paper's python-witnessed predicates; the whole script, check by check, is `python3 reductio.py`
# (17 checks, `results.json`), `python3 -m frc_5_reductio` once installed.

# %%
# !pip install -q frc-5-reductio --find-links https://finitering.space/pkg/
from frc_5_reductio import verify_all
assert verify_all(), "a check failed"
print("all checks pass")
# Out:
# SUMMARY: 17/17 checks passed
# all checks pass

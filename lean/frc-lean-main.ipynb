# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gamayos/finite-ring-space/blob/main/lean/frc-lean-main.ipynb)
#
# # FRC predicate ledgers — the Lean witnesses
#
# Each module under `lean/FrcLedger/` proves ledger rows of one paper as Lean 4 theorems over Mathlib
# (`Algebra`, `Causality`, `Dimensions`, `Entropy`, `Epi`, `Fourier`, `Geometry`, `Reductio`, `Representation`, `Rh`). This notebook installs the pinned toolchain, fetches Mathlib's
# compiled cache and re-checks every module, then prints the axioms each theorem depends on and applies the
# strict gate (only `propext`, `Classical.choice`, `Quot.sound`; `sorryAx` and `native_decide` fail).
#
# Budget: 10–15 minutes on a fresh Colab runtime, almost all of it the cache download. To read a proof with
# live goal states instead, open the module in the Lean web editor — links in `lean/README.md`.

# %%
# --- toolchain: elan installs the Lean version pinned in lean-toolchain on first use
import os
if not os.path.exists(os.path.expanduser("~/.elan/bin/lake")):
    # !curl -sSf https://raw.githubusercontent.com/leanprover/elan/master/elan-init.sh | sh -s -- -y --default-toolchain none
os.environ["PATH"] = os.path.expanduser("~/.elan/bin") + ":" + os.environ["PATH"]
# !lake --version || true

# %%
# --- the package: a sparse clone of lean/ (Colab) or the checkout this notebook lives in
if not os.path.exists("lakefile.toml"):
    if not os.path.exists("finite-ring-space"):
        # !git clone --depth 1 --filter=blob:none --sparse https://github.com/gamayos/finite-ring-space
        # !cd finite-ring-space && git sparse-checkout set lean
    # %cd finite-ring-space/lean
# !cat lean-toolchain && grep -A2 'name = "mathlib"' lake-manifest.json | head -3

# %%
# --- Mathlib's compiled cache (≈7 GB unpacked; minutes), then the build of the modules themselves
# !lake exe cache get
# !lake build

# %%
# --- Algebra: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Algebra.lean

# %%
# --- Causality: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Causality.lean

# %%
# --- Dimensions: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Dimensions.lean

# %%
# --- Entropy: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Entropy.lean

# %%
# --- Epi: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Epi.lean

# %%
# --- Fourier: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Fourier.lean

# %%
# --- Geometry: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Geometry.lean

# %%
# --- Reductio: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Reductio.lean

# %%
# --- Representation: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Representation.lean

# %%
# --- Rh: re-check the module (0 errors expected; linter notes are not errors)
# !lake env lean FrcLedger/Rh.lean

# %%
# --- the axioms of every theorem, and the strict gate
# !python3 check_axioms.py
print(open("axioms.log").read())

# %%
# --- the web copies (one self-contained file per module, for live.lean-lang.org) still compile
# !python3 make_web.py --check
for m in __import__("glob").glob("web/*.lean"):
    print("==", m); !lake env lean {m}
